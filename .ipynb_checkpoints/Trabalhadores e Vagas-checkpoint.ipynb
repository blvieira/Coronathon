# %% [markdown]
# # Importando as libraries

# %%
import os
import pandas as pd
import numpy as np
import re
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
import unicodedata
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm
from nltk.stem import SnowballStemmer
from nltk.stem import RSLPStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split, GridSearchCV
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import glob

# %%
import sqlite3

# %%
#nltk.download('stopwords')
#nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hugos\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %% [markdown]
# # Lendo e salvando todos os arquivos de trabalhadores em um único dataframe

# %%
path = r'SINE/Trabalhadores' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, sep=";", encoding='iso-8859-1')
    li.append(df)

trabalhadores = pd.concat(li, axis=0, ignore_index=True)

# %% [markdown]
# # Criando todo o framework para o preprocessamento

# %%
def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

# %%
CONTRACTION_MAP = {
    "d'aquela": "de aquela",
    "d'aquella": "de aquela",
    "d'aquellas": "de aquelas",
    "d'aquelle": "de aquele",
    "d'aquelles": "de aqueles",
    "d'aquillo": "de aquilo",
    'daquela': "de aquela",
    'daquelas': "de aquelas",
    'daquele': "de aquele",
    'daqueles': "de aqueles",
    'daquella': "de aquela",
    'daquelle': "de aquele",
    'daquelles': "de aquela",
    'daqueloutro': "de aquele outro",
    'daquillo': "de aquilo",
    'daquilo': "de aquilo",
    "n'aquella": "em aquela",
    "n'aquellas": "em aquelas",
    "n'aquelle": "em aquele",
    "n'aquelles": "em aqueles",
    "n'aquillo": "em aquilo",
    'naquela': "em aquela",
    'naquelas': "em aquelas",
    'naquele': "em aquele",
    'naqueles': "em aqueles",
    'naquella': "em aquela",
    'naquelle': "em aquele",
    'naquilo': "em aquilo",
    "d'essa": "de essa",
    "d'essas": "de essas",
    "d'esse": "de esse",
    "d'esses": "de essa",
    "d'esta": "de esta",
    "d'estas": "de estas",
    "d'este": "de este",
    "d'estes": "de estes",
    'dessa': "de essa",
    'dessas': "de essas",
    'desses': "de esses",
    'desta': "de esta",
    'destas': "de estas",
    'deste': "de este",
    'destes': "de estes",
    "n'essa": "em essa",
    "n'essas": "em essas",
    "n'esse": "em esse",
    "n'esses": "em esses",
    "n'esta": "em esta",
    "n'estas": "em estas",
    "n'este": "em este",
    "n'estes": "em estes",
    'nessa': "em essa",
    'nessas': "em essas",
    'nesse': "em esse",
    'nesses': "em esses",
    'nesta': "em esta",
    'nestas': "em estas",
    'neste': "em este",
    'nestes': "em estes",
    "d'isso": "de isso",
    "d'isto": "de isto",
    'disso': "de isso",
    'disto': "de isto",
    "n'isso": "em isso",
    "n'isto": "em isto",
    'nisso': "em isso",
    'nisto': "em isto"
}

# %%
def expand_contractions(text, contraction_mapping=CONTRACTION_MAP):
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), flags=re.IGNORECASE|re.DOTALL)
    
    def expand_match(contraction):
        match = contraction.group(0)
        expanded_contraction = contraction_mapping.get(match) if contraction_mapping.get(match) else contraction_mapping.get(match.lower())
        expanded_contraction = expanded_contraction[0:]
        return expanded_contraction
    
    expanded_text = contractions_pattern.sub(expand_match, text)
    return expanded_text

# %%
def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-z0-9\s\-]' if not remove_digits else r'[^a-zA-z\s\-]'
    text = re.sub(pattern, '', text)
    return text

# %%
def caseconversion(text, case_type = 'lower'):
    if case_type == 'lower':
        text = text.lower()
    elif case_type == 'upper':
        text = text.upper()
    elif case_type == 'title':
        text = text.title()
    return text

# %%
def simple_stemmer(text, stemmer='RSLP'):
    ps = RSLPStemmer()
    if stemmer=='Snowball':
        ps = SnowballStemmer("portuguese")
    text = ' '.join([ps.stem(word) for word in text.split()])
    return text

# %%
stopword_list = nltk.corpus.stopwords.words('portuguese')
new_stopwords = ['ate', 'até', 'ano', 'vai', 'sera', 'será']
stopword_list.extend(new_stopwords)

# %%
def remove_stopwords(text, is_lower_case=False):
    tokens = nltk.word_tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

# %%
def preprocess_corpus(corpus, contraction_expansion=True, accented_char_removal=True, 
                     text_lower_case=True, stem_or_lemma='stem', special_char_removal=True, stopword_removal=True, 
                     remove_digits=False):
    preprocessed_corpus = []
    # preprocess each document in the corpus
    for doc in tqdm(corpus):
        # remove accented characters
        if accented_char_removal:
            doc = remove_accented_chars(doc)
        # expand contractions
        if contraction_expansion:
            doc = expand_contractions(doc)
        # lowercase the text
        if text_lower_case:
            doc = doc.lower()
        # remove extra newlines
            doc = re.sub(r'[\r|\n|\r\n]+', ' ',doc)
        # lemmatize or stem text
#         if stem_or_lemma == 'stem':
#             doc = simple_stemmer(doc, stemmer='RSLP')
#         elif stem_or_lemma == 'lemma':
#             doc = lemmatize_text(doc)
#         else doc = doc
        # remove special characters and\or digits
        if special_char_removal:
            # insert spaces between special characters to isolate them
            special_char_pattern = re.compile(r'([{.(-)!}])')
            doc = special_char_pattern.sub(" \\1 ", doc)
            doc = remove_special_characters(doc, remove_digits=remove_digits)
        # remove extra whitespace
        doc = re.sub(' +', ' ', doc)
        # remove stopwords
        if stopword_removal:
            doc = remove_stopwords(doc, is_lower_case=text_lower_case)
        preprocessed_corpus.append(doc)
    return preprocessed_corpus

# %% [markdown]
# # Criando um dataframe apenas com trabalhadores que cadastraram cursos profissionalizantes

# %%
trab_com_cursos = trabalhadores[trabalhadores.CURSOS_PROFISSIONALIZANTES.notnull()]

# %% [markdown]
# # Explodindo o campo PRETENSOES em linhas diferentes linhas, caso o trabalhador possua mais de um CBO cadastrado.

# %%
trab_com_cursos.PRETENSOES = trab_com_cursos.PRETENSOES.str.split('|')
trab_com_cursos = trab_com_cursos.explode('PRETENSOES')

# %% [markdown]
# # Removendo os registros com o campo PRETENSOES nulo

# %%
trab_com_cursos = trab_com_cursos[trab_com_cursos.PRETENSOES.notnull()]

# %% [markdown]
# # Criando um campo com Código da Ocupação a partir do campo PRETENSOES

# %%
trab_com_cursos['cod_ocupacao'] = trab_com_cursos.PRETENSOES.str.split('-').apply(lambda x:x[0])

# %%
trab_com_cursos['pretensao'] = trab_com_cursos.PRETENSOES.str.split('(').apply(lambda x:x[0])
trab_com_cursos['pretensao'] = trab_com_cursos.pretensao.str.split('-').apply(lambda x:x[1])

# %%
trabalhadores.PRETENSOES = trabalhadores.PRETENSOES.astype(str)

# %%
trabalhadores['pretensao'] = trabalhadores.PRETENSOES.str.split('(').apply(lambda x:x[0])
trabalhadores['pretensao'] = trabalhadores.pretensao.str.split('-').apply(lambda x:x[1] if len(x)>1 else x[0])

# %%
trab_com_cursos.head(3)
# Out:
#   NACIONALIDADE DEFICIENCIAS                  BAIRRO          CEP  \
# 8    BRASILEIRA          NaN  JARDIM MARIA DE FATIMA  1.32205e+07
# 8    BRASILEIRA          NaN  JARDIM MARIA DE FATIMA  1.32205e+07
# 8    BRASILEIRA          NaN  JARDIM MARIA DE FATIMA  1.32205e+07
#
#   CODIGO_MUNICIPIO_IBGE   NOME_MUNICIPIO  UF    ESCOLARIDADE ESTUDANTE  \
# 8                355650  VARZEA PAULISTA  SP  Médio Completo         S
# 8                355650  VARZEA PAULISTA  SP  Médio Completo         S
# 8                355650  VARZEA PAULISTA  SP  Médio Completo         S
#
#   CURSOS_PROFISSIONALIZANTES  ... IDIOMAS HABILITACAO VEICULOS DISP_VIAJAR  \
# 8     auxliar administrativo  ...     NaN      Nenhum        N           N
# 8     auxliar administrativo  ...     NaN      Nenhum        N           N
# 8     auxliar administrativo  ...     NaN      Nenhum        N           N
#
#   DISP_DORMIR_EMP DISP_AUSENTAR_DOMIC  \
# 8               N                   N
# 8               N                   N
# 8               N                   N
#
#                                           PRETENSOES MUNICIPIOS_INTERESSE  \
# 8  374110-Auxiliar técnico de montagem(N,19,0,Ind...                  NaN
# 8     514320-Auxiliar de limpeza(N,0,13,Indiferente)                  NaN
# 8  521110-Vendedor - no comércio de mercadorias(N...                  NaN
#
#   cod_ocupacao                     pretensao
# 8       374110  Auxiliar técnico de montagem
# 8       514320           Auxiliar de limpeza
# 8       521110                     Vendedor
#
# [3 rows x 22 columns]

# %%
trabalhadores.head(3)
# Out:
#   NACIONALIDADE DEFICIENCIAS                       BAIRRO          CEP  \
# 0    BRASILEIRA          NaN                  VILA UNIDOS  1.22145e+07
# 1    BRASILEIRA          NaN                    MONTANHAO  9.78414e+06
# 2    BRASILEIRA          NaN  JARDIM SANTA TEREZINHA (ZON  8.43002e+06
#
#   CODIGO_MUNICIPIO_IBGE         NOME_MUNICIPIO  UF         ESCOLARIDADE  \
# 0                354990    SAO JOSE DOS CAMPOS  SP  Superior Incompleto
# 1                354870  SAO BERNARDO DO CAMPO  SP       Médio Completo
# 2                355030              SAO PAULO  SP       Médio Completo
#
#   ESTUDANTE CURSOS_PROFISSIONALIZANTES  ... POS_GRADUACOES IDIOMAS  \
# 0         S                        NaN  ...            NaN     NaN
# 1         N                        NaN  ...            NaN     NaN
# 2         N                        NaN  ...            NaN     NaN
#
#   HABILITACAO VEICULOS DISP_VIAJAR DISP_DORMIR_EMP DISP_AUSENTAR_DOMIC  \
# 0          AB        N           N               N                   N
# 1      Nenhum        N           N               N                   N
# 2      Nenhum        N           N               N                   N
#
#                                           PRETENSOES MUNICIPIOS_INTERESSE  \
# 0  521110-Vendedor de comércio varejista(N,54,0,I...                  NaN
# 1  513505-Ajudante de cozinha(N,0,0,Indiferente)|...                  NaN
# 2  411005-Auxiliar administrativo(N,0,0,Indiferen...                  NaN
#
#                         pretensao
# 0  Vendedor de comércio varejista
# 1             Ajudante de cozinha
# 2         Auxiliar administrativo
#
# [3 rows x 21 columns]

# %%
trab_com_cursos.to_pickle("./trabalhadores.pkl")

# %%
# trab_com_cursos = pd.read_pickle("./trabalhadores.pkl")

# %% [markdown]
# # Extraindo as 10 principais ocupações procuradas (com cursos)

# %%
top_10_ocup_com_cursos = list(trab_com_cursos.pretensao.value_counts().index[:10])

# %%
top_10_ocup_com_cursos
# Out:
# ['Auxiliar de linha de produção',
#  'Auxiliar de limpeza',
#  'Operador de caixa',
#  'Recepcionista atendente',
#  'Auxiliar administrativo',
#  'Repositor de mercadorias',
#  'Porteiro',
#  'Assistente administrativo',
#  'Atendente balconista',
#  'Atendente de lanchonete']

# %%
print(f'As ocupações mais procuradas pelos trabalhadores são: {top_10_ocup_com_cursos}')
# Out:
# As ocupações mais procuradas pelos trabalhadores são: ['Auxiliar de linha de produção', 'Auxiliar de limpeza', 'Operador de caixa', 'Recepcionista atendente', 'Auxiliar administrativo', 'Repositor de mercadorias', 'Porteiro', 'Assistente administrativo', 'Atendente balconista', 'Atendente de lanchonete']

# %% [markdown]
# # Criando o corpus apenas para a principal ocupação

# %%
corpus = trab_com_cursos.loc[trab_com_cursos.pretensao == top_10_ocup_com_cursos[0],'CURSOS_PROFISSIONALIZANTES'].copy()

# %%
corpus = preprocess_corpus(corpus)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 203989/203989 [00:59<00:00, 3442.18it/s]

# %%
def get_top_n_words(corpus, n=10, n_gram=2):
    """
    List the top n words in a vocabulary according to occurrence in a text corpus.
    
    get_top_n_words(["I love Python", "Python is a language programming", "Hello world", "I love the world"]) -> 
    [('python', 2),
     ('world', 2),
     ('love', 2),
     ('hello', 1),
     ('is', 1),
     ('programming', 1),
     ('the', 1),
     ('language', 1)]
    """
    vec = CountVectorizer(ngram_range=(n_gram,n_gram)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
t = get_top_n_words(corpus)

# %%
t
# Out:
# [('informatica basica', 50907),
#  ('operador empilhadeira', 10800),
#  ('informatica basico', 9485),
#  ('ensino medio', 7290),
#  ('cursou ate', 5626),
#  ('ano ensino', 5544),
#  ('auxiliar administrativo', 4000),
#  ('controlador acesso', 3792),
#  ('seguranca trabalho', 3440),
#  ('desenho tecnico', 2999)]

# %% [markdown]
# # Agora, para as 10 ocupações com maior procura, vamos rodar e gravar os resultados. Quais são as características dos candidatos à mesma ocupação?

# %%
top_caracteristicas = {}

# %%
for job in top_10_ocup_com_cursos:
    corpus = trab_com_cursos.loc[trab_com_cursos.pretensao == job,'CURSOS_PROFISSIONALIZANTES'].copy()
    corpus = preprocess_corpus(corpus)
    top_caracteristicas[job] = get_top_n_words(corpus)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 203989/203989 [01:00<00:00, 3366.09it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 133489/133489 [00:41<00:00, 3229.90it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 116397/116397 [00:28<00:00, 4123.97it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 105239/105239 [00:26<00:00, 3906.14it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 89197/89197 [00:22<00:00, 3986.61it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 83886/83886 [00:19<00:00, 4289.60it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 73695/73695 [00:18<00:00, 3964.59it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 59798/59798 [00:18<00:00, 3169.86it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 56961/56961 [00:12<00:00, 4620.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 56258/56258 [00:11<00:00, 5081.87it/s]

# %%
top_caracteristicas
# Out:
# {'Auxiliar de linha de produção': [('informatica basica', 50907),
#   ('operador empilhadeira', 10800),
#   ('informatica basico', 9485),
#   ('ensino medio', 7290),
#   ('auxiliar administrativo', 4000),
#   ('controlador acesso', 3792),
#   ('seguranca trabalho', 3440),
#   ('desenho tecnico', 2999),
#   ('leitura interpretacao', 2945),
#   ('interpretacao desenho', 2899)],
#  'Auxiliar de limpeza': [('informatica basica', 26325),
#   ('ensino medio', 6334),
#   ('informatica basico', 5456),
#   ('ensino fundamental', 4820),
#   ('controlador acesso', 3941),
#   ('serie ensino', 3756),
#   ('parou serie', 2720),
#   ('cuidador idosos', 2687),
#   ('cursou serie', 2563),
#   ('5a serie', 2025)],
#  'Operador de caixa': [('informatica basica', 35611),
#   ('informatica basico', 7122),
#   ('auxiliar administrativo', 4025),
#   ('ensino medio', 3772),
#   ('atendimento cliente', 2850),
#   ('operador caixa', 2277),
#   ('tecnico administracao', 2268),
#   ('gestao empresarial', 2009),
#   ('assistente administrativo', 1964),
#   ('recursos humanos', 1944)],
#  'Recepcionista atendente': [('informatica basica', 30566),
#   ('informatica basico', 5862),
#   ('ensino medio', 3905),
#   ('auxiliar administrativo', 3859),
#   ('tecnico administracao', 2598),
#   ('gestao empresarial', 2279),
#   ('atendimento cliente', 2227),
#   ('recursos humanos', 2008),
#   ('pacote office', 1942),
#   ('assistente administrativo', 1942)],
#  'Auxiliar administrativo': [('informatica basica', 19929),
#   ('auxiliar administrativo', 4388),
#   ('tecnico administracao', 4018),
#   ('informatica basico', 3733),
#   ('ensino medio', 3123),
#   ('pacote office', 2676),
#   ('gestao empresarial', 2500),
#   ('recursos humanos', 2072),
#   ('assistente administrativo', 1864),
#   ('seguranca trabalho', 1767)],
#  'Repositor de mercadorias': [('informatica basica', 21324),
#   ('informatica basico', 4345),
#   ('ensino medio', 4295),
#   ('operador empilhadeira', 2493),
#   ('controlador acesso', 1781),
#   ('auxiliar administrativo', 1681),
#   ('pacote office', 1052),
#   ('atendimento cliente', 1046),
#   ('gestao empresarial', 986),
#   ('seguranca trabalho', 984)],
#  'Porteiro': [('informatica basica', 12574),
#   ('controlador acesso', 6202),
#   ('operador empilhadeira', 3520),
#   ('informatica basico', 2582),
#   ('ensino medio', 2297),
#   ('fiscal loja', 1361),
#   ('bombeiro civil', 1287),
#   ('seguranca trabalho', 1255),
#   ('porteiro vigilante', 1121),
#   ('transporte coletivo', 1119)],
#  'Assistente administrativo': [('informatica basica', 11777),
#   ('tecnico administracao', 3126),
#   ('assistente administrativo', 2558),
#   ('auxiliar administrativo', 2352),
#   ('informatica basico', 2200),
#   ('departamento pessoal', 2074),
#   ('pacote office', 1997),
#   ('recursos humanos', 1821),
#   ('seguranca trabalho', 1497),
#   ('tecnico contabilidade', 1389)],
#  'Atendente balconista': [('informatica basica', 15808),
#   ('informatica basico', 3050),
#   ('ensino medio', 2611),
#   ('auxiliar administrativo', 1578),
#   ('atendimento cliente', 985),
#   ('tecnico administracao', 983),
#   ('gestao empresarial', 981),
#   ('pacote office', 876),
#   ('recursos humanos', 775),
#   ('assistente administrativo', 766)],
#  'Atendente de lanchonete': [('informatica basica', 15226),
#   ('ensino medio', 3971),
#   ('informatica basico', 3165),
#   ('auxiliar administrativo', 1337),
#   ('cursando ensino', 902),
#   ('gestao empresarial', 854),
#   ('controlador acesso', 817),
#   ('atendimento cliente', 771),
#   ('ens medio', 695),
#   ('pacote office', 694)]}

# %% [markdown]
# # Quais são as demais características dos candidatos à mesma função?

# %%
top_outras_caracteristicas = {}

# %% [markdown]
# Vamos obter as 10 ocupações com maior procura, com ou sem cursos.

# %%
top_10_ocup = list(trabalhadores.pretensao.value_counts().index[:10])

# %%
for job in tqdm(top_10_ocup):
    temp_trab = trabalhadores[trabalhadores.pretensao == job]
    top_outras_caracteristicas[job] = {'ESCOLARIDADE': (temp_trab.ESCOLARIDADE.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict(),
                                       'POS_GRADUACOES': (temp_trab.POS_GRADUACOES.isna().value_counts()/temp_trab.shape[0]).to_dict(),
                                       'IDIOMAS': (temp_trab.IDIOMAS.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict(),
                                       'HABILITACAO': (temp_trab.HABILITACAO.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict(),
                                       'VEICULOS': (temp_trab.VEICULOS.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict(),
                                       'DISP_VIAJAR': (temp_trab.DISP_VIAJAR.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict(),
                                       'DISP_DORMIR_EMP': (temp_trab.DISP_DORMIR_EMP.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict(),
                                       'DISP_AUSENTAR_DOMIC': (temp_trab.DISP_AUSENTAR_DOMIC.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict()
                                       }
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:10<00:00,  1.07s/it]

# %%
top_outras_caracteristicas
# Out:
# {'Operador de caixa': {'ESCOLARIDADE': {'Médio Completo': 0.7849883047449321,
#    'Médio Incompleto': 0.10326631766540433,
#    'Fundamental Completo': 0.042228224548897304,
#    'Superior Incompleto': 0.03261444642459345,
#    'Superior Completo': 0.015238638895076855},
#   'POS_GRADUACOES': {True: 0.9996936957006015, False: 0.00030630429939852976},
#   'IDIOMAS': {nan: 0.9700309088883938,
#    'Inglês Básico': 0.014528569837380262,
#    'Espanhol Básico': 0.002937736689685899,
#    'Inglês Intermediário': 0.0027776230786366674,
#    'Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado': 0.0027567386945867678},
#   'HABILITACAO': {'Nenhum': 0.8715958453998663,
#    'AB': 0.07030379817331255,
#    'B': 0.04795054577856984,
#    'A': 0.004796446870126977,
#    'AD': 0.00201882379149031},
#   'VEICULOS': {'N': 0.9756905769659167, 'S': 0.024309423034083316},
#   'DISP_VIAJAR': {'N': 0.8297574626865671, 'S': 0.17024253731343283},
#   'DISP_DORMIR_EMP': {'N': 0.8571786589440855, 'S': 0.14282134105591446},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.859796168411673, 'S': 0.14020383158832703}},
#  'Auxiliar de escritório': {'ESCOLARIDADE': {'Médio Completo': 0.6866539628767027,
#    'Superior Incompleto': 0.09570894205660244,
#    'Superior Completo': 0.09456560095984191,
#    'Médio Incompleto': 0.07927870703648811,
#    'Fundamental Completo': 0.025675771049474203},
#   'POS_GRADUACOES': {True: 0.9987225633425083, False: 0.0012774366574917072},
#   'IDIOMAS': {nan: 0.9561789822852707,
#    'Inglês Básico': 0.0212153292398899,
#    'Inglês Intermediário': 0.007389371162396781,
#    'Espanhol Básico': 0.0032394664408215115,
#    'Inglês Básico|Espanhol Básico': 0.003070082574634766},
#   'HABILITACAO': {'Nenhum': 0.8104806267203049,
#    'AB': 0.10263250758698567,
#    'B': 0.07510762933163949,
#    'AD': 0.003578234173195003,
#    'A': 0.0033029853906415413},
#   'VEICULOS': {'N': 0.9708518596936975, 'S': 0.02914814030630249},
#   'DISP_VIAJAR': {'N': 0.8711059354929777, 'S': 0.12889406450702237},
#   'DISP_DORMIR_EMP': {'N': 0.8957230573787847, 'S': 0.10427694262121533},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.8968805137977275, 'S': 0.10311948620227257}},
#  'Auxiliar administrativo': {'ESCOLARIDADE': {'Médio Completo': 0.6086949724862432,
#    'Médio Incompleto': 0.18794553526763383,
#    'Superior Incompleto': 0.10844484742371185,
#    'Superior Completo': 0.05620779139569785,
#    'Fundamental Incompleto': 0.021596735867933967},
#   'POS_GRADUACOES': {True: 0.998546148074037, False: 0.0014538519259629816},
#   'IDIOMAS': {nan: 0.9017242996498249,
#    'Inglês Básico': 0.044881815907953974,
#    'Inglês Intermediário': 0.017422773886943473,
#    'Inglês Básico|Espanhol Básico': 0.006159329664832416,
#    'Espanhol Básico': 0.00587012256128064},
#   'HABILITACAO': {'Nenhum': 0.856998811905953,
#    'AB': 0.06869841170585293,
#    'B': 0.06389913706853427,
#    'A': 0.0028217233616808406,
#    'AD': 0.0026575787893946975},
#   'VEICULOS': {'N': 0.9694925587793897, 'S': 0.030507441220610304},
#   'DISP_VIAJAR': {'N': 0.8057153576788394, 'S': 0.19428464232116058},
#   'DISP_DORMIR_EMP': {'N': 0.832181715857929, 'S': 0.16781828414207103},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.8321660830415207, 'S': 0.16783391695847924}},
#  'Vendedor de comércio varejista': {'ESCOLARIDADE': {'Médio Completo': 0.7596760203483601,
#    'Médio Incompleto': 0.07179360948965,
#    'Fundamental Completo': 0.050519258269451674,
#    'Superior Completo': 0.04584241742269733,
#    'Superior Incompleto': 0.04470544107649389},
#   'POS_GRADUACOES': {True: 0.9996131936141782, False: 0.0003868063858217877},
#   'IDIOMAS': {nan: 0.9941392971845183,
#    'Inglês Básico': 0.0025435450219190286,
#    'Inglês Intermediário': 0.0010080408842628409,
#    'Espanhol Básico': 0.0004805776308694939,
#    'Inglês Básico|Espanhol Básico': 0.00041024919708371427},
#   'HABILITACAO': {'Nenhum': 0.8414914316524837,
#    'AB': 0.09298591087043158,
#    'B': 0.04728415031530581,
#    'AD': 0.006493658719553649,
#    'D': 0.003106172492205265},
#   'VEICULOS': {'N': 0.9853834071781888, 'S': 0.014616592821811191},
#   'DISP_VIAJAR': {'N': 0.9336802869400098, 'S': 0.06631971305999015},
#   'DISP_DORMIR_EMP': {'N': 0.9426706050589587, 'S': 0.05732939494104133},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.944815622289425, 'S': 0.05518437771057505}},
#  'Assistente administrativo': {'ESCOLARIDADE': {'Médio Completo': 0.617151087739323,
#    'Superior Completo': 0.1962822551057845,
#    'Superior Incompleto': 0.11730735260147025,
#    'Médio Incompleto': 0.04062886415827592,
#    'Fundamental Completo': 0.01695813460519343},
#   'POS_GRADUACOES': {True: 0.9967252320193497, False: 0.0032747679806503335},
#   'IDIOMAS': {nan: 0.9602136072724308,
#    'Inglês Básico': 0.01828978299566535,
#    'Inglês Intermediário': 0.007188183658771894,
#    'Inglês Básico|Espanhol Básico': 0.0027855910208851387,
#    'Inglês Avançado': 0.0022420610655904775},
#   'HABILITACAO': {'Nenhum': 0.7965159729865612,
#    'B': 0.10106939518704225,
#    'AB': 0.08763061704238174,
#    'AD': 0.0049732990909461495,
#    'D': 0.0028399440164146045},
#   'VEICULOS': {'N': 0.9771038006332124, 'S': 0.022896199366787603},
#   'DISP_VIAJAR': {'N': 0.8981288981288982, 'S': 0.10187110187110188},
#   'DISP_DORMIR_EMP': {'N': 0.9169350345820934, 'S': 0.08306496541790659},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.916364328129034, 'S': 0.08363567187096599}},
#  'Controlador de entrada e saída': {'ESCOLARIDADE': {'Médio Completo': 0.6794416730621642,
#    'Médio Incompleto': 0.11521488871834229,
#    'Fundamental Completo': 0.09572460987464824,
#    'Fundamental Incompleto': 0.05030058838577641,
#    'Superior Incompleto': 0.02441481197237145},
#   'POS_GRADUACOES': {True: 0.9995203376822717, False: 0.00047966231772831924},
#   'IDIOMAS': {nan: 0.9603798925556408,
#    'Inglês Básico': 0.016372473778459965,
#    'Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado': 0.00665131747249936,
#    'Espanhol Básico': 0.003037861345612689,
#    'Inglês Intermediário': 0.0027340752110514197},
#   'HABILITACAO': {'Nenhum': 0.7196373752877974,
#    'AB': 0.1126726784343822,
#    'B': 0.10683678690202097,
#    'D': 0.01846699923254029,
#    'AD': 0.01776349449987209},
#   'VEICULOS': {'N': 0.9484043233563572, 'S': 0.051595676643642875},
#   'DISP_VIAJAR': {'N': 0.7057911230493732, 'S': 0.29420887695062675},
#   'DISP_DORMIR_EMP': {'N': 0.728671015605014, 'S': 0.27132898439498593},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.7383442056792019, 'S': 0.26165579432079816}},
#  'Faxineiro': {'ESCOLARIDADE': {'Médio Completo': 0.4400152111371978,
#    'Fundamental Completo': 0.19767864819285078,
#    'Não Identificado': 0.17782150061175225,
#    'Médio Incompleto': 0.1197381038986806,
#    'Fundamental Incompleto': 0.04761747296716379},
#   'POS_GRADUACOES': {True: 1.0},
#   'IDIOMAS': {nan: 0.9981482093846104,
#    'Inglês Básico': 0.0006282861016500777,
#    'Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado': 0.00023147382692371285,
#    'Inglês Intermediário': 0.00019840613736318244,
#    'Espanhol Básico': 0.00016533844780265204},
#   'HABILITACAO': {'Nenhum': 0.9390231804503819,
#    'AB': 0.03153004199596574,
#    'B': 0.01979101220197745,
#    'AD': 0.0028934228365464104,
#    'D': 0.00244700902747925},
#   'VEICULOS': {'N': 0.9914189345590424, 'S': 0.00858106544095764},
#   'DISP_VIAJAR': {'N': 0.9256969015574882, 'S': 0.07430309844251182},
#   'DISP_DORMIR_EMP': {'N': 0.9350054561687775, 'S': 0.06499454383122251},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.9371713898349923, 'S': 0.06282861016500776}},
#  'Auxiliar de limpeza': {'ESCOLARIDADE': {'Médio Completo': 0.3810151945232927,
#    'Fundamental Incompleto': 0.20841542828518952,
#    'Fundamental Completo': 0.17942895308064785,
#    'Médio Incompleto': 0.14474870596092837,
#    'Não Identificado': 0.07233260978460511},
#   'POS_GRADUACOES': {True: 0.9997328435465019, False: 0.0002671564534980798},
#   'IDIOMAS': {nan: 0.987861078644181,
#    'Inglês Básico': 0.003038904658540658,
#    'Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado': 0.0021205543496410086,
#    'Francês Avançado': 0.0012189013190849892,
#    'Espanhol Básico': 0.0008515611955251294},
#   'HABILITACAO': {'Nenhum': 0.8910836533645016,
#    'AB': 0.045717148104858905,
#    'B': 0.03755217899482385,
#    'D': 0.007864418099849724,
#    'AD': 0.006962765069293705},
#   'VEICULOS': {'N': 0.9800801469360494, 'S': 0.019919853063950575},
#   'DISP_VIAJAR': {'N': 0.779963265987644, 'S': 0.220036734012356},
#   'DISP_DORMIR_EMP': {'N': 0.7996994489898147, 'S': 0.20030055101018535},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.8073634997495408, 'S': 0.19263650025045917}},
#  'nan': {'ESCOLARIDADE': {'Nenhum': 0.8192071966900719,
#    'Médio Completo': 0.06901406032721592,
#    'Superior Completo': 0.029459733214304108,
#    'Superior Incompleto': 0.02381156758055932,
#    'Médio Incompleto': 0.020000343353533966},
#   'POS_GRADUACOES': {True: 0.9941114868924789, False: 0.005888513107521159},
#   'IDIOMAS': {nan: 0.9725488849593984,
#    'Inglês Básico': 0.0052533090696835994,
#    'Inglês Intermediário': 0.00518463836289035,
#    'Inglês Avançado': 0.0033476969561709214,
#    'Inglês Intermediário|Espanhol Básico': 0.002094456557194115},
#   'HABILITACAO': {'Nenhum': 0.9824202990609281,
#    'B': 0.008412161582173085,
#    'AB': 0.007073082799704716,
#    'A': 0.0005493656543459973,
#    'AD': 0.00044635959415612286},
#   'VEICULOS': {'N': 0.9913303232673523, 'S': 0.00866967673264777},
#   'DISP_VIAJAR': {'S': 0.9453896204226682, 'N': 0.0546103795773318},
#   'DISP_DORMIR_EMP': {'S': 0.9423509416470669, 'N': 0.057649058352933095},
#   'DISP_AUSENTAR_DOMIC': {'S': 0.9421449295266872,
#    'N': 0.057837902796614535,
#    nan: 1.7167676698312416e-05}},
#  'Estoquista': {'ESCOLARIDADE': {'Médio Completo': 0.6641611545399879,
#    'Médio Incompleto': 0.18296133847405469,
#    'Fundamental Completo': 0.06059212620706731,
#    'Fundamental Incompleto': 0.04670864136394185,
#    'Superior Incompleto': 0.023009444306886916},
#   'POS_GRADUACOES': {True: 0.9997523964486577, False: 0.000247603551342365},
#   'IDIOMAS': {nan: 0.9603480598493156,
#    'Inglês Básico': 0.017792083760744225,
#    'Inglês Intermediário': 0.0041385165010081005,
#    'Espanhol Básico': 0.003307276007215875,
#    'Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado': 0.003006614552014432},
#   'HABILITACAO': {'Nenhum': 0.8299494181316543,
#    'AB': 0.0843974390718404,
#    'B': 0.05937179441830851,
#    'AD': 0.007711082027519366,
#    'A': 0.007357362668458845},
#   'VEICULOS': {'N': 0.9725513777369036, 'S': 0.02744862226309646},
#   'DISP_VIAJAR': {'N': 0.7611863747302889, 'S': 0.238813625269711},
#   'DISP_DORMIR_EMP': {'N': 0.7828339995047929, 'S': 0.2171660004952071},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.791040288634997, 'S': 0.20895971136500302}}}

# %%
for key, value in top_outras_caracteristicas.items():
    print('Ocupação:', key)
    for k, v in top_outras_caracteristicas[key].items():
        print('\n')
        print('Característica:', k)
        print('Distribuição percentual:\n')
        print(v)
# Out:
# Ocupação: Operador de caixa
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# Médio Completo          0.784988
# Médio Incompleto        0.103266
# Fundamental Completo    0.042228
# Superior Incompleto     0.032614
# Superior Completo       0.015239
# Name: ESCOLARIDADE, dtype: float64
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# True     0.999694
# False    0.000306
# Name: POS_GRADUACOES, dtype: float64
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# NaN                                                                                     0.970031
# Inglês Básico                                                                           0.014529
# Espanhol Básico                                                                         0.002938
# Inglês Intermediário                                                                    0.002778
# Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado    0.002757
# Name: IDIOMAS, dtype: float64
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# Nenhum    0.871596
# AB        0.070304
# B         0.047951
# A         0.004796
# AD        0.002019
# Name: HABILITACAO, dtype: float64
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# N    0.975691
# S    0.024309
# Name: VEICULOS, dtype: float64
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# N    0.829757
# S    0.170243
# Name: DISP_VIAJAR, dtype: float64
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# N    0.857179
# S    0.142821
# Name: DISP_DORMIR_EMP, dtype: float64
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# N    0.859796
# S    0.140204
# Name: DISP_AUSENTAR_DOMIC, dtype: float64
# Ocupação: Auxiliar de escritório
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# Médio Completo          0.686654
# Superior Incompleto     0.095709
# Superior Completo       0.094566
# Médio Incompleto        0.079279
# Fundamental Completo    0.025676
# Name: ESCOLARIDADE, dtype: float64
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# True     0.998723
# False    0.001277
# Name: POS_GRADUACOES, dtype: float64
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# NaN                              0.956179
# Inglês Básico                    0.021215
# Inglês Intermediário             0.007389
# Espanhol Básico                  0.003239
# Inglês Básico|Espanhol Básico    0.003070
# Name: IDIOMAS, dtype: float64
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# Nenhum    0.810481
# AB        0.102633
# B         0.075108
# AD        0.003578
# A         0.003303
# Name: HABILITACAO, dtype: float64
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# N    0.970852
# S    0.029148
# Name: VEICULOS, dtype: float64
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# N    0.871106
# S    0.128894
# Name: DISP_VIAJAR, dtype: float64
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# N    0.895723
# S    0.104277
# Name: DISP_DORMIR_EMP, dtype: float64
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# N    0.896881
# S    0.103119
# Name: DISP_AUSENTAR_DOMIC, dtype: float64
# Ocupação: Auxiliar administrativo
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# Médio Completo            0.608695
# Médio Incompleto          0.187946
# Superior Incompleto       0.108445
# Superior Completo         0.056208
# Fundamental Incompleto    0.021597
# Name: ESCOLARIDADE, dtype: float64
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# True     0.998546
# False    0.001454
# Name: POS_GRADUACOES, dtype: float64
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# NaN                              0.901724
# Inglês Básico                    0.044882
# Inglês Intermediário             0.017423
# Inglês Básico|Espanhol Básico    0.006159
# Espanhol Básico                  0.005870
# Name: IDIOMAS, dtype: float64
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# Nenhum    0.856999
# AB        0.068698
# B         0.063899
# A         0.002822
# AD        0.002658
# Name: HABILITACAO, dtype: float64
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# N    0.969493
# S    0.030507
# Name: VEICULOS, dtype: float64
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# N    0.805715
# S    0.194285
# Name: DISP_VIAJAR, dtype: float64
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# N    0.832182
# S    0.167818
# Name: DISP_DORMIR_EMP, dtype: float64
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# N    0.832166
# S    0.167834
# Name: DISP_AUSENTAR_DOMIC, dtype: float64
# Ocupação: Vendedor de comércio varejista
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# Médio Completo          0.759676
# Médio Incompleto        0.071794
# Fundamental Completo    0.050519
# Superior Completo       0.045842
# Superior Incompleto     0.044705
# Name: ESCOLARIDADE, dtype: float64
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# True     0.999613
# False    0.000387
# Name: POS_GRADUACOES, dtype: float64
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# NaN                              0.994139
# Inglês Básico                    0.002544
# Inglês Intermediário             0.001008
# Espanhol Básico                  0.000481
# Inglês Básico|Espanhol Básico    0.000410
# Name: IDIOMAS, dtype: float64
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# Nenhum    0.841491
# AB        0.092986
# B         0.047284
# AD        0.006494
# D         0.003106
# Name: HABILITACAO, dtype: float64
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# N    0.985383
# S    0.014617
# Name: VEICULOS, dtype: float64
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# N    0.93368
# S    0.06632
# Name: DISP_VIAJAR, dtype: float64
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# N    0.942671
# S    0.057329
# Name: DISP_DORMIR_EMP, dtype: float64
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# N    0.944816
# S    0.055184
# Name: DISP_AUSENTAR_DOMIC, dtype: float64
# Ocupação: Assistente administrativo
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# Médio Completo          0.617151
# Superior Completo       0.196282
# Superior Incompleto     0.117307
# Médio Incompleto        0.040629
# Fundamental Completo    0.016958
# Name: ESCOLARIDADE, dtype: float64
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# True     0.996725
# False    0.003275
# Name: POS_GRADUACOES, dtype: float64
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# NaN                              0.960214
# Inglês Básico                    0.018290
# Inglês Intermediário             0.007188
# Inglês Básico|Espanhol Básico    0.002786
# Inglês Avançado                  0.002242
# Name: IDIOMAS, dtype: float64
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# Nenhum    0.796516
# B         0.101069
# AB        0.087631
# AD        0.004973
# D         0.002840
# Name: HABILITACAO, dtype: float64
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# N    0.977104
# S    0.022896
# Name: VEICULOS, dtype: float64
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# N    0.898129
# S    0.101871
# Name: DISP_VIAJAR, dtype: float64
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# N    0.916935
# S    0.083065
# Name: DISP_DORMIR_EMP, dtype: float64
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# N    0.916364
# S    0.083636
# Name: DISP_AUSENTAR_DOMIC, dtype: float64
# Ocupação: Controlador de entrada e saída
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# Médio Completo            0.679442
# Médio Incompleto          0.115215
# Fundamental Completo      0.095725
# Fundamental Incompleto    0.050301
# Superior Incompleto       0.024415
# Name: ESCOLARIDADE, dtype: float64
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# True     0.99952
# False    0.00048
# Name: POS_GRADUACOES, dtype: float64
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# NaN                                                                                     0.960380
# Inglês Básico                                                                           0.016372
# Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado    0.006651
# Espanhol Básico                                                                         0.003038
# Inglês Intermediário                                                                    0.002734
# Name: IDIOMAS, dtype: float64
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# Nenhum    0.719637
# AB        0.112673
# B         0.106837
# D         0.018467
# AD        0.017763
# Name: HABILITACAO, dtype: float64
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# N    0.948404
# S    0.051596
# Name: VEICULOS, dtype: float64
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# N    0.705791
# S    0.294209
# Name: DISP_VIAJAR, dtype: float64
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# N    0.728671
# S    0.271329
# Name: DISP_DORMIR_EMP, dtype: float64
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# N    0.738344
# S    0.261656
# Name: DISP_AUSENTAR_DOMIC, dtype: float64
# Ocupação: Faxineiro
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# Médio Completo            0.440015
# Fundamental Completo      0.197679
# Não Identificado          0.177822
# Médio Incompleto          0.119738
# Fundamental Incompleto    0.047617
# Name: ESCOLARIDADE, dtype: float64
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# True    1.0
# Name: POS_GRADUACOES, dtype: float64
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# NaN                                                                                     0.998148
# Inglês Básico                                                                           0.000628
# Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado    0.000231
# Inglês Intermediário                                                                    0.000198
# Espanhol Básico                                                                         0.000165
# Name: IDIOMAS, dtype: float64
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# Nenhum    0.939023
# AB        0.031530
# B         0.019791
# AD        0.002893
# D         0.002447
# Name: HABILITACAO, dtype: float64
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# N    0.991419
# S    0.008581
# Name: VEICULOS, dtype: float64
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# N    0.925697
# S    0.074303
# Name: DISP_VIAJAR, dtype: float64
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# N    0.935005
# S    0.064995
# Name: DISP_DORMIR_EMP, dtype: float64
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# N    0.937171
# S    0.062829
# Name: DISP_AUSENTAR_DOMIC, dtype: float64
# Ocupação: Auxiliar de limpeza
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# Médio Completo            0.381015
# Fundamental Incompleto    0.208415
# Fundamental Completo      0.179429
# Médio Incompleto          0.144749
# Não Identificado          0.072333
# Name: ESCOLARIDADE, dtype: float64
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# True     0.999733
# False    0.000267
# Name: POS_GRADUACOES, dtype: float64
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# NaN                                                                                     0.987861
# Inglês Básico                                                                           0.003039
# Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado    0.002121
# Francês Avançado                                                                        0.001219
# Espanhol Básico                                                                         0.000852
# Name: IDIOMAS, dtype: float64
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# Nenhum    0.891084
# AB        0.045717
# B         0.037552
# D         0.007864
# AD        0.006963
# Name: HABILITACAO, dtype: float64
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# N    0.98008
# S    0.01992
# Name: VEICULOS, dtype: float64
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# N    0.779963
# S    0.220037
# Name: DISP_VIAJAR, dtype: float64
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# N    0.799699
# S    0.200301
# Name: DISP_DORMIR_EMP, dtype: float64
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# N    0.807363
# S    0.192637
# Name: DISP_AUSENTAR_DOMIC, dtype: float64
# Ocupação: nan
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# Nenhum                 0.819207
# Médio Completo         0.069014
# Superior Completo      0.029460
# Superior Incompleto    0.023812
# Médio Incompleto       0.020000
# Name: ESCOLARIDADE, dtype: float64
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# True     0.994111
# False    0.005889
# Name: POS_GRADUACOES, dtype: float64
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# NaN                                     0.972549
# Inglês Básico                           0.005253
# Inglês Intermediário                    0.005185
# Inglês Avançado                         0.003348
# Inglês Intermediário|Espanhol Básico    0.002094
# Name: IDIOMAS, dtype: float64
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# Nenhum    0.982420
# B         0.008412
# AB        0.007073
# A         0.000549
# AD        0.000446
# Name: HABILITACAO, dtype: float64
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# N    0.99133
# S    0.00867
# Name: VEICULOS, dtype: float64
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# S    0.94539
# N    0.05461
# Name: DISP_VIAJAR, dtype: float64
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# S    0.942351
# N    0.057649
# Name: DISP_DORMIR_EMP, dtype: float64
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# S      0.942145
# N      0.057838
# NaN    0.000017
# Name: DISP_AUSENTAR_DOMIC, dtype: float64
# Ocupação: Estoquista
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# Médio Completo            0.664161
# Médio Incompleto          0.182961
# Fundamental Completo      0.060592
# Fundamental Incompleto    0.046709
# Superior Incompleto       0.023009
# Name: ESCOLARIDADE, dtype: float64
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# True     0.999752
# False    0.000248
# Name: POS_GRADUACOES, dtype: float64
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# NaN                                                                                     0.960348
# Inglês Básico                                                                           0.017792
# Inglês Intermediário                                                                    0.004139
# Espanhol Básico                                                                         0.003307
# Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado    0.003007
# Name: IDIOMAS, dtype: float64
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# Nenhum    0.829949
# AB        0.084397
# B         0.059372
# AD        0.007711
# A         0.007357
# Name: HABILITACAO, dtype: float64
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# N    0.972551
# S    0.027449
# Name: VEICULOS, dtype: float64
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# N    0.761186
# S    0.238814
# Name: DISP_VIAJAR, dtype: float64
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# N    0.782834
# S    0.217166
# Name: DISP_DORMIR_EMP, dtype: float64
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# N    0.79104
# S    0.20896
# Name: DISP_AUSENTAR_DOMIC, dtype: float64

# %% [markdown]
# # Lendo e salvando todos os arquivos de vagas em um único dataframe

# %%
path = r'SINE/Vagas' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in tqdm(all_files):
    df = pd.read_csv(filename, sep=";", encoding='iso-8859-1', usecols = list(range(12)))
    li.append(df)

vagas = pd.concat(li, axis=0, ignore_index=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 92.71it/s]

# %% [markdown]
# # Eliminando todos os registros que possuem o campo OBSERVACOES_OCUPACAO nulo.

# %%
vagas_com_observacoes = vagas[vagas.OBSERVACOES_OCUPACAO.notnull()]

# %%
vagas_com_observacoes.shape
# Out:
# (1759, 12)

# %% [markdown]
# # Criando o corpus apenas para vagas da principal ocupação

# %%
todas_as_vagas = list(vagas_com_observacoes.TITULO_OCUPACAO.value_counts().index)

# %%
top_exigencias = {}

# %%
for job in todas_as_vagas:
    corpus_vagas = vagas_com_observacoes.loc[vagas_com_observacoes.TITULO_OCUPACAO == job,'OBSERVACOES_OCUPACAO'].copy()
    corpus_vagas = preprocess_corpus(corpus_vagas)
    try:
        top_exigencias[job] = get_top_n_words(corpus_vagas)
    except:
        top_exigencias[job] = 'Não existe vaga para essa ocupação.'
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 111/111 [00:00<00:00, 897.56it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 49/49 [00:00<00:00, 733.30it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 813.47it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 771.26it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 38/38 [00:00<00:00, 705.63it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 779.84it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 1160.89it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 441.19it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 646.90it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 572.97it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 656.91it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 429.71it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 546.90it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 392.35it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 473.48it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 501.33it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 1002.81it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 561.67it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 638.15it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 814.61it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 482.80it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 931.06it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 501.37it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 707.70it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 648.76it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 1002.68it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 355.79it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 919.09it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 626.67it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 835.54it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 716.23it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 601.65it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 564.07it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 1288.88it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 891.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 802.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1002.19it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 802.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 637.96it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 702.11it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 467.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 539.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 780.02it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 779.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 701.91it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 601.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 859.20it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 751.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 546.77it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 859.11it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 752.03it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 601.55it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 601.56it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 668.56it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 668.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 546.86it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 668.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 859.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 859.28it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 751.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 501.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 455.81it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 626.48it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 716.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 716.14it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1671.30it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 626.67it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 455.83it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 385.63it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 557.01it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 835.75it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1002.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 626.73it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1003.13it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1002.56it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 716.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1336.19it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 668.55it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 668.10it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1336.62it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1336.83it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 668.52it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 572.93it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 501.28it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1337.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 802.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1338.11it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1003.24it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1337.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 572.91it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 802.32it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 668.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1336.40it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 801.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 572.95it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.54it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 601.68it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 601.54it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 375.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 752.43it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1003.02it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.67it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 601.85it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1003.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 601.68it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1503.51it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 752.16it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.86it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 601.74it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1505.13it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1502.80it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 501.37it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1503.87it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 429.83it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 752.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 601.59it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 752.03it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 601.54it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 752.34it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 376.04it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1003.74it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 752.48it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 752.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.80it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1003.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1503.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 334.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 601.88it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 752.43it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 429.80it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 602.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1003.50it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1003.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 752.57it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1504.77it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.85it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1504.77it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1505.49it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.04it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.84it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.14it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2007.32it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1004.02it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.53it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.79it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.15it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.73it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2009.25it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.20it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.32it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.06it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.95it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.20it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1004.14it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.02it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 334.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.68it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1004.62it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.58it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.14it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.73it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.63it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2006.84it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.14it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.36it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.44it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.12it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.04it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.52it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.04it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.42it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.26it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1006.07it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2005.40it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.54it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.23it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.32it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.50it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 250.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.04it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 333.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.15it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.42it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 400.83it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.95it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.89it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.20it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.52it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.08it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.10it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2003.49it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.04it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.20it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.75it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.50it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.77it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.95it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1000.79it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.03it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.71it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 999.83it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.04it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 999.83it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 200.49it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.65it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 502.19it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.83it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.11it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.11it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1000.79it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.93it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 999.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.71it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.48it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.71it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.71it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.27it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.83it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.11it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.93it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.77it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.27it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.65it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1006.79it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.55it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.99it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.68it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.68it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.99it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.27it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.11it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.81it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.89it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.87it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.99it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.27it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.07it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.14it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.89it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.62it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.51it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.02it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.93it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.07it/s]
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.71it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.11it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.37it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.99it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 200.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.38it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.81it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.83it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.68it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.74it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1005.11it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.03it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.03it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1006.79it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 502.73it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 333.49it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 502.79it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1005.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.87it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.21it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.51it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 502.37it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.65it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.99it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.81it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.02it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.75it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1000.07it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.05it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.77it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1005.11it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.18it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.23it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.99it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.27it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.21it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1000.79it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.53it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 333.84it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.89it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1000.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.75it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.23it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1000.79it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.77it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.87it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.77it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 502.19it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 333.91it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.11it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.93it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.95it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 502.19it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 502.07it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.27it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]

# %%
top_exigencias
# Out:
# {'Operador de caixa': [('fechamento caixa', 5),
#   ('ensino medio', 4),
#   ('recebimento valores', 3),
#   ('atendimento cliente', 3),
#   ('abertura fechamento', 3),
#   ('disponibilidade horarios', 3),
#   ('valores fechamento', 2),
#   ('caixa emissao', 2),
#   ('emissao notas', 2),
#   ('notas fiscais', 2)],
#  'Auxiliar de escritório': [('trabalho ser', 1),
#   ('ser executado', 1),
#   ('executado preparacao', 1),
#   ('preparacao documentos', 1),
#   ('documentos digitalizacao', 1),
#   ('digitalizacao geracao', 1),
#   ('geracao imagens', 1),
#   ('11 auxiliar', 1),
#   ('auxiliar atividades', 1),
#   ('atividades escritorio', 1)],
#  'Auxiliar administrativo': [('medio completo', 7),
#   ('ensino medio', 6),
#   ('auxiliar administrativo', 5),
#   ('pacote office', 5),
#   ('rotinas administrativas', 4),
#   ('enviar curriculo', 4),
#   ('segunda sexta', 4),
#   ('vaga exclusiva', 3),
#   ('exclusiva pcd', 3),
#   ('horario trabalho', 3)],
#  'Vendedor de comércio varejista': [('vendedor loja', 1),
#   ('loja material', 1),
#   ('material construcao', 1)],
#  'Assistente administrativo': [('ensino medio', 5),
#   ('planilhas excel', 3),
#   ('medio completo', 3),
#   ('enviar curriculo', 3),
#   ('vaga exclusiva', 2),
#   ('exclusiva pcd', 2),
#   ('contas pagar', 2),
#   ('ind trabalhador', 2),
#   ('trabalhador fazer', 2),
#   ('notas fiscais', 2)],
#  'Controlador de entrada e saída': '',
#  'Faxineiro': [('trabalhador responsavel', 1),
#   ('responsavel area', 1),
#   ('area limpeza', 1),
#   ('limpeza interna', 1),
#   ('interna externa', 1),
#   ('externa empresa', 1),
#   ('empresa tera', 1),
#   ('tera disponibilizado', 1),
#   ('disponibilizado transporte', 1),
#   ('transporte local', 1)],
#  'Auxiliar de limpeza': [('vaga exclusiva', 6),
#   ('exclusiva pcd', 5),
#   ('ensino fundamental', 5),
#   ('fundamental completo', 5),
#   ('limpeza conservacao', 4),
#   ('vaga trabalhar', 4),
#   ('fazer limpeza', 3),
#   ('conservacao geral', 3),
#   ('limpeza higienizacao', 3),
#   ('limpeza escritorio', 3)],
#  'nan': '',
#  'Estoquista': [('controle estoque', 2),
#   ('trabalhar entrada', 1),
#   ('entrada saida', 1),
#   ('saida mercadorias', 1),
#   ('mercadorias organizacao', 1),
#   ('organizacao geral', 1),
#   ('geral empresa', 1),
#   ('empresa equipamentos', 1),
#   ('equipamentos agricultura', 1),
#   ('agricultura pecuaria', 1)],
#  'Auxiliar de linha de produção': [('vaga exclusiva', 15),
#   ('linha producao', 15),
#   ('pessoa deficiencia', 12),
#   ('auxiliar producao', 10),
#   ('linhas producao', 8),
#   ('disponibilidade trabalhar', 8),
#   ('exclusiva pcd', 7),
#   ('segunda sexta', 7),
#   ('area servico', 6),
#   ('segunda sabado', 6)],
#  'Vendedor pracista': [('experiencia vendas', 16),
#   ('ensino medio', 11),
#   ('medio completo', 11),
#   ('ter experiencia', 10),
#   ('necessario ter', 6),
#   ('vendas externas', 6),
#   ('cnh ab', 6),
#   ('segunda sexta', 5),
#   ('realizar vendas', 5),
#   ('horario comercial', 4)],
#  'Vendedor interno': [('ensino medio', 9),
#   ('medio completo', 9),
#   ('materiais construcao', 7),
#   ('experiencia vendas', 7),
#   ('segunda sexta', 5),
#   ('horario comercial', 5),
#   ('vaga trabalhar', 4),
#   ('ter experiencia', 4),
#   ('completo experiencia', 4),
#   ('cnh ab', 3)],
#  'Empregado  doméstico  nos serviços gerais': [('lavar passar', 8),
#   ('ter experiencia', 7),
#   ('segunda sexta', 6),
#   ('fazer todo', 4),
#   ('passar roupas', 4),
#   ('experiencia comprovada', 4),
#   ('casa lavar', 3),
#   ('preparar refeicoes', 3),
#   ('experiencia referencias', 3),
#   ('ter referencias', 3)],
#  'Pedreiro': [('executar trabalhos', 4),
#   ('outros materiais', 4),
#   ('processos instrumentos', 4),
#   ('instrumentos pertinentes', 4),
#   ('pertinentes oficio', 4),
#   ('servicos pedreiro', 3),
#   ('materiais guiando', 3),
#   ('guiando se', 3),
#   ('trabalhos alvenaria', 3),
#   ('alvenaria concreto', 3)],
#  'Consultor de vendas': [('ensino medio', 5),
#   ('medio completo', 4),
#   ('vendas externas', 4),
#   ('cnh disponibilidade', 3),
#   ('experiencia vendas', 3),
#   ('realizar vendas', 3),
#   ('ambos sexos', 3),
#   ('encaminhar candidatos', 2),
#   ('candidatos ensino', 2),
#   ('completo experiencias', 2)],
#  'Soldador': [('ter experiencia', 5),
#   ('solda mig', 3),
#   ('candidato deve', 2),
#   ('servicos solda', 2),
#   ('mig tig', 2),
#   ('maquinas agricolas', 2),
#   ('agricolas industria', 2),
#   ('industria madeireira', 2),
#   ('pecas serem', 2),
#   ('eletrodo revestido', 2)],
#  'Servente de obras': [('ensino fundamental', 4),
#   ('fundamental completo', 3),
#   ('completo ter', 3),
#   ('ter experiencia', 3),
#   ('experiencia 06', 3),
#   ('06 meses', 3),
#   ('meses obra', 3),
#   ('obra porem', 3),
#   ('porem nao', 3),
#   ('nao sao', 3)],
#  'Motorista de caminhão': [('experiencia comprovada', 6),
#   ('comprovada carteira', 4),
#   ('motorista caminhao', 3),
#   ('ter cnh', 3),
#   ('carteira trabalho', 3),
#   ('necessario ter', 3),
#   ('imprimir carta', 2),
#   ('ira realizar', 2),
#   ('dirigir caminhao', 2),
#   ('fundamental completo', 2)],
#  'Empacotador, a mão': [('exclusiva pcd', 12),
#   ('vaga exclusiva', 11),
#   ('pcd programa', 7),
#   ('programa apoio', 6),
#   ('pessoa deficiencia', 6),
#   ('deficiencia ppd', 6),
#   ('embalar mercadorias', 6),
#   ('apoio pessoa', 5),
#   ('ppd ira', 5),
#   ('mercadorias compradas', 5)],
#  'Técnico de enfermagem': [('tecnico enfermagem', 6),
#   ('disponibilidade horario', 4),
#   ('curso tecnico', 4),
#   ('horario trabalho', 3),
#   ('outras atribuicoes', 2),
#   ('atribuicoes funcao', 2),
#   ('curativos outras', 2),
#   ('seguranca trabalho', 2),
#   ('segunda sexta', 2),
#   ('vaga exclusiva', 2)],
#  'Auxiliar de cozinha': [('pre preparo', 3),
#   ('disponibilidade trabalhar', 3),
#   ('preparo alimentos', 2),
#   ('auxilia preparo', 2),
#   ('generos alimenticios', 2),
#   ('limpeza dependencias', 2),
#   ('trabalhar finais', 2),
#   ('finais semana', 2),
#   ('cozinheira preparar', 2),
#   ('ter experiencia', 2)],
#  'Repositor de mercadorias': [('vaga exclusiva', 6),
#   ('exclusiva pcd', 4),
#   ('reposicao mercadorias', 3),
#   ('enviar curriculo', 3),
#   ('pessoa deficiencia', 2),
#   ('veiculo proprio', 2),
#   ('fazer reposicao', 2),
#   ('ensino medio', 2),
#   ('pessoas deficiencia', 2),
#   ('mercadorias gondolas', 2)],
#  'Técnico em segurança do trabalho': [('seguranca trabalho', 3),
#   ('ter experiencia', 2),
#   ('experiencia comprovada', 2),
#   ('trabalhador fara', 2),
#   ('atividades inerentes', 2),
#   ('inerentes funcao', 2),
#   ('construcao civil', 2),
#   ('curso tecnico', 2),
#   ('vagas moradores', 1),
#   ('moradores itapemirim', 1)],
#  'Torneiro mecânico': [('experiencia comprovada', 4),
#   ('vaga trabalhar', 3),
#   ('segunda sexta', 3),
#   ('fazenda rio', 3),
#   ('rio grande', 3),
#   ('horario comercial', 2),
#   ('ter experiencia', 2),
#   ('cnh ab', 2),
#   ('horario trabalho', 2),
#   ('sexta feira', 2)],
#  'Motorista entregador': [('ter cnh', 4),
#   ('ensino medio', 3),
#   ('entrega clientes', 3),
#   ('cnh ab', 3),
#   ('deve ter', 2),
#   ('ter experiencia', 2),
#   ('curso mopp', 2),
#   ('cnh categoria', 2),
#   ('carga descarga', 2),
#   ('dirige carrega', 1)],
#  'Caseiro': [('vaga casal', 3),
#   ('fazer todos', 1),
#   ('todos servicos', 1),
#   ('servicos gerais', 1),
#   ('gerais fazenda', 1),
#   ('fazenda toda', 1),
#   ('toda limpeza', 1),
#   ('vaga permanente', 1),
#   ('permanente caseiro', 1),
#   ('caseiro necessario', 1)],
#  'Mecânico de manutenção de máquina industrial': [('experiencia comprovada',
#    3),
#   ('ensino medio', 2),
#   ('medio completo', 2),
#   ('manutencao maquinas', 2),
#   ('maquinas industriais', 2),
#   ('experiencia comprovacao', 1),
#   ('comprovacao carteira', 1),
#   ('carteira ensino', 1),
#   ('ensino fundamental', 1),
#   ('fundamental disponibilidade', 1)],
#  'Açougueiro': [('preparar carnes', 2),
#   ('carnes comercializacao', 2),
#   ('trabalhar conformidade', 2),
#   ('conformidade normas', 2),
#   ('normas procedimentos', 2),
#   ('procedimentos tecnicos', 2),
#   ('tecnicos qualidade', 2),
#   ('qualidade seguranca', 2),
#   ('preservacao ambiental', 2),
#   ('expediente seg', 2)],
#  'Marceneiro': [('fabricacao moveis', 5),
#   ('moveis sob', 3),
#   ('sob medida', 3),
#   ('ter experiencia', 2),
#   ('segunda sexta', 2),
#   ('moveis planejados', 2),
#   ('atencao vaga', 1),
#   ('vaga exclusiva', 1),
#   ('exclusiva moradores', 1),
#   ('moradores igarape', 1)],
#  'Farmacêutico': [('superior completo', 4),
#   ('curso superior', 3),
#   ('completo farmacia', 3),
#   ('disponibilidade horario', 2),
#   ('ctps minimo', 2),
#   ('atendimento cliente', 2),
#   ('farmaceutico deve', 1),
#   ('deve supervisionar', 1),
#   ('supervisionar orientar', 1),
#   ('orientar processo', 1)],
#  'Oficial de serviços gerais na manutenção de edificações': [('disponibilidade horario',
#    3),
#   ('ter disponibilidade', 3),
#   ('ira realizar', 2),
#   ('realizar servicos', 2),
#   ('servicos limpeza', 2),
#   ('servicos gerais', 2),
#   ('trabalhar restaurante', 1),
#   ('restaurante atendendo', 1),
#   ('atendendo fazer', 1),
#   ('fazer limpeza', 1)],
#  'Trabalhador rural': [('servicos gerais', 4),
#   ('ter referencias', 3),
#   ('casal trabalhar', 2),
#   ('trabalhar propriedade', 2),
#   ('propriedade rural', 2),
#   ('referencias experiencia', 2),
#   ('pode ter', 2),
#   ('ter filhos', 2),
#   ('ter experiencia', 2),
#   ('vaga casal', 2)],
#  'Técnico em manutenção de equipamentos de informática': [('manutencao computadores',
#    3),
#   ('tecnico informatica', 2),
#   ('necessario ter', 2),
#   ('candidatos experiencia', 1),
#   ('experiencia programacao', 1),
#   ('programacao alteracao', 1),
#   ('alteracao loja', 1),
#   ('loja virtual', 1),
#   ('virtual codigofazer', 1),
#   ('codigofazer integracao', 1)],
#  'Zelador': [('necessario ter', 2),
#   ('experiencia funcao', 2),
#   ('pessoa experiencia', 2),
#   ('trabalhador fara', 2),
#   ('vaga trabalhar', 1),
#   ('trabalhar campos', 1),
#   ('campos julio', 1),
#   ('julio necessario', 1),
#   ('ter experiencia', 1),
#   ('efetuar limpeza', 1)],
#  'Cozinheiro geral': [('trabalhador experiencia', 3),
#   ('boas praticas', 2),
#   ('cozinha industrial', 2),
#   ('vaga casal', 2),
#   ('ter experiencia', 2),
#   ('residir cidade', 1),
#   ('cidade taua', 1),
#   ('taua conhecimento', 1),
#   ('conhecimento boas', 1),
#   ('praticas higiene', 1)],
#  'Auxiliar de logistica': [('vaga exclusiva', 3),
#   ('exclusiva pcd', 3),
#   ('carga descarga', 2),
#   ('ensino medio', 2),
#   ('medio completo', 2),
#   ('separar armazenar', 1),
#   ('armazenar organizar', 1),
#   ('organizar mercadorias', 1),
#   ('mercadorias demais', 1),
#   ('demais atividades', 1)],
#  'Operador de empilhadeira': [('vaga trabalhar', 3),
#   ('operar empilhadeira', 2),
#   ('operador empilhadeira', 2),
#   ('acompanhar plano', 1),
#   ('plano manutencao', 1),
#   ('manutencao acompanhar', 1),
#   ('acompanhar graficos', 1),
#   ('graficos sistema', 1),
#   ('sistema gestao', 1),
#   ('gestao atualizado', 1)],
#  'Ajudante de carga e descarga de mercadoria': [('carga descarga', 6),
#   ('vaga exclusiva', 4),
#   ('exclusiva pcd', 4),
#   ('pessoa deficiencia', 2),
#   ('enviar curriculo', 2),
#   ('deposito carga', 2),
#   ('candidatos vaga', 1),
#   ('pcd ensino', 1),
#   ('ensino fundamental', 1),
#   ('fundamental completo', 1)],
#  'Alimentador de linha de produção': [('ira realizar', 1),
#   ('realizar diversos', 1),
#   ('diversos servicos', 1),
#   ('servicos internos', 1),
#   ('ira trabalhar', 1),
#   ('trabalhar servicos', 1),
#   ('servicos diversos', 1),
#   ('diversos auxiliar', 1),
#   ('cortar limpar', 1),
#   ('limpar frango', 1)],
#  'Borracheiro': [('montagem desmontagem', 3),
#   ('desmontagem pneus', 2),
#   ('motorista borracheiro', 1),
#   ('sine municipal', 1),
#   ('municipal experiencia', 1),
#   ('experiencia consertos', 1),
#   ('consertos pneus', 1),
#   ('pneus carro', 1),
#   ('carro caminhao', 1),
#   ('caminhao etc', 1)],
#  'Motorista de caminhão-guincho pesado com munk': [('experiencia comprovada',
#    2),
#   ('gsst 100', 2),
#   ('operador munk', 2),
#   ('responsavel efetuar', 1),
#   ('efetuar servicos', 1),
#   ('servicos motorista', 1),
#   ('motorista operacao', 1),
#   ('operacao caminhao', 1),
#   ('caminhao munck', 1),
#   ('munck fazer', 1)],
#  'Operador de retro-escavadeira': [('retro escavadeira', 3),
#   ('experiencia comprovada', 2),
#   ('segunda sexta', 2),
#   ('operador bob', 1),
#   ('bob cat', 1),
#   ('operar equipamentos', 1),
#   ('equipamentos escavacao', 1),
#   ('escavacao carregamento', 1),
#   ('carregamento confeccionado', 1),
#   ('confeccionado valas', 1)],
#  'Costureira em geral': [('ter experiencia', 2),
#   ('diferencial ter', 1),
#   ('experiencia ramo', 1),
#   ('ramo colchoes', 1),
#   ('colchoes estofados', 1),
#   ('pessoa ira', 1),
#   ('ira confeccionar', 1),
#   ('confeccionar pecas', 1),
#   ('pecas inteiras', 1),
#   ('inteiras ajustes', 1)],
#  'Motorista carreteiro': [('disponibilidade viagens', 2),
#   ('obrigatorio ensino', 2),
#   ('experiencia ctps', 2),
#   ('ctps cnh', 2),
#   ('cnh trabalhar', 2),
#   ('trabalhar motorista', 2),
#   ('motorista coleta', 2),
#   ('coleta entrega', 2),
#   ('pcdtransporte carga', 1),
#   ('carga graos', 1)],
#  'Serralheiro': [('experiencia solda', 2),
#   ('experiencia comprovada', 2),
#   ('solda inox', 1),
#   ('confeccionam reparam', 1),
#   ('reparam instalam', 1),
#   ('instalam pecas', 1),
#   ('pecas elementos', 1),
#   ('elementos diversos', 1),
#   ('diversos chapas', 1),
#   ('chapas metal', 1)],
#  'Vigilante': [('entrada saida', 3),
#   ('saida pessoas', 3),
#   ('curso vigilante', 2),
#   ('vigilancia seguranca', 2),
#   ('curso formacao', 2),
#   ('formacao vigilante', 2),
#   ('escala 12x36', 2),
#   ('vaga exclusiva', 2),
#   ('controlar entrada', 2),
#   ('ensino medio', 2)],
#  'Representante comercial autônomo': [('veiculo proprio', 5),
#   ('experiencia vendas', 3),
#   ('ter veiculo', 3),
#   ('carteira habilitacao', 2),
#   ('horario comercial', 2),
#   ('ensino medio', 2),
#   ('realizar vendas', 1),
#   ('vendas cosmeticos', 1),
#   ('cosmeticos afins', 1),
#   ('afins necessario', 1)],
#  'Mecânico de automóvel': [('enviar curriculo', 2),
#   ('veiculos leves', 2),
#   ('injecao eletronica', 2),
#   ('trabalhador realizar', 2),
#   ('manutencao veiculos', 2),
#   ('mecanico automotivo', 1),
#   ('curriculo juliana', 1),
#   ('juliana cabralseteq', 1),
#   ('cabralseteq pe', 1),
#   ('pe gov', 1)],
#  'Motofretista': [('moto propria', 2),
#   ('realizar entrega', 1),
#   ('entrega moto', 1),
#   ('moto empresa', 1),
#   ('empresa durante', 1),
#   ('durante dia', 1),
#   ('dia conheca', 1),
#   ('conheca ruascom', 1),
#   ('ruascom experiencia', 1),
#   ('experiencia referencia', 1)],
#  'Analista de recursos humanos': [('superior completo', 3),
#   ('promovem acoes', 2),
#   ('departamento pessoal', 2),
#   ('assistente rh', 1),
#   ('assistente gerencia', 1),
#   ('gerencia presidencia', 1),
#   ('presidencia conhecimentos', 1),
#   ('conhecimentos ingles', 1),
#   ('ingles espanhol', 1),
#   ('espanhol ferramentas', 1)],
#  'Eletricista': [('instalacoes eletricas', 2),
#   ('trabalhador experiencia', 2),
#   ('equipamentos eletricos', 2),
#   ('atuar area', 1),
#   ('area manutencao', 1),
#   ('manutencao construcao', 1),
#   ('construcao prestar', 1),
#   ('prestar servicos', 1),
#   ('servicos diversos', 1),
#   ('diversos energisa', 1)],
#  'Ajudante de eletricista': [('horario comercial', 3),
#   ('trabalho horario', 1),
#   ('comercial nao', 1),
#   ('nao exige', 1),
#   ('exige experiencia', 1),
#   ('experiencia auxiliara', 1),
#   ('auxiliara parte', 1),
#   ('parte eletrica', 1),
#   ('eletrica obras', 1),
#   ('obras geral', 1)],
#  'Auxiliar de mecânico de autos': [('necessario ter', 2),
#   ('ensino medio', 2),
#   ('medio completo', 2),
#   ('experiencia mecanica', 2),
#   ('auxiliar manutencao', 1),
#   ('manutencao mecanica', 1),
#   ('mecanica caminhoes', 1),
#   ('caminhoes caminhonetes', 1),
#   ('nao necessario', 1),
#   ('ter experiencia', 1)],
#  'Mecânico de manutenção de máquinas agrícolas': [('necessario ter', 2),
#   ('experiencia comprovada', 2),
#   ('realizar manutencao', 1),
#   ('manutencao tratores', 1),
#   ('tratores necessario', 1),
#   ('ter curso', 1),
#   ('curso mecanica', 1),
#   ('trabalhar fazenda', 1),
#   ('formacao tecnica', 1),
#   ('tecnica completa', 1)],
#  'Eletricista de instalações de veículos automotores': [('trabalhador ira', 3),
#   ('exclusiva pcd', 2),
#   ('sistema eletrico', 2),
#   ('ira realizar', 2),
#   ('manutencao eletrica', 2),
#   ('expediente segunda', 2),
#   ('segunda sexta', 2),
#   ('pcd eletricista', 1),
#   ('eletricista manutencao', 1),
#   ('manutencao veiculos', 1)],
#  'Padeiro': [('experiencia comprovada', 3),
#   ('comprovada funcao', 2),
#   ('vaga permanente', 1),
#   ('permanente padeiro', 1),
#   ('padeiro nova', 1),
#   ('nova canaa', 1),
#   ('canaa norte', 1),
#   ('norte deve', 1),
#   ('deve ter', 1),
#   ('ter experiencia', 1)],
#  'Atendente de balcão': [('ter experiencia', 2),
#   ('vendas pecas', 2),
#   ('ira realizar', 1),
#   ('realizar atendimento', 1),
#   ('atendimento on', 1),
#   ('on line', 1),
#   ('line telefone', 1),
#   ('telefone necessario', 1),
#   ('necessario possuir', 1),
#   ('possuir boa', 1)],
#  'Vendedor de serviços': [('empresa contrata', 2),
#   ('contrata vendedor', 2),
#   ('vendedor externo', 2),
#   ('externo experiencia', 2),
#   ('experiencia trabalhar', 2),
#   ('contrato temporario', 2),
#   ('temporario possibilidade', 2),
#   ('possibilidade renovacao', 2),
#   ('renovacao contratacao', 2),
#   ('contratacao permanente', 2)],
#  'Jardineiro': [('local trabalho', 2),
#   ('exclusiva pcd', 1),
#   ('pcd executar', 1),
#   ('executar atividades', 1),
#   ('atividades poda', 1),
#   ('poda replantio', 1),
#   ('replantio adubacao', 1),
#   ('adubacao periodica', 1),
#   ('periodica irrigacao', 1),
#   ('irrigacao varredura', 1)],
#  'Montador de móveis de madeira': [('montador moveis', 3),
#   ('moveis sob', 2),
#   ('sob medida', 2),
#   ('montagem moveis', 2),
#   ('moveis planejados', 2),
#   ('preparam local', 1),
#   ('local trabalho', 1),
#   ('trabalho montam', 1),
#   ('montam serie', 1),
#   ('serie unidade', 1)],
#  'Repositor - em supermercados': [('vaga exclusiva', 2),
#   ('exclusiva pcd', 2),
#   ('vaga trabalhar', 1),
#   ('trabalhar supermercado', 1),
#   ('supermercado avenida', 1),
#   ('avenida valdon', 1),
#   ('valdon varjao', 1),
#   ('varjao setor', 1),
#   ('setor industrialvai', 1),
#   ('industrialvai registrar', 1)],
#  'Enfermeiro': [('superior completo', 3),
#   ('vaga exclusiva', 2),
#   ('enviar curriculo', 1),
#   ('curriculo mail', 1),
#   ('mail ilanaamaciellgmail', 1),
#   ('ilanaamaciellgmail assunto', 1),
#   ('assunto enfermeiro', 1),
#   ('enfermeiro cpf', 1),
#   ('cpf pis', 1),
#   ('pis aguardar', 1)],
#  'Recepcionista secretária': [('vaga trabalhar', 3),
#   ('ira auxiliar', 2),
#   ('imprescindivel experiencia', 1),
#   ('experiencia administrativo', 1),
#   ('administrativo atendimento', 1),
#   ('atendimento telefone', 1),
#   ('telefone auxiliar', 1),
#   ('auxiliar escritorio', 1),
#   ('escritorio deixa', 1),
#   ('deixa lo', 1)],
#  'Cozinheiro de restaurante': [('horario comercial', 2),
#   ('preparar pratos', 1),
#   ('pratos diversos', 1),
#   ('diversos carnes', 1),
#   ('carnes peixe', 1),
#   ('peixe frangos', 1),
#   ('frangos massas', 1),
#   ('massas saladas', 1),
#   ('saladas comida', 1),
#   ('comida selv', 1)],
#  'Servente de limpeza': [('servicos gerais', 3),
#   ('gerais limpeza', 2),
#   ('ajudante limpeza', 1),
#   ('limpeza servicos', 1),
#   ('trabalhador vaga', 1),
#   ('vaga masculinarealizar', 1),
#   ('masculinarealizar servicos', 1),
#   ('limpeza industrial', 1),
#   ('industrial moinho', 1),
#   ('moinho servico', 1)],
#  'Cuidador de idosos': [('cuidar idosa', 1),
#   ('idosa 8o', 1),
#   ('8o anoscom', 1),
#   ('anoscom alzheimer', 1),
#   ('alzheimer trocar', 1),
#   ('trocar frauda', 1),
#   ('frauda fazer', 1),
#   ('fazer higiene', 1),
#   ('higiene medicamento', 1),
#   ('medicamento entrar', 1)],
#  'Operador de caldeira': [('controlar funcionamento', 2),
#   ('funcionamento caldeiras', 2),
#   ('ensino medio', 2),
#   ('medio completo', 2),
#   ('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('vaga permanente', 1),
#   ('permanente operador', 1),
#   ('operador caldeiras', 1),
#   ('caldeiras trabalhador', 1)],
#  'Operador de telemarketing ativo e receptivo': [('18 anos', 3),
#   ('anos ensino', 3),
#   ('ensino medio', 3),
#   ('medio completo', 3),
#   ('vaga exclusiva', 2),
#   ('exclusiva pcd', 2),
#   ('somente maiores', 2),
#   ('maiores 18', 2),
#   ('atendimento cliente', 2),
#   ('realizara atendimento', 2)],
#  'Recepcionista atendente': [('ensino medio', 2),
#   ('medio completo', 2),
#   ('atendimento cliente', 1),
#   ('cliente pessoalmente', 1),
#   ('pessoalmente telefone', 1),
#   ('telefone organizacao', 1),
#   ('organizacao processos', 1),
#   ('processos arquivos', 1),
#   ('arquivos rotinas', 1),
#   ('rotinas administrativas', 1)],
#  'Auxiliar de estoque': [('limpo organizado', 4),
#   ('produtos materiais', 4),
#   ('vaga exclusiva', 2),
#   ('exclusiva pcd', 2),
#   ('pcd executar', 2),
#   ('executar atividades', 2),
#   ('atividades relacionadas', 2),
#   ('relacionadas setor', 2),
#   ('setor deposito', 2),
#   ('deposito conforme', 2)],
#  'Auxiliar financeiro': [('ira trabalhar', 1),
#   ('trabalhar material', 1),
#   ('material construcao', 1),
#   ('construcao auxiliar', 1),
#   ('auxiliar financeiro', 1),
#   ('financeiro foco', 1),
#   ('foco faturamento', 1),
#   ('faturamento lancamento', 1),
#   ('lancamento notas', 1),
#   ('vaga trabalhar', 1)],
#  'Confeiteiro': [('ter experiencia', 2),
#   ('experiencia comprovada', 2),
#   ('trabalhar padaria', 1),
#   ('padaria supermercado', 1),
#   ('supermercado necessario', 1),
#   ('necessario ter', 1),
#   ('candidatos deve', 1),
#   ('deve ter', 1),
#   ('experiencia funcaoira', 1),
#   ('funcaoira auxiliar', 1)],
#  'Encanador': [('cnh ab', 2),
#   ('deve ter', 2),
#   ('expediente segunda', 2),
#   ('encanador rede', 1),
#   ('rede aguas', 1),
#   ('aguas pluvial', 1),
#   ('pluvial obras', 1),
#   ('obras infraestrutura', 1),
#   ('infraestrutura experiencia', 1),
#   ('experiencia cnh', 1)],
#  'Ajudante de açougueiro (comércio)': [('horario trabalho', 3),
#   ('atendimento balcao', 2),
#   ('folga escala', 2),
#   ('trabalhar supermercado', 2),
#   ('domingo domingo', 2),
#   ('vaga auxiliar', 2),
#   ('auxiliar acougue', 2),
#   ('deve ser', 2),
#   ('conhecimento gerais', 1),
#   ('gerais acougue', 1)],
#  'Carpinteiro': [('trabalhar obras', 1),
#   ('obras construtora', 1),
#   ('construtora ha', 1),
#   ('ha 20', 1),
#   ('20 km', 1),
#   ('km cidade', 1),
#   ('cidade sorriso', 1),
#   ('sorriso mt', 1),
#   ('mt nao', 1),
#   ('nao alojamento', 1)],
#  'Montador soldador': [('experiencia solda', 2),
#   ('solda montagem', 1),
#   ('montagem pecas', 1),
#   ('pecas silos', 1),
#   ('silos ensino', 1),
#   ('ensino fundamental', 1),
#   ('fundamental completo', 1),
#   ('montagem desmontagem', 1),
#   ('desmontagem equipamentos', 1),
#   ('equipamentos solda', 1)],
#  'Montador': [('observando normas', 4),
#   ('trabalhador ira', 2),
#   ('etapas iniciais', 2),
#   ('iniciais processo', 2),
#   ('processo producao', 2),
#   ('producao observando', 2),
#   ('normas seguranca', 2),
#   ('seguranca qualidade', 2),
#   ('qualidade produto', 2),
#   ('produto final', 2)],
#  'Promotor de vendas': [('necessario ter', 2),
#   ('vendas externas', 2),
#   ('atencao vaga', 1),
#   ('vaga exclusiva', 1),
#   ('exclusiva moradores', 1),
#   ('moradores igarape', 1),
#   ('igarape sao', 1),
#   ('sao joaquim', 1),
#   ('joaquim bicas', 1),
#   ('bicas necessario', 1)],
#  'Inspetor de qualidade': [('ensino medio', 2),
#   ('medio completo', 2),
#   ('vaga assistente', 1),
#   ('assistente qualidade', 1),
#   ('qualidade implementar', 1),
#   ('implementar executar', 1),
#   ('executar procedimentos', 1),
#   ('procedimentos sistema', 1),
#   ('sistema qualidade', 1),
#   ('qualidade organizar', 1)],
#  'Auxiliar de marceneiro': [('auxiliar fabricacao', 2),
#   ('fabricacao moveis', 2),
#   ('moveis sob', 2),
#   ('sob medida', 2),
#   ('auxiliar montador', 2),
#   ('trabalhador ira', 1),
#   ('ira auxiliar', 1),
#   ('medida cortes', 1),
#   ('cortes chapas', 1),
#   ('chapas carga', 1)],
#  'Mecânico de máquinas pesadas (manutenção)': [('maquinas pesadas', 2),
#   ('necessario ter', 2),
#   ('experiencia funcao', 2),
#   ('montar desmontar', 2),
#   ('ramo atividadeobras', 1),
#   ('atividadeobras terraplenagemmanutencao', 1),
#   ('terraplenagemmanutencao maquinas', 1),
#   ('pesadas ex', 1),
#   ('ex escavadeira', 1),
#   ('escavadeira retroescavadeira', 1)],
#  'Pizzaiolo': [('preparo pizzas', 2),
#   ('folga semana', 2),
#   ('semana domingo', 2),
#   ('domingo mes', 2),
#   ('horario trabalho', 2),
#   ('ramo atividade', 1),
#   ('atividade hoteispreparacao', 1),
#   ('hoteispreparacao pizzas', 1),
#   ('pizzas salgados', 1),
#   ('pizzaiolo ajudante', 1)],
#  'Lavador de veículos': [('exclusiva pcd', 1),
#   ('pcd lavagem', 1),
#   ('lavagem veiculos', 1),
#   ('veiculos pesados', 1),
#   ('pesados caminhao', 1),
#   ('caminhao aplicacao', 1),
#   ('aplicacao produtos', 1),
#   ('produtos higienizacao', 1),
#   ('higienizacao geral', 1),
#   ('necessario ter', 1)],
#  'Manicure': [('cuidam beleza', 2),
#   ('beleza maos', 2),
#   ('maos pes', 2),
#   ('tratam estetica', 1),
#   ('estetica saude', 1),
#   ('saude aplicam', 1),
#   ('aplicam produtos', 1),
#   ('produtos quimicos', 1),
#   ('quimicos ondular', 1),
#   ('ondular alisar', 1)],
#  'Operador de máquinas fixas, em geral': [('vaga exclusiva', 4),
#   ('exclusiva ppd', 3),
#   ('ppd ira', 3),
#   ('ira verificar', 3),
#   ('verificar condicoes', 3),
#   ('condicoes operacao', 3),
#   ('operacao maquina', 3),
#   ('maquina dispositivos', 3),
#   ('dispositivos ferramentas', 3),
#   ('ferramentas operar', 3)],
#  'Auxiliar de almoxarifado': [('exclusiva pcd', 2),
#   ('vaga exclusiva', 1),
#   ('pcd pessoa', 1),
#   ('pessoa deficiencia', 1),
#   ('deficiencia trabalhar', 1),
#   ('trabalhar empresa', 1),
#   ('empresa avenida', 1),
#   ('avenida miguel', 1),
#   ('miguel sutil', 1),
#   ('sutil bairro', 1)],
#  'Operador de escavadeira': [('mini escavadeira', 2),
#   ('trabalhador ira', 1),
#   ('ira operar', 1),
#   ('operar mini', 1),
#   ('escavadeira cnh', 1),
#   ('cnh pois', 1),
#   ('pois transporta', 1),
#   ('transporta escavadeira', 1),
#   ('escavadeira caminhao', 1),
#   ('caminhao horario', 1)],
#  'Chapista de lanchonete': [('recebera treinamento', 1),
#   ('treinamento manipulacao', 1),
#   ('manipulacao boas', 1),
#   ('boas praticas', 1),
#   ('praticas alimentos', 1),
#   ('alimentos experiencia', 1),
#   ('experiencia auxiliar', 1),
#   ('auxiliar chapeiro', 1),
#   ('chapeiro montagem', 1),
#   ('montagem lanches', 1)],
#  'Eletricista de manutenção industrial': [('experiencia curso', 2),
#   ('nr 10', 2),
#   ('executar montagem', 1),
#   ('montagem manutencao', 1),
#   ('manutencao instalacoes', 1),
#   ('instalacoes eletricas', 1),
#   ('eletricas maquinas', 1),
#   ('maquinas equipamentos', 1),
#   ('equipamentos industriais', 1),
#   ('industriais outras', 1)],
#  'Mecânico de manutenção de máquinas, em geral': [('maquinas pesadas', 3),
#   ('manutencao mecanica', 2),
#   ('mecanica maquinas', 2),
#   ('pesadas frotas', 2),
#   ('frotas equipamentos', 2),
#   ('equipamentos mineracao', 2),
#   ('mineracao cat', 2),
#   ('cat scania', 2),
#   ('scania volvo', 2),
#   ('volvo liebherr', 2)],
#  'Técnico em eletromecânica': [('atividades eletrica', 2),
#   ('eletrica mecanica', 2),
#   ('mecanica industrial', 2),
#   ('ter curso', 2),
#   ('curso tecnico', 2),
#   ('executar atividades', 1),
#   ('industrial conforme', 1),
#   ('conforme solicitacao', 1),
#   ('solicitacao ordem', 1),
#   ('ordem servico', 1)],
#  'Mestre de obras': [('vaga permanente', 1),
#   ('permanente mestre', 1),
#   ('mestre obras', 1),
#   ('obras necessario', 1),
#   ('necessario experiencia', 1),
#   ('experiencia funca', 1),
#   ('profissional funcao', 1),
#   ('necessario cnh', 1),
#   ('cnh trabalhar', 1),
#   ('trabalhar obra', 1)],
#  'Atendente de telemarketing': [('atendem usuarios', 1),
#   ('usuarios oferecem', 1),
#   ('oferecem servicos', 1),
#   ('servicos produtos', 1),
#   ('produtos prestam', 1),
#   ('prestam servicos', 1),
#   ('servicos tecnicos', 1),
#   ('tecnicos especializados', 1),
#   ('especializados realizam', 1),
#   ('realizam pesquisas', 1)],
#  'Auxiliar de contabilidade': [('ter experiencia', 3),
#   ('experiencia comprovada', 2),
#   ('ciencias contabeis', 2),
#   ('comprovada area', 1),
#   ('area estar', 1),
#   ('estar cursando', 1),
#   ('cursando ter', 1),
#   ('ter concluido', 1),
#   ('concluido ciencias', 1),
#   ('contabeis enviar', 1)],
#  'Gerente comercial': [('conhecimento vendas', 2),
#   ('vendas demais', 2),
#   ('ter cnh', 1),
#   ('cnh disponibilidade', 1),
#   ('disponibilidade viajar', 1),
#   ('viajar curso', 1),
#   ('curso tecnico', 1),
#   ('tecnico tecnologo', 1),
#   ('tecnologo gestao', 1),
#   ('gestao comercial', 1)],
#  'Abatedor de aves': [('desossa cortes', 2),
#   ('cortes congeladospesagem', 2),
#   ('ocupacao trabalhar', 1),
#   ('trabalhar abatedouro', 1),
#   ('abatedouro aves', 1),
#   ('aves separador', 1),
#   ('separador partes', 1),
#   ('partes frango', 1),
#   ('trabalhar abate', 1),
#   ('abate aves', 1)],
#  'Vaqueiro': [('necessario ter', 2),
#   ('ter experiencia', 2),
#   ('experiencia funcao', 2),
#   ('trabalhar cuidando', 1),
#   ('cuidando animais', 1),
#   ('animais tirando', 1),
#   ('tirando leite', 1),
#   ('leite fazendo', 1),
#   ('fazendo queijo', 1),
#   ('queijo fazendo', 1)],
#  'Mecânico de manutenção de caminhão a diesel': [('mecanico caminhao', 1),
#   ('caminhao diesel', 1),
#   ('diesel d20', 1),
#   ('efetuar manutencao', 1),
#   ('manutencao preventiva', 1),
#   ('preventiva corretiva', 1),
#   ('corretiva equipamentos', 1),
#   ('equipamentos automoveis', 1),
#   ('automoveis caminhoes', 1),
#   ('caminhoes empresa', 1)],
#  'Salgadeiro': [('segunda sabado', 2),
#   ('trabalhar segunda', 1),
#   ('sabado necessario', 1),
#   ('necessario experiencia', 1),
#   ('experiencia nao', 1),
#   ('nao fumante', 1),
#   ('necessario ter', 1),
#   ('ter experiencia', 1),
#   ('experiencia producao', 1),
#   ('producao salgados', 1)],
#  'Atendente de farmácia - balconista': [('experiencia area', 2),
#   ('balconista deve', 1),
#   ('deve supervisionar', 1),
#   ('supervisionar orientar', 1),
#   ('orientar processo', 1),
#   ('processo compra', 1),
#   ('compra medicamentos', 1),
#   ('medicamentos demais', 1),
#   ('demais produtos', 1),
#   ('produtos farmacia', 1)],
#  'Corretor de imóveis': [('ensino medio', 2),
#   ('ter experiencia', 1),
#   ('experiencia curso', 1),
#   ('curso area', 1),
#   ('area ensino', 1),
#   ('medio morar', 1),
#   ('morar eusebio', 1),
#   ('eusebio fortaleza', 1),
#   ('fortaleza interessados', 1),
#   ('interessados enviar', 1)],
#  'Conferente de carga e descarga': [('disponibilidade horario', 1),
#   ('horario noturno', 1),
#   ('noturno vaga', 1),
#   ('vaga trabalhar', 1),
#   ('trabalhar companhia', 1),
#   ('companhia alimentos', 1),
#   ('alimentos varzea', 1),
#   ('varzea grande', 1),
#   ('grande ira', 1),
#   ('ira carregar', 1)],
#  'Auxiliar de expedição': [('produtos materiais', 2),
#   ('vaga exclusiva', 1),
#   ('exclusiva pcd', 1),
#   ('pcd experiencia', 1),
#   ('experiencia carga', 1),
#   ('carga descarga', 1),
#   ('descarga encaminhar', 1),
#   ('encaminhar candidatos', 1),
#   ('candidatos deficiencia', 1),
#   ('deficiencia leve', 1)],
#  'Vigia': [('areas externas', 2),
#   ('vigiar diversas', 1),
#   ('diversas areas', 1),
#   ('areas unidade', 1),
#   ('unidade portaria', 1),
#   ('portaria areas', 1),
#   ('areas limitrofes', 1),
#   ('limitrofes empresa', 1),
#   ('empresa percorrendo', 1),
#   ('percorrendo verificando', 1)],
#  'Operador de processo de produção': [('ter disponibilidade', 2),
#   ('embalar selar', 1),
#   ('selar cortar', 1),
#   ('cortar inspecionar', 1),
#   ('inspecionar frango', 1),
#   ('tarefas diversas', 1),
#   ('diversas setores', 1),
#   ('setores embalagem', 1),
#   ('embalagem evisceracao', 1),
#   ('vaga exclusiva', 1)],
#  'Frentista': [('exclusiva pcd', 1),
#   ('pcd realizar', 1),
#   ('realizar abastecimento', 1),
#   ('abastecimento lubrificacao', 1),
#   ('lubrificacao calibragem', 1),
#   ('calibragem veiculos', 1),
#   ('veiculos pesados', 1),
#   ('vendem mercadorias', 1),
#   ('mercadorias estabelecimentos', 1),
#   ('estabelecimentos comercio', 1)],
#  'Balconista': [('atuar area', 1),
#   ('area auto', 1),
#   ('auto pecas', 1),
#   ('pessoa ter', 1),
#   ('ter experiencia', 1),
#   ('experiencia balcao', 1),
#   ('balcao padaria', 1),
#   ('padaria saber', 1),
#   ('saber troco', 1),
#   ('troco auxiliar', 1)],
#  'Mecânico de automóveis e caminhões': [('manutencao mecanica', 1),
#   ('mecanica caminhoes', 1),
#   ('caminhoes caminhonetes', 1),
#   ('elaboram planos', 1),
#   ('planos manutencao', 1),
#   ('manutencao realizam', 1),
#   ('realizam manutencoes', 1),
#   ('manutencoes motores', 1),
#   ('motores sistemas', 1),
#   ('sistemas partes', 1)],
#  'Mecânico de auto em geral': [('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('experiencia motor', 1),
#   ('motor diferencial', 1),
#   ('diferencial caixa', 1),
#   ('caixa necessario', 1),
#   ('necessario ter', 1),
#   ('ter experiencia', 1),
#   ('experiencia comprovada', 1),
#   ('comprovada carteira', 1)],
#  'Montador de estruturas metálicas': [('expediente segunda', 2),
#   ('segunda sexta', 2),
#   ('trabalhador ira', 2),
#   ('vaga fabricante', 1),
#   ('fabricante estruturas', 1),
#   ('estruturas metalicas', 1),
#   ('metalicas expediente', 1),
#   ('sexta atencao', 1),
#   ('atencao enviar', 1),
#   ('enviar curriculo', 1)],
#  'Atendente de lojas': [('atendimento cliente', 2),
#   ('14h 22h', 2),
#   ('candidatos operador', 1),
#   ('operador loja', 1),
#   ('loja caixaexclusiva', 1),
#   ('caixaexclusiva pcdreposicao', 1),
#   ('pcdreposicao mercadorias', 1),
#   ('mercadorias atendimento', 1),
#   ('cliente operacoes', 1),
#   ('operacoes caixaexperiencia', 1)],
#  'Auxiliar de operação': [('receber separar', 1),
#   ('separar preparar', 1),
#   ('preparar documentos', 1),
#   ('documentos conferindo', 1),
#   ('conferindo relacoes', 1),
#   ('relacoes remessas', 1),
#   ('remessas encaminhadas', 1),
#   ('encaminhadas area', 1),
#   ('area caixa', 1),
#   ('caixa forte', 1)],
#  'Técnico agrícola': [('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('trabalhador dara', 1),
#   ('dara assistencia', 1),
#   ('assistencia produtores', 1),
#   ('produtores leite', 1),
#   ('leite manutencao', 1),
#   ('manutencao maquinas', 1),
#   ('maquinas ordenha', 1),
#   ('ordenha interessante', 1)],
#  'Técnico eletrônico': [('atencao vaga', 1),
#   ('vaga exclusiva', 1),
#   ('exclusiva moradores', 1),
#   ('moradores igarape', 1),
#   ('igarape sao', 1),
#   ('sao joaquim', 1),
#   ('joaquim bicas', 1),
#   ('bicas betim', 1),
#   ('betim ira', 1),
#   ('ira realizar', 1)],
#  'Torneiro cnc': [('vaga trabalhar', 1),
#   ('trabalhar cachoeira', 1),
#   ('cachoeira sul', 1),
#   ('sul programador', 1),
#   ('programador cnc', 1),
#   ('cnc exige', 1),
#   ('exige ensino', 1),
#   ('ensino medio', 1),
#   ('medio completo', 1),
#   ('completo experiencia', 1)],
#  'Servente de pedreiro': [('carpinteiro armador', 2),
#   ('ramo atividadeconstrucao', 1),
#   ('atividadeconstrucao edificiosexecutar', 1),
#   ('edificiosexecutar servicos', 1),
#   ('servicos apoio', 1),
#   ('apoio pedreiro', 1),
#   ('pedreiro carpinteiro', 1),
#   ('armador canteiro', 1),
#   ('canteiro transportando', 1),
#   ('transportando materiais', 1)],
#  'Mecânico de veículos': [('exclusiva pcd', 1),
#   ('pcd substituir', 1),
#   ('substituir filtro', 1),
#   ('filtro diesel', 1),
#   ('diesel lubrificante', 1),
#   ('lubrificante assim', 1),
#   ('assim troca', 1),
#   ('troca oleo', 1),
#   ('oleo motor', 1),
#   ('motor cambio', 1)],
#  'Mecânico de motor a diesel': [('trabalhador fara', 1),
#   ('fara todas', 1),
#   ('todas atividades', 1),
#   ('atividades inerentes', 1),
#   ('inerentes funcao', 1),
#   ('trabalhar mecanica', 1),
#   ('mecanica caminhonetes', 1),
#   ('caminhonetes diesel', 1),
#   ('diesel eletricidade', 1),
#   ('eletricidade demais', 1)],
#  'Fonoaudiólogo geral': [('candidatas formacao', 1),
#   ('formacao area', 1),
#   ('area ira', 1),
#   ('ira atuar', 1),
#   ('atuar junto', 1),
#   ('junto equipe', 1),
#   ('equipe multidisciplinar', 1),
#   ('multidisciplinar atendimento', 1),
#   ('atendimento clinico', 1),
#   ('clinico infantil', 1)],
#  'Vendedor porta a porta': [('perfil vendas', 1),
#   ('vendas trabalhar', 1),
#   ('trabalhar vendas', 1),
#   ('vendas energia', 1),
#   ('energia fotovoltaicatera', 1),
#   ('fotovoltaicatera treinamento', 1),
#   ('vaga moradores', 1),
#   ('moradores viamao', 1),
#   ('nao necessita', 1),
#   ('necessita experiencia', 1)],
#  'Gerente de vendas': [('gerente vendas', 3),
#   ('todo brasil', 2),
#   ('vendas emporio', 1),
#   ('emporio italiano', 1),
#   ('italiano salario', 1),
#   ('salario 50000', 1),
#   ('50000 necessario', 1),
#   ('necessario ensino', 1),
#   ('ensino medio', 1),
#   ('medio completo', 1)],
#  'Instalador de alarme': [('rastreamento veicular', 2),
#   ('instalador rastreamento', 1),
#   ('veicular trabalhar', 1),
#   ('trabalhar instalacao', 1),
#   ('instalacao manutencao', 1),
#   ('manutencao equipamentos', 1),
#   ('equipamentos eletronicos', 1),
#   ('eletronicos rastreamento', 1),
#   ('veicular carro', 1),
#   ('carro moto', 1)],
#  'Atendente central telemarketing': [('agente atendimento', 1),
#   ('atendimento sac', 1),
#   ('sac empresa', 1),
#   ('empresa exige', 1),
#   ('exige 2o', 1),
#   ('2o completo', 1),
#   ('completo atendimento', 1),
#   ('atendimento clientes', 1),
#   ('clientes criticos', 1),
#   ('criticos ativo', 1)],
#  'Tratorista agrícola': [('vaga trabalhar', 1),
#   ('trabalhar curtume', 1),
#   ('curtume saida', 1),
#   ('saida cuiaba', 1),
#   ('cuiaba ter', 1),
#   ('ter disponibilidade', 1),
#   ('disponibilidade horario', 1),
#   ('horario cnh', 1),
#   ('ira trabalhar', 1),
#   ('trabalhar transbordo', 1)],
#  'Instalador de sistemas eletroeletrônicos de segurança': [('instalacao manutencao',
#    2),
#   ('necessario experiencia', 1),
#   ('experiencia trabalhador', 1),
#   ('trabalhador devera', 1),
#   ('devera ter', 1),
#   ('ter disponibilidade', 1),
#   ('disponibilidade fazer', 1),
#   ('fazer plantao', 1),
#   ('plantao viagens', 1),
#   ('viagens interior', 1)],
#  'Costureiro, a  máquina  na confecção em série': [('trabalhar confeccao', 2),
#   ('trabalhar maquina', 1),
#   ('maquina reta', 1),
#   ('reta fechadeira', 1),
#   ('fechadeira fechar', 1),
#   ('fechar lateral', 1),
#   ('lateral unir', 1),
#   ('unir pala', 1),
#   ('pala pregar', 1),
#   ('pregar carcela', 1)],
#  'Contador': [('necessario curso', 1),
#   ('curso superior', 1),
#   ('superior experiencia', 1),
#   ('experiencia contadorcnh', 1),
#   ('contadorcnh desejavel', 1),
#   ('desejavel conhecimento', 1),
#   ('conhecimento sistema', 1),
#   ('sistema totvsrm', 1),
#   ('totvsrm trabalhar', 1),
#   ('trabalhar laticinios', 1)],
#  'Ajudante de farmácia': [('medicamentos materiais', 2),
#   ('ensino medio', 2),
#   ('medio completo', 2),
#   ('precisa estar', 1),
#   ('estar cursando', 1),
#   ('cursando concluido', 1),
#   ('concluido ensino', 1),
#   ('ensino superior', 1),
#   ('superior tecnico', 1),
#   ('tecnico farmacia', 1)],
#  'Atendente de padaria': [('pessoa ira', 1),
#   ('ira realizar', 1),
#   ('realizar atendimento', 1),
#   ('atendimento padaria', 1),
#   ('padaria mercado', 1),
#   ('mercado auxiliar', 1),
#   ('auxiliar limpeza', 1),
#   ('limpeza organizacao', 1),
#   ('organizacao local', 1),
#   ('local seg', 1)],
#  'Técnico de refrigeração (instalação)': [('tecnico eletromecanica', 1),
#   ('eletromecanica industrial', 1),
#   ('industrial concluido', 1),
#   ('concluido nr13', 1),
#   ('nr13 nr10', 1),
#   ('nr10 nr', 1),
#   ('nr 35', 1),
#   ('35 trabalhar', 1),
#   ('trabalhar industria', 1),
#   ('industria ramo', 1)],
#  'Operador de teleatendimento híbrido (telemarketing)': [('atencao entrevista',
#    1),
#   ('entrevista levar', 1),
#   ('levar rg', 1),
#   ('atividades ira', 1),
#   ('ira atuar', 1),
#   ('atuar central', 1),
#   ('central atendimento', 1),
#   ('atendimento cliente', 1),
#   ('cliente podendo', 1),
#   ('podendo atuar', 1)],
#  'Técnico mecânico': [('tecnico mecanica', 2),
#   ('veiculos leves', 2),
#   ('leves pesados', 2),
#   ('curso tecnico', 2),
#   ('ter cnh', 2),
#   ('ensino medio', 1),
#   ('medio tecnico', 1),
#   ('mecanica conhecimento', 1),
#   ('conhecimento operacao', 1),
#   ('operacao equipamentos', 1)],
#  'Auxiliar mecânico de refrigeração': [('experiencia comprovada', 2),
#   ('auxiliar instalacao', 1),
#   ('instalacao servicos', 1),
#   ('servicos manutencao', 1),
#   ('manutencao preventiva', 1),
#   ('preventiva corretiva', 1),
#   ('corretiva equipamentos', 1),
#   ('equipamentos climatizacao', 1),
#   ('climatizacao refrigeracao', 1),
#   ('refrigeracao self', 1)],
#  'Cobrador externo': [('necessario ter', 2),
#   ('ter experiencia', 1),
#   ('experiencia funcao', 1),
#   ('funcao ter', 1),
#   ('ter cnh', 1),
#   ('cnh empresa', 1),
#   ('empresa disponibiliza', 1),
#   ('disponibiliza moto', 1),
#   ('moto trabalhar', 1),
#   ('trabalhar trabalho', 1)],
#  'Pintor industrial': [('segunda sexta', 2),
#   ('pintor experiencia', 1),
#   ('experiencia pintura', 1),
#   ('pintura po', 1),
#   ('po eletrostatica', 1),
#   ('eletrostatica expediente', 1),
#   ('expediente segunda', 1),
#   ('sexta horario', 1),
#   ('horario comercial', 1),
#   ('comercial antes', 1)],
#  'Classificador de grãos': [('vaga trabalhar', 2),
#   ('trabalhar auditor', 2),
#   ('auditor graos', 2),
#   ('graos ira', 2),
#   ('ira fazer', 2),
#   ('fazer analise', 2),
#   ('analise criteriosa', 2),
#   ('criteriosa graos', 2),
#   ('graos soja', 2),
#   ('soja interagir', 2)],
#  'Apontador de obras': [('trabalhador deve', 1),
#   ('deve ter', 1),
#   ('ter conhecimentos', 1),
#   ('conhecimentos informatica', 1),
#   ('informatica word', 1),
#   ('word excel', 1),
#   ('excel ponto', 1),
#   ('ponto trabalhadores', 1),
#   ('trabalhadores enteder', 1),
#   ('enteder obras', 1)],
#  'Pintor de automóveis': [('preparar tinta', 1),
#   ('tinta pintar', 1),
#   ('pintar carretas', 1),
#   ('carretas pintar', 1),
#   ('pintar chassi', 1),
#   ('chassi caminhoes', 1),
#   ('caminhoes pintura', 1),
#   ('pintura parte', 1),
#   ('parte graneleira', 1),
#   ('graneleira carretas', 1)],
#  'Auxiliar operacional de logística': [('exclusiva pcd', 3),
#   ('curriculo carta', 2),
#   ('carta sine', 2),
#   ('vaga exclusiva', 2),
#   ('movimentacao mercadorias', 2),
#   ('vaga auxiliar', 1),
#   ('auxiliar operacional', 1),
#   ('operacional exclusiva', 1),
#   ('pcd carimbar', 1),
#   ('carimbar auditar', 1)],
#  'Ajudante de motorista': [('carregar descarregar', 1),
#   ('descarregar produtos', 1),
#   ('produtos cliente', 1),
#   ('cliente revenda', 1),
#   ('revenda conferir', 1),
#   ('conferir vasilhames', 1),
#   ('vasilhames conformidade', 1),
#   ('conformidade auxiliar', 1),
#   ('auxiliar motorista', 1),
#   ('motorista entregas', 1)],
#  'Vendedor - no comércio de mercadorias': [('ter disponibilidade', 2),
#   ('vendas mercadorias', 1),
#   ('informacoes fgtas', 1),
#   ('fgtas sine', 1),
#   ('sine tres', 1),
#   ('tres maio', 1),
#   ('maio 55', 1),
#   ('55 3535', 1),
#   ('3535 1841', 1),
#   ('obs conta', 1)],
#  'Almoxarife': [('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('trabalhador realizar', 1),
#   ('realizar separacao', 1),
#   ('separacao carregamento', 1),
#   ('carregamento pecas', 1),
#   ('pecas area', 1),
#   ('area usinagem', 1),
#   ('usinagem cnh', 1),
#   ('cnh expediente', 1)],
#  'Operador de vendas (lojas)': [('atendimento cliente', 2),
#   ('ajudante lojasrepositorfiscal', 1),
#   ('lojasrepositorfiscal lojaempacotadoroperador', 1),
#   ('lojaempacotadoroperador caixa', 1),
#   ('xy1945 captacao', 1),
#   ('captacao curriculos', 1),
#   ('curriculos cleuza', 1),
#   ('cleuza email', 1),
#   ('email dp', 1),
#   ('dp rioclarospani', 1)],
#  'Mecânico de veículos automotores a diesel (exceto tratores)': [('trabalhar ter',
#    1),
#   ('ter experiencia', 1),
#   ('experiencia manutencao', 1),
#   ('manutencao preventiva', 1),
#   ('preventiva corretiva', 1),
#   ('corretiva veiculo', 1),
#   ('veiculo diesel', 1),
#   ('diesel medio', 1),
#   ('medio grande', 1),
#   ('grande porte', 1)],
#  'Empregado doméstico diarista': [('trabalhar 2x', 2),
#   ('2x semana', 2),
#   ('necessario ter', 1),
#   ('ter experiencia', 1),
#   ('experiencia funcao', 1),
#   ('funcao referencia', 1),
#   ('referencia pessoal', 1),
#   ('pessoal trabalhar', 1),
#   ('semana limpeza', 1),
#   ('limpeza organizacao', 1)],
#  'Analista administrativo': [('realizar analise', 2),
#   ('departamento pessoal', 2),
#   ('0800 1800', 2),
#   ('analise processos', 1),
#   ('processos departamento', 1),
#   ('pessoal identificar', 1),
#   ('identificar pontos', 1),
#   ('pontos melhoria', 1),
#   ('melhoria propor', 1),
#   ('propor solucoes', 1)],
#  'Ajudante de estruturas metálicas': [('ter disponibilidade', 2),
#   ('auxiliara montadores', 1),
#   ('montadores organizacao', 1),
#   ('organizacao pecas', 1),
#   ('pecas torres', 1),
#   ('torres estrutura', 1),
#   ('estrutura metalica', 1),
#   ('metalica necessario', 1),
#   ('necessario ter', 1),
#   ('disponibilidade trabalhar', 1)],
#  'Mecânico de refrigeração': [('experiencia comprovada', 3),
#   ('comprovada area', 2),
#   ('possuir experiencia', 1),
#   ('trabalhador ira', 1),
#   ('ira fazer', 1),
#   ('fazer desmontagem', 1),
#   ('desmontagem montagem', 1),
#   ('montagem limpeza', 1),
#   ('limpeza retirada', 1),
#   ('retirada reinstalacao', 1)],
#  'Babá': [('crianca anos', 2),
#   ('trabalhara primeiros', 1),
#   ('primeiros meses', 1),
#   ('meses navirai', 1),
#   ('navirai mudara', 1),
#   ('mudara trabalhar', 1),
#   ('trabalhar maringa', 1),
#   ('maringa residencia', 1),
#   ('residencia empregadora', 1),
#   ('empregadora cuidando', 1)],
#  'Ajudante de cozinha': [('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('itapemirim marataizes', 1),
#   ('vaga trabalhar', 1),
#   ('trabalhar adrianopolis', 1),
#   ('adrianopolis restaurante', 1),
#   ('restaurante coma', 1),
#   ('coma bem', 1),
#   ('bem auxiliar', 1),
#   ('auxiliar servicos', 1)],
#  'Porteiro': [('exclusiva pcd', 1),
#   ('pcd controle', 1),
#   ('controle acesso', 1),
#   ('acesso pessoas', 1),
#   ('pessoas veiculos', 1),
#   ('veiculos materiais', 1),
#   ('materiais atendimento', 1),
#   ('atendimento pessoal', 1),
#   ('pessoal telefonico', 1),
#   ('telefonico visitantes', 1)],
#  'Eletricista de instalações': [('instalacao equipamentos', 2),
#   ('trabalho seg', 2),
#   ('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('eletricista instalacao', 1),
#   ('equipamentos energia', 1),
#   ('energia solar', 1),
#   ('solar trabalho', 1),
#   ('seg sex', 1),
#   ('sex horario', 1)],
#  'Atendente balconista': [('realizar atendimento', 1),
#   ('atendimento viajantes', 1),
#   ('viajantes iram', 1),
#   ('iram fazer', 1),
#   ('fazer refeicoes', 1),
#   ('refeicoes balcao', 1),
#   ('atendimento cliente', 1),
#   ('cliente organizacao', 1),
#   ('organizacao limpeza', 1),
#   ('limpeza local', 1)],
#  'Auxiliar de agricultura': [('ira trabalhar', 2),
#   ('trabalhar tratos', 2),
#   ('tratos culturais', 2),
#   ('culturais cana', 2),
#   ('cana acucar', 2),
#   ('acucar auxiliam', 1),
#   ('auxiliam colheita', 1),
#   ('colheita mesma', 1),
#   ('plantio cana', 1),
#   ('cana acucaradubamento', 1)],
#  'Armador de ferragens na construção civil': [('armacao ferragens', 1),
#   ('ferragens montagem', 1),
#   ('montagem ferragens', 1),
#   ('ferragens conforme', 1),
#   ('conforme projeto', 1),
#   ('projeto anos', 1),
#   ('anos comprovacao', 1),
#   ('comprovacao preferencialmente', 1),
#   ('preferencialmente morar', 1),
#   ('morar bairros', 1)],
#  'Operador de pá carregadeira': [('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('imprescindivel habilitacao', 1),
#   ('habilitacao categoria', 1),
#   ('categoria bd', 1),
#   ('bd curso', 1),
#   ('curso operador', 1),
#   ('operador maquinas', 1),
#   ('maquinas candidato', 1),
#   ('candidato ira', 1)],
#  'Camareira de hotel': [('ramo atividade', 1),
#   ('atividade hoteislimpeza', 1),
#   ('hoteislimpeza geral', 1),
#   ('geral arrumacao', 1),
#   ('arrumacao quartos', 1),
#   ('quartos hotel', 1),
#   ('vaga exclusiva', 1),
#   ('exclusiva pessoas', 1),
#   ('pessoas deficiencia', 1),
#   ('deficiencia realizar', 1)],
#  'Vidraceiro': [('planejar trabalhos', 1),
#   ('trabalhos efetuar', 1),
#   ('efetuar cortes', 1),
#   ('cortes montagem', 1),
#   ('montagem edficacoes', 1),
#   ('edficacoes anos', 1),
#   ('anos comprovacao', 1),
#   ('comprovacao preferencialmente', 1),
#   ('preferencialmente morar', 1),
#   ('morar bairros', 1)],
#  'Trabalhador da suinocultura': [('granja suinos', 2),
#   ('masculinode preferencia', 1),
#   ('preferencia experiencia', 1),
#   ('experiencia granja', 1),
#   ('suinos trabalhar', 1),
#   ('trabalhar granja', 1),
#   ('suinos alibem', 1),
#   ('alibem santo', 1),
#   ('santo angelo', 1)],
#  'Carpinteiro de obras': [('ensino fundamental', 2),
#   ('vaga trabalhar', 1),
#   ('trabalhar aripuanamt', 1),
#   ('aripuanamt ensino', 1),
#   ('fundamental completo', 1),
#   ('completo ter', 1),
#   ('ter experiencia', 1),
#   ('experiencia 06', 1),
#   ('06 meses', 1),
#   ('meses funcao', 1)],
#  'Pedagogo': [('tutor presencial', 2),
#   ('tutor polo', 1),
#   ('polo tutor', 1),
#   ('presencial funcao', 1),
#   ('funcao fazer', 1),
#   ('fazer estudantes', 1),
#   ('estudantes interessem', 1),
#   ('interessem ativos', 1),
#   ('ativos processo', 1),
#   ('processo desenvolvimento', 1)],
#  'Assistente social': [('atribuicoes atendimento', 1),
#   ('atendimento social', 1),
#   ('social construcao', 1),
#   ('construcao plano', 1),
#   ('plano individual', 1),
#   ('individual atendimento', 1),
#   ('atendimento desenvolvimento', 1),
#   ('desenvolvimento convivio', 1),
#   ('convivio socia', 1),
#   ('socia familiaretc', 1)],
# ...
#  'Operador de equipamentos de secagem (mineração)': [('vagas moradores', 1),
#   ('moradores itapemirim', 1)],
#  'Fiscal de loja': [('trabalhar prevencao', 1),
#   ('prevencao pequenos', 1),
#   ('pequenos furtos', 1),
#   ('furtos loja', 1),
#   ('loja supermercado', 1),
#   ('supermercado curso', 1),
#   ('curso vigilante', 1),
#   ('vigilante experiencia', 1),
#   ('experiencia horario', 1),
#   ('horario 1330', 1)],
#  'Podador de árvores na conservação de vias permanentes': [('ajudante podador',
#    1)],
#  'Chefe de serviço de limpeza': [('trabalhara hospital', 1),
#   ('hospital campanha', 1),
#   ('campanha criciuma', 1),
#   ('criciuma local', 1),
#   ('local definir', 1),
#   ('definir cnh', 1),
#   ('cnh exp', 1),
#   ('exp lideranca', 1),
#   ('lideranca equipe', 1),
#   ('equipe diferencial', 1)],
#  'Pintor de edifícios': [('trabalho interior', 1)],
#  'Supervisor da manutenção e reparação de veículos pesados': [('relacionadas gestao',
#    2),
#   ('veiculos equipamentos', 2),
#   ('trabalhador gerir', 1),
#   ('gerir todas', 1),
#   ('todas atividades', 1),
#   ('atividades relacionadas', 1),
#   ('gestao veiculos', 1),
#   ('equipamentos unidade', 1),
#   ('unidade garantir', 1),
#   ('garantir conformidade', 1)],
#  'Coordenador de infraestrutura de tecnologia da informação': [('vaga pcd', 1),
#   ('pcd coordenador', 1),
#   ('coordenador ti', 1),
#   ('ti meses', 1),
#   ('meses experiencia', 1),
#   ('experiencia ctps', 1),
#   ('ctps superior', 1),
#   ('superior completo', 1),
#   ('completo aceita', 1),
#   ('aceita moradores', 1)],
#  'Mecânico montador de motores de aeronaves': [('obrigatorio curso', 1),
#   ('curso lid', 1),
#   ('lid metrologia', 1),
#   ('metrologia curso', 1),
#   ('curso tecnico', 1),
#   ('tecnico area', 1),
#   ('area disponibilidade', 1),
#   ('disponibilidade viagens', 1),
#   ('viagens ensino', 1),
#   ('ensino fundamental', 1)],
#  'Operador de máquinas de usinar madeira (cnc)': [('trabalhador atuar', 1),
#   ('atuar montagem', 1),
#   ('montagem preparacao', 1),
#   ('preparacao pecas', 1),
#   ('pecas marmore', 1),
#   ('marmore local', 1),
#   ('local centro', 1)],
#  'Pintor especializado em pintura acrílica (veículos)': [('vaga preparacao',
#    1),
#   ('preparacao pintura', 1),
#   ('pintura veiculos', 1),
#   ('veiculos obrigatorio', 1),
#   ('obrigatorio experiencia', 1),
#   ('experiencia ctps', 1)],
#  'Programador de computador': [('teste sistema', 1), ('sistema numero', 1)],
#  'Representante técnico de vendas': [('trabalhar regiao', 1),
#   ('regiao cariri', 1),
#   ('cariri representacao', 1),
#   ('representacao administradora', 1),
#   ('administradora cartao', 1),
#   ('cartao credito', 1),
#   ('credito legista', 1),
#   ('legista substituindo', 1),
#   ('substituindo crediario', 1),
#   ('crediario garantindo', 1)],
#  'Ferramenteiro': [('captacao curriculos', 1),
#   ('curriculos mail', 1),
#   ('mail vanuza', 1),
#   ('vanuza camposhelptech', 1),
#   ('camposhelptech ind', 1),
#   ('ind br', 1),
#   ('br manutencoes', 1),
#   ('manutencoes corretivas', 1),
#   ('corretivas preventivas', 1),
#   ('preventivas moldes', 1)],
#  'Encarregado da recepção': [('hotel matrincha', 1)],
#  'Bombeiro civil': [('vao trabalhar', 1),
#   ('trabalhar efetuando', 1),
#   ('efetuando salvamento', 1),
#   ('salvamento terrestres', 1),
#   ('terrestres aquaticos', 1),
#   ('aquaticos altura', 1),
#   ('altura protegendo', 1),
#   ('protegendo pessoas', 1),
#   ('pessoas patrimonios', 1),
#   ('patrimonios incendios', 1)],
#  'Auxiliares administrativos e de escritórios': [('ira ajudar', 1),
#   ('ajudar tarefas', 1),
#   ('tarefas simples', 1),
#   ('simples area', 1),
#   ('area administrativa', 1),
#   ('administrativa arquivo', 1),
#   ('arquivo informacoes', 1),
#   ('informacoes fornecedores', 1),
#   ('fornecedores etc', 1)],
#  'Encarregado eletromecânico de instalações': [('morador horizontina', 1),
#   ('horizontina experiencia', 1),
#   ('experiencia tecnico', 1),
#   ('tecnico eletromecanica', 1),
#   ('eletromecanica eletrotecnico', 1),
#   ('eletrotecnico realizar', 1),
#   ('realizar manutencao', 1),
#   ('manutencao preventiva', 1),
#   ('preventiva corretiva', 1),
#   ('corretiva portoes', 1)],
#  'Supervisor de vendas no varejo': [('atuar encarregado', 1),
#   ('encarregado vendas', 1),
#   ('vendas ramo', 1),
#   ('ramo pecas', 1),
#   ('pecas automotivas', 1),
#   ('automotivas solida', 1),
#   ('solida experiencia', 1),
#   ('experiencia lideranca', 1),
#   ('lideranca equipe', 1),
#   ('equipe seg', 1)],
#  'Topógrafo': [('levantamento topografico', 1),
#   ('topografico campo', 1),
#   ('campo utilizando', 1),
#   ('utilizando gps', 1),
#   ('gps geodesico', 1),
#   ('geodesico rtk', 1),
#   ('rtk estacao', 1),
#   ('estacao total', 1),
#   ('total fins', 1),
#   ('fins regularizacao', 1)],
#  'Administrador de marketing': [('vaga estagio', 1),
#   ('estagio obrigatorio', 1),
#   ('obrigatorio experiencia', 1),
#   ('experiencia cursando', 1),
#   ('cursando nivel', 1),
#   ('nivel superior', 1),
#   ('superior area', 1),
#   ('area conhecimento', 1),
#   ('conhecimento area', 1),
#   ('area publicidade', 1)],
#  'Afiador de ferramentas': [('fazenda rio', 2),
#   ('rio grande', 2),
#   ('trabalhadorpara trabalhar', 1),
#   ('trabalhar fazenda', 1),
#   ('grande bairro', 1),
#   ('bairro pioneiros', 1),
#   ('pioneiros polimento', 1),
#   ('polimento superficies', 1),
#   ('superficies metalicas', 1),
#   ('metalicas afiacao', 1)],
#  'Conferente de serviços bancários': [('obrigatorio ensino', 1),
#   ('ensino medio', 1),
#   ('medio completo', 1),
#   ('completo experiencia', 1),
#   ('experiencia trabalhar', 1),
#   ('trabalhar financiamentos', 1),
#   ('financiamentos bancarios', 1),
#   ('bancarios credito', 1),
#   ('credito consignado', 1),
#   ('consignado emprestimo', 1)],
#  'Instrutor de informática': [('professor informatica', 1),
#   ('informatica tecnologia', 1),
#   ('tecnologia conhecimento', 1),
#   ('conhecimento funcao', 1),
#   ('funcao experiencia', 1),
#   ('experiencia programacao', 1),
#   ('programacao adobe', 1),
#   ('adobe horario', 1),
#   ('horario trabalho', 1),
#   ('trabalho flexivel', 1)],
#  'Médico da estratégia de saúde da família': [('consultas atendimentos', 1),
#   ('atendimentos medicos', 1)],
#  'Operador de máquina perfuratriz': [('operar perfuratriz', 1),
#   ('perfuratriz roto', 1),
#   ('roto percussiva', 1),
#   ('percussiva avanco', 1),
#   ('avanco automatico', 1),
#   ('automatico sobre', 1),
#   ('sobre carreta', 1),
#   ('carreta efetuando', 1),
#   ('efetuando perfuracoes', 1),
#   ('perfuracoes rocha', 1)],
#  'Avaliador de imóveis': [('trabalhador conhecimento', 1),
#   ('conhecimento informatica', 1),
#   ('informatica ira', 1),
#   ('ira trabalhar', 1),
#   ('trabalhar vistorias', 1),
#   ('vistorias imoveis', 1),
#   ('imoveis fazer', 1),
#   ('fazer relatorios', 1),
#   ('relatorios atendimento', 1),
#   ('atendimento cliente', 1)],
#  'Mecânico de manutenção de ar condicionado': [('ter cnh', 1),
#   ('cnh ter', 1),
#   ('ter curso', 1),
#   ('curso tecnico', 1),
#   ('tecnico ar', 1),
#   ('ar condicionado', 1),
#   ('condicionado morar', 1),
#   ('morar trabalhar', 1),
#   ('trabalhar nobres', 1),
#   ('nobres vaga', 1)],
#  'Cuidador em saúde': [('dinamico ensino', 1),
#   ('ensino medio', 1),
#   ('medio completo', 1),
#   ('completo empregador', 1),
#   ('empregador exige', 1),
#   ('exige maior', 1),
#   ('maior 21', 1),
#   ('21 anos', 1),
#   ('anos alega', 1),
#   ('alega existe', 1)],
#  'ASSISTENTE ADMINISTRATIVO': [('ter disponibilidade', 1),
#   ('disponibilidade trabalhar', 1),
#   ('trabalhar sabados', 1)],
#  'Chacareiro - exclusive conta própria e empregador': [('fazer reformas', 1),
#   ('reformas cercas', 1),
#   ('cercas rocadas', 1),
#   ('rocadas lidar', 1),
#   ('lidar gado', 1),
#   ('gado fazer', 1),
#   ('fazer limpezas', 1),
#   ('limpezas redor', 1),
#   ('redor sitio', 1),
#   ('sitio tratar', 1)],
#  'Auxiliar geral de conservação de vias permanentes (exceto trilhos)': [('masculino rastelar',
#    1),
#   ('rastelar pavimentacao', 1),
#   ('pavimentacao tapar', 1),
#   ('tapar buraco', 1),
#   ('buraco massa', 1),
#   ('massa asfalto', 1)],
#  'Concreteiro': [('vaga exclusiva', 1),
#   ('exclusiva pcd', 1),
#   ('pcd encher', 1),
#   ('encher formas', 1),
#   ('formas postes', 1),
#   ('postes concreto', 1),
#   ('concreto auxilio', 1),
#   ('auxilio ponte', 1),
#   ('ponte rolante', 1),
#   ('rolante experiencia', 1)],
#  'Operador de secador na fabricação e refino de açúcar': [('vagas moradores',
#    1),
#   ('moradores itapemirim', 1)],
#  'Vendedor em comércio atacadista': [('atendimento pontos', 1),
#   ('pontos vendas', 1),
#   ('vendas propaganda', 1),
#   ('propaganda reposicao', 1),
#   ('reposicao ens', 1),
#   ('ens medio', 1),
#   ('medio completo', 1),
#   ('completo cnha', 1),
#   ('cnha experiencia', 1),
#   ('experiencia vendas', 1)],
#  'Operador de centro de usinagem com comando numérico': [('operador programador',
#    1),
#   ('programador usinagem', 1)],
#  'Operador de adubadeira': [('vagas moradores', 1),
#   ('moradores itapemirim', 1)],
#  'Projetista de ferramentas': [('desenvolver projetosdesenhos', 1),
#   ('projetosdesenhos solidworks', 1),
#   ('solidworks chaparias', 1),
#   ('chaparias necessario', 1),
#   ('necessario ter', 1),
#   ('ter conhecimento', 1),
#   ('conhecimento basico', 1),
#   ('basico solidworks', 1)],
#  'Montador de equipamentos elétricos (transformadores)': [('vaga exclusiva',
#    1),
#   ('exclusiva pcd', 1),
#   ('pcd candidato', 1),
#   ('candidato devera', 1),
#   ('devera ter', 1),
#   ('ter experiencia', 1),
#   ('experiencia area', 1),
#   ('area producao', 1),
#   ('producao montam', 1),
#   ('montam testam', 1)],
#  'Trabalhador agrícola polivalente': [('trabalhar fazenda', 1)],
#  'Recepcionista de hospital': [('trabalhar recepcao', 1),
#   ('recepcao hospital', 1),
#   ('hospital disponibilidade', 1),
#   ('disponibilidade horario', 1),
#   ('horario experiencia', 1),
#   ('experiencia atendimento', 1)],
#  'Técnico em instrumentação': [('vaga pcd', 1),
#   ('pcd tec', 1),
#   ('tec enfermagem', 1),
#   ('enfermagem instrumentador', 1),
#   ('instrumentador meses', 1),
#   ('meses experiencia', 1),
#   ('experiencia ctps', 1),
#   ('ctps medio', 1),
#   ('medio completo', 1),
#   ('completo aceita', 1)],
#  'Apontador de produção': [('apropriacao apontamento', 1),
#   ('apontamento equipamentos', 1),
#   ('equipamentos servicos', 1),
#   ('servicos materias', 1)],
#  'Armazenista': [('responsavel armazenamento', 1),
#   ('armazenamento correto', 1),
#   ('correto mercadorias', 1),
#   ('mercadorias horario', 1),
#   ('horario trabalho', 1),
#   ('trabalho 06h', 1),
#   ('06h 16', 1),
#   ('16 possuir', 1),
#   ('possuir cnh', 1),
#   ('cnh ab', 1)],
#  'Operador de motoniveladora': [('vaga aripuana', 1),
#   ('aripuana necessario', 1),
#   ('necessario ter', 1),
#   ('ter experiencia', 1),
#   ('experiencia funcao', 1),
#   ('funcao operar', 1),
#   ('operar motoniveladora', 1),
#   ('motoniveladora executando', 1),
#   ('executando servicos', 1),
#   ('servicos regularizacao', 1)],
#  'Operador de fábrica de rações': [('masculino trabalhar', 1),
#   ('trabalhar fabrica', 1),
#   ('fabrica racoes', 1),
#   ('racoes alibem', 1)],
#  'Encarregado de expedição': [('carregar caminhoesentregar', 1),
#   ('caminhoesentregar receber', 1),
#   ('receber mercadorias', 1),
#   ('mercadorias cuidar', 1),
#   ('cuidar estoques', 1),
#   ('estoques materiais', 1),
#   ('materiais vao', 1),
#   ('vao obras', 1),
#   ('obras precisa', 1),
#   ('precisa ter', 1)],
#  'Conferente mercadoria (exceto carga e descarga)': [('conferir mercadorias',
#    1),
#   ('mercadorias chegam', 1),
#   ('chegam deposito', 1),
#   ('deposito estado', 1),
#   ('estado quantidades', 1),
#   ('quantidades validades', 1),
#   ('validades realizar', 1),
#   ('realizar conferencia', 1),
#   ('conferencia nf', 1),
#   ('nf atender', 1)],
#  'Professor de educação física no ensino superior': [('vaga estagio', 1),
#   ('estagio cursando', 1),
#   ('cursando educacao', 1),
#   ('educacao fisica', 1),
#   ('fisica trabalhara', 1),
#   ('trabalhara instrutor', 1),
#   ('instrutor academia', 1),
#   ('academia auxiliando', 1),
#   ('auxiliando alunos', 1),
#   ('alunos treinos', 1)],
#  'Gerente de hotel': [('ira zelar', 1),
#   ('zelar cuidar', 1),
#   ('cuidar gerencia', 1),
#   ('gerencia hotel', 1)],
#  'Técnico de inspeção da indústria metalúrgica': [('vaga tecnico', 1),
#   ('tecnico inspecao', 1),
#   ('inspecao planejamento', 1),
#   ('planejamento mecanico', 1),
#   ('mecanico iv', 1),
#   ('iv v2060218', 1),
#   ('v2060218 candidato', 1),
#   ('candidato deve', 1),
#   ('deve ser', 1),
#   ('ser encaminhado', 1)],
#  'Auxiliar de faturamento': [('notas fiscais', 3),
#   ('vaga exclusiva', 1),
#   ('exclusiva pcd', 1),
#   ('pcd pessoa', 1),
#   ('pessoa deficiencia', 1),
#   ('deficiencia auxiliar', 1),
#   ('auxiliar faturamento', 1),
#   ('faturamento pedidos', 1),
#   ('pedidos notas', 1),
#   ('fiscais expedicao', 1)],
#  'Médico do trabalho': [('vaga permanente', 1),
#   ('permanente medico', 1),
#   ('medico trabalho', 1),
#   ('trabalho deve', 1),
#   ('deve ter', 1),
#   ('ter especializacao', 1),
#   ('especializacao medicina', 1),
#   ('medicina trabalho', 1),
#   ('trabalho vaga', 1),
#   ('vaga permanece', 1)],
#  'Pintor de alvenaria': [('realizara funcoes', 1),
#   ('funcoes pintor', 1),
#   ('pintor empresa', 1),
#   ('empresa necessario', 1),
#   ('necessario ter', 1),
#   ('ter cnh', 1),
#   ('cnh ab', 1),
#   ('ab trabalho', 1),
#   ('trabalho segunda', 1),
#   ('segunda sabado', 1)],
#  'Gerente administrativo': [('experiencia area', 2),
#   ('ambos sexos', 1),
#   ('sexos ter', 1),
#   ('ter experiencia', 1),
#   ('area farmacia', 1),
#   ('farmacia comprovada', 1),
#   ('comprovada nao', 1),
#   ('nao encaminhe', 1),
#   ('encaminhe pra', 1),
#   ('pra vaga', 1)],
#  'Instalador de antenas de televisão': [('instalacao antena', 1),
#   ('antena tv', 1),
#   ('tv acessorios', 1)],
#  'Lixador de peças de metal': [('trabalhador realizar', 1),
#   ('realizar acabamento', 1),
#   ('acabamento pecas', 1),
#   ('pecas metal', 1),
#   ('metal lixar', 1),
#   ('lixar pintar', 1),
#   ('pintar outras', 1),
#   ('outras atividades', 1),
#   ('atividades expediente', 1),
#   ('expediente horario', 1)],
#  'Supervisor de manutenção mecânica de sistemas operacionais': [('vagav2061219 supervisao',
#    1),
#   ('supervisao manutencao', 1),
#   ('manutencao mecanica', 1),
#   ('mecanica candidato', 1),
#   ('candidato deve', 1),
#   ('deve ser', 1),
#   ('ser encaminhado', 1),
#   ('encaminhado sistema', 1),
#   ('sistema mte', 1),
#   ('mte emprega', 1)],
#  'Rebitador, a  mão': [('trabalhador experiencia', 1),
#   ('experiencia trabalhar', 1),
#   ('trabalhar rebitador', 1),
#   ('rebitador fabrica', 1),
#   ('fabrica cod20', 1)],
#  'Mecânico de direção e freios de automóveis': [('servico manutencao', 1),
#   ('manutencao suspensao', 1),
#   ('suspensao sistema', 1),
#   ('sistema freio', 1),
#   ('freio carreta', 1),
#   ('carreta experiencia', 1),
#   ('experiencia comprovada', 1),
#   ('comprovada carteira', 1),
#   ('carteira horario', 1),
#   ('horario trabalho', 1)],
#  'Marceneiro de móveis': [('experiencia comprovada', 1),
#   ('comprovada ctps', 1),
#   ('ctps cnh', 1)],
#  'Abatedor de porco': [('abater porcossuinos', 1),
#   ('porcossuinos carregar', 1),
#   ('carregar pecas', 1),
#   ('pecas inteiras', 1),
#   ('inteiras classificar', 1),
#   ('classificar pesar', 1),
#   ('pesar embalar', 1),
#   ('embalar trabalhos', 1),
#   ('trabalhos relacionados', 1),
#   ('relacionados abate', 1)],
#  'Arqueador de molas': [('trabalhar molas', 1),
#   ('molas caminhoes', 1),
#   ('caminhoes geral', 1)],
#  'Preparador de calçados': [('vaga exclusiva', 1),
#   ('exclusiva pessoa', 1),
#   ('pessoa deficiencia', 1),
#   ('deficiencia trabalhar', 1),
#   ('trabalhar senador', 1),
#   ('senador pompeu', 1),
#   ('pompeu candidatos', 1),
#   ('candidatos precisam', 1),
#   ('precisam ser', 1),
#   ('ser homologados', 1)],
#  'Ferreiro armador na construção civil': [('ter ensino', 1),
#   ('ensino fundamental', 1),
#   ('fundamental completo', 1),
#   ('completo desejavel', 1),
#   ('desejavel ensino', 1),
#   ('ensino medio', 1),
#   ('medio saber', 1),
#   ('saber ler', 1),
#   ('ler interpretar', 1),
#   ('interpretar desenhos', 1)],
#  'Operador de prensa': [('vagas operador', 1),
#   ('operador prensa', 1),
#   ('prensa sexo', 1),
#   ('sexo masculinofaixa', 1),
#   ('masculinofaixa etaria', 1),
#   ('etaria indiferentecom', 1),
#   ('indiferentecom experiencia2', 1),
#   ('experiencia2 grau', 1),
#   ('grau completo', 1),
#   ('completo ter', 1)],
#  'Instalador de material isolante, a mão (edificações)': [('instalacao forros',
#    1),
#   ('forros edificacoes', 1)]}

# %% [markdown]
# # Preparando os resultados para salvar em BD

# %%
maisProcuradas = pd.DataFrame(top_10_ocup, columns=['pretensao'])

# %%
maisProcuradasComCursos = pd.DataFrame(top_10_ocup_com_cursos, columns=['pretensao'])

# %%
def flat_caracteristicas(data):
    flat = [[(k, v) for v in vs] for k, vs in data.items()]
    flat2 = []
    for i in flat:
        for j in i:
            try:
                flat2.append([j[0], j[1][0], j[1][1]])
            except:
                flat2.append([j[0], '', ''])
    return flat2

# %%
 flatten_top_caracteristicas = flat_caracteristicas(top_caracteristicas)

# %%
topCaracteristicasConcorrentes = pd.DataFrame.from_records(flatten_top_caracteristicas, columns=['pretensao', 'caracteristica', 'ocorrencias'])

# %%
topCaracteristicasConcorrentes
# Out:
#                         pretensao           caracteristica  ocorrencias
# 0   Auxiliar de linha de produção       informatica basica        50907
# 1   Auxiliar de linha de produção    operador empilhadeira        10800
# 2   Auxiliar de linha de produção       informatica basico         9485
# 3   Auxiliar de linha de produção             ensino medio         7290
# 4   Auxiliar de linha de produção  auxiliar administrativo         4000
# ..                            ...                      ...          ...
# 95        Atendente de lanchonete       gestao empresarial          854
# 96        Atendente de lanchonete       controlador acesso          817
# 97        Atendente de lanchonete      atendimento cliente          771
# 98        Atendente de lanchonete                ens medio          695
# 99        Atendente de lanchonete            pacote office          694
#
# [100 rows x 3 columns]

# %%
flatten_top_outras_caracteristicas = []
for ks, vs in top_outras_caracteristicas.items():
    for kk, vv in vs.items():
        for k, v in vv.items():
            flatten_top_outras_caracteristicas.append(list((ks, kk, k, round(v,3))))

# %%
topOutrasCaracteristicasConcorrentes = pd.DataFrame.from_records(flatten_top_outras_caracteristicas, columns=['pretensao', 'caracteristica', 'valor','proporcao'])

# %%
topOutrasCaracteristicasConcorrentes
# Out:
#              pretensao       caracteristica                 valor  proporcao
# 0    Operador de caixa         ESCOLARIDADE        Médio Completo      0.785
# 1    Operador de caixa         ESCOLARIDADE      Médio Incompleto      0.103
# 2    Operador de caixa         ESCOLARIDADE  Fundamental Completo      0.042
# 3    Operador de caixa         ESCOLARIDADE   Superior Incompleto      0.033
# 4    Operador de caixa         ESCOLARIDADE     Superior Completo      0.015
# ..                 ...                  ...                   ...        ...
# 245         Estoquista          DISP_VIAJAR                     S      0.239
# 246         Estoquista      DISP_DORMIR_EMP                     N      0.783
# 247         Estoquista      DISP_DORMIR_EMP                     S      0.217
# 248         Estoquista  DISP_AUSENTAR_DOMIC                     N      0.791
# 249         Estoquista  DISP_AUSENTAR_DOMIC                     S      0.209
#
# [250 rows x 4 columns]

# %%
flatten_top_exigencias = flat_caracteristicas(top_exigencias)

# %%
topExigenciasVagas = pd.DataFrame.from_records(flatten_top_caracteristicas, columns=['pretensao', 'caracteristica', 'ocorrencias'])

# %% [markdown]
# # Salvando os resultados no banco SQLite

# %%
conn = sqlite3.connect('coronathon_db.sqlite')

# %%
cur = conn.cursor()

# %%
cur.execute('CREATE TABLE pre_maisprocuradas (pretensao VARCHAR)')
conn.commit()

# %%
maisProcuradas.to_sql(name='pre_maisprocuradas', con=conn, if_exists='replace')

# %%
maisProcuradasComCursos.to_sql(name='pre_maisProcuradasComCursos', con=conn, if_exists='replace')

# %%
topCaracteristicasConcorrentes.to_sql(name='pre_topCaracteristicasConcorrentes', con=conn, if_exists='replace')

# %%
topOutrasCaracteristicasConcorrentes.to_sql(name='pre_topOutrasCaracteristicasConcorrentes', con=conn, if_exists='replace')

# %%
topExigenciasVagas.to_sql(name='pre_topExigenciasVagas', con=conn, if_exists='replace')

# %%
cur.execute("SELECT name, sql FROM sqlite_master WHERE type='table' ORDER BY name;")
print(cur.fetchall())
# Out:
# [('pre_maisProcuradasComCursos', 'CREATE TABLE "pre_maisProcuradasComCursos" (\n"index" INTEGER,\n  "pretensao" TEXT\n)'), ('pre_maisprocuradas', 'CREATE TABLE "pre_maisprocuradas" (\n"index" INTEGER,\n  "pretensao" TEXT\n)'), ('pre_topCaracteristicasConcorrentes', 'CREATE TABLE "pre_topCaracteristicasConcorrentes" (\n"index" INTEGER,\n  "pretensao" TEXT,\n  "caracteristica" TEXT,\n  "ocorrencias" INTEGER\n)'), ('pre_topExigenciasVagas', 'CREATE TABLE "pre_topExigenciasVagas" (\n"index" INTEGER,\n  "pretensao" TEXT,\n  "caracteristica" TEXT,\n  "ocorrencias" INTEGER\n)'), ('pre_topOutrasCaracteristicasConcorrentes', 'CREATE TABLE "pre_topOutrasCaracteristicasConcorrentes" (\n"index" INTEGER,\n  "pretensao" TEXT,\n  "caracteristica" TEXT,\n  "valor" TEXT,\n  "proporcao" REAL\n)')]

# %%
def to_csv():
    db = sqlite3.connect('coronathon_db.sqlite')
    cursor = db.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()
    for table_name in tables:
        table_name = table_name[0]
        table = pd.read_sql_query("SELECT * from %s" % table_name, db)
        table.to_csv(table_name + '.csv', index_label='index')
    cursor.close()
    db.close()

# %%
to_csv()
