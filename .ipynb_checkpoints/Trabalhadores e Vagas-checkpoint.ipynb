# %% [markdown]
# # Importando as libraries

# %%
import os
import pandas as pd
import numpy as np
import re
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
import unicodedata
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm
from nltk.stem import SnowballStemmer
from nltk.stem import RSLPStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split, GridSearchCV
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import glob

# %%
import sqlite3

# %%
#nltk.download('stopwords')
#nltk.download('punkt')

# %% [markdown]
# # Lendo e salvando todos os arquivos de trabalhadores em um único dataframe

# %%
path = r'SINE/Trabalhadores' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, sep=";", encoding='iso-8859-1')
    li.append(df)

trabalhadores = pd.concat(li, axis=0, ignore_index=True)

# %% [markdown]
# # Criando todo o framework para o preprocessamento

# %%
def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

# %%
CONTRACTION_MAP = {
    "d'aquela": "de aquela",
    "d'aquella": "de aquela",
    "d'aquellas": "de aquelas",
    "d'aquelle": "de aquele",
    "d'aquelles": "de aqueles",
    "d'aquillo": "de aquilo",
    'daquela': "de aquela",
    'daquelas': "de aquelas",
    'daquele': "de aquele",
    'daqueles': "de aqueles",
    'daquella': "de aquela",
    'daquelle': "de aquele",
    'daquelles': "de aquela",
    'daqueloutro': "de aquele outro",
    'daquillo': "de aquilo",
    'daquilo': "de aquilo",
    "n'aquella": "em aquela",
    "n'aquellas": "em aquelas",
    "n'aquelle": "em aquele",
    "n'aquelles": "em aqueles",
    "n'aquillo": "em aquilo",
    'naquela': "em aquela",
    'naquelas': "em aquelas",
    'naquele': "em aquele",
    'naqueles': "em aqueles",
    'naquella': "em aquela",
    'naquelle': "em aquele",
    'naquilo': "em aquilo",
    "d'essa": "de essa",
    "d'essas": "de essas",
    "d'esse": "de esse",
    "d'esses": "de essa",
    "d'esta": "de esta",
    "d'estas": "de estas",
    "d'este": "de este",
    "d'estes": "de estes",
    'dessa': "de essa",
    'dessas': "de essas",
    'desses': "de esses",
    'desta': "de esta",
    'destas': "de estas",
    'deste': "de este",
    'destes': "de estes",
    "n'essa": "em essa",
    "n'essas": "em essas",
    "n'esse": "em esse",
    "n'esses": "em esses",
    "n'esta": "em esta",
    "n'estas": "em estas",
    "n'este": "em este",
    "n'estes": "em estes",
    'nessa': "em essa",
    'nessas': "em essas",
    'nesse': "em esse",
    'nesses': "em esses",
    'nesta': "em esta",
    'nestas': "em estas",
    'neste': "em este",
    'nestes': "em estes",
    "d'isso": "de isso",
    "d'isto": "de isto",
    'disso': "de isso",
    'disto': "de isto",
    "n'isso": "em isso",
    "n'isto": "em isto",
    'nisso': "em isso",
    'nisto': "em isto"
}

# %%
def expand_contractions(text, contraction_mapping=CONTRACTION_MAP):
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), flags=re.IGNORECASE|re.DOTALL)
    
    def expand_match(contraction):
        match = contraction.group(0)
        expanded_contraction = contraction_mapping.get(match) if contraction_mapping.get(match) else contraction_mapping.get(match.lower())
        expanded_contraction = expanded_contraction[0:]
        return expanded_contraction
    
    expanded_text = contractions_pattern.sub(expand_match, text)
    return expanded_text

# %%
def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-z0-9\s\-]' if not remove_digits else r'[^a-zA-z\s\-]'
    text = re.sub(pattern, '', text)
    return text

# %%
def caseconversion(text, case_type = 'lower'):
    if case_type == 'lower':
        text = text.lower()
    elif case_type == 'upper':
        text = text.upper()
    elif case_type == 'title':
        text = text.title()
    return text

# %%
def simple_stemmer(text, stemmer='RSLP'):
    ps = RSLPStemmer()
    if stemmer=='Snowball':
        ps = SnowballStemmer("portuguese")
    text = ' '.join([ps.stem(word) for word in text.split()])
    return text

# %%
stopword_list = nltk.corpus.stopwords.words('portuguese')
new_stopwords = ['ate', 'até', 'ano', 'vai', 'sera', 'será']
stopword_list.extend(new_stopwords)

# %%
def remove_stopwords(text, is_lower_case=False):
    tokens = nltk.word_tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

# %%
def preprocess_corpus(corpus, contraction_expansion=True, accented_char_removal=True, 
                     text_lower_case=True, stem_or_lemma='stem', special_char_removal=True, stopword_removal=True, 
                     remove_digits=False):
    preprocessed_corpus = []
    # preprocess each document in the corpus
    for doc in tqdm(corpus):
        # remove accented characters
        if accented_char_removal:
            doc = remove_accented_chars(doc)
        # expand contractions
        if contraction_expansion:
            doc = expand_contractions(doc)
        # lowercase the text
        if text_lower_case:
            doc = doc.lower()
        # remove extra newlines
            doc = re.sub(r'[\r|\n|\r\n]+', ' ',doc)
        # lemmatize or stem text
#         if stem_or_lemma == 'stem':
#             doc = simple_stemmer(doc, stemmer='RSLP')
#         elif stem_or_lemma == 'lemma':
#             doc = lemmatize_text(doc)
#         else doc = doc
        # remove special characters and\or digits
        if special_char_removal:
            # insert spaces between special characters to isolate them
            special_char_pattern = re.compile(r'([{.(-)!}])')
            doc = special_char_pattern.sub(" \\1 ", doc)
            doc = remove_special_characters(doc, remove_digits=remove_digits)
        # remove extra whitespace
        doc = re.sub(' +', ' ', doc)
        # remove stopwords
        if stopword_removal:
            doc = remove_stopwords(doc, is_lower_case=text_lower_case)
        preprocessed_corpus.append(doc)
    return preprocessed_corpus

# %% [markdown]
# # Criando um dataframe apenas com trabalhadores que cadastraram cursos profissionalizantes

# %%
trab_com_cursos = trabalhadores[trabalhadores.CURSOS_PROFISSIONALIZANTES.notnull()]

# %% [markdown]
# # Explodindo o campo PRETENSOES em linhas diferentes linhas, caso o trabalhador possua mais de um CBO cadastrado.

# %%
trab_com_cursos.PRETENSOES = trab_com_cursos.PRETENSOES.str.split('|')
trab_com_cursos = trab_com_cursos.explode('PRETENSOES')

# %% [markdown]
# # Removendo os registros com o campo PRETENSOES nulo

# %%
trab_com_cursos = trab_com_cursos[trab_com_cursos.PRETENSOES.notnull()]

# %% [markdown]
# # Criando um campo com Código da Ocupação a partir do campo PRETENSOES

# %%
trab_com_cursos['cod_ocupacao'] = trab_com_cursos.PRETENSOES.str.split('-').apply(lambda x:x[0])

# %%
trab_com_cursos['pretensao'] = trab_com_cursos.PRETENSOES.str.split('(').apply(lambda x:x[0])
trab_com_cursos['pretensao'] = trab_com_cursos.pretensao.str.split('-').apply(lambda x:x[1])

# %%
trabalhadores.PRETENSOES = trabalhadores.PRETENSOES.astype(str)

# %%
trabalhadores['pretensao'] = trabalhadores.PRETENSOES.str.split('(').apply(lambda x:x[0])
trabalhadores['pretensao'] = trabalhadores.pretensao.str.split('-').apply(lambda x:x[1] if len(x)>1 else x[0])

# %%
trab_com_cursos.head(3)
# Out:
#   NACIONALIDADE DEFICIENCIAS BAIRRO        CEP CODIGO_MUNICIPIO_IBGE  \
# 1    BRASILEIRA          NaN    NaN  4.285e+07                291005
# 1    BRASILEIRA          NaN    NaN  4.285e+07                291005
# 1    BRASILEIRA          NaN    NaN  4.285e+07                291005
#
#   NOME_MUNICIPIO  UF    ESCOLARIDADE ESTUDANTE CURSOS_PROFISSIONALIZANTES  \
# 1   DIAS D AVILA  BA  Médio Completo         N                  vigilante
# 1   DIAS D AVILA  BA  Médio Completo         N                  vigilante
# 1   DIAS D AVILA  BA  Médio Completo         N                  vigilante
#
#    ... IDIOMAS HABILITACAO VEICULOS DISP_VIAJAR DISP_DORMIR_EMP  \
# 1  ...     NaN          AB        N           N               N
# 1  ...     NaN          AB        N           N               N
# 1  ...     NaN          AB        N           N               N
#
#   DISP_AUSENTAR_DOMIC                                     PRETENSOES  \
# 1                   N         414110-Armazenista(N,16,0,Indiferente)
# 1                   N    716610-Pintor de obras(N,176,0,Indiferente)
# 1                   N  717020-Ajudante de obras(N,19,10,Indiferente)
#
#   MUNICIPIOS_INTERESSE cod_ocupacao          pretensao
# 1                  NaN       414110        Armazenista
# 1                  NaN       716610    Pintor de obras
# 1                  NaN       717020  Ajudante de obras
#
# [3 rows x 22 columns]

# %%
trabalhadores.head(3)
# Out:
#   NACIONALIDADE DEFICIENCIAS       BAIRRO          CEP CODIGO_MUNICIPIO_IBGE  \
# 0      IGNORADO          NaN          NaN  4.15001e+07                292740
# 1    BRASILEIRA          NaN          NaN    4.285e+07                291005
# 2    BRASILEIRA          NaN  BOCA DO RIO  4.17107e+07                292740
#
#   NOME_MUNICIPIO  UF    ESCOLARIDADE ESTUDANTE CURSOS_PROFISSIONALIZANTES  \
# 0       SALVADOR  BA  Médio Completo         N                        NaN
# 1   DIAS D AVILA  BA  Médio Completo         N                  vigilante
# 2       SALVADOR  BA  Médio Completo         N      ROTINAS DE ESCRITORIO
#
#    ... POS_GRADUACOES IDIOMAS HABILITACAO VEICULOS DISP_VIAJAR  \
# 0  ...            NaN     NaN      Nenhum        N           N
# 1  ...            NaN     NaN          AB        N           N
# 2  ...            NaN     NaN          AB        N           N
#
#   DISP_DORMIR_EMP DISP_AUSENTAR_DOMIC  \
# 0               N                   N
# 1               N                   N
# 2               N                   N
#
#                                           PRETENSOES MUNICIPIOS_INTERESSE  \
# 0  513505-Auxiliar nos serviços de alimentação(N,...                  NaN
# 1  414110-Armazenista(N,16,0,Indiferente)|716610-...                  NaN
# 2  354810-Operador de turismo(N,5,0,Indiferente)|...                  NaN
#
#                               pretensao
# 0  Auxiliar nos serviços de alimentação
# 1                           Armazenista
# 2                   Operador de turismo
#
# [3 rows x 21 columns]

# %%
#trab_com_cursos.to_pickle("./trabalhadores.pkl")

# %%
# trab_com_cursos = pd.read_pickle("./trabalhadores.pkl")

# %% [markdown]
# # Extraindo as 10 principais ocupações procuradas (com cursos)

# %%
top_10_ocup_com_cursos = list(trab_com_cursos.pretensao.value_counts().index[:10])

# %%
top_10_ocup_com_cursos
# Out:
# ['Auxiliar de linha de produção',
#  'Operador de caixa',
#  'Auxiliar de limpeza',
#  'Recepcionista atendente',
#  'Auxiliar administrativo',
#  'Repositor de mercadorias',
#  'Vendedor interno',
#  'Assistente administrativo',
#  'Porteiro',
#  'Operador de telemarketing ativo e receptivo']

# %%
print(f'As ocupações mais procuradas pelos trabalhadores são: {top_10_ocup_com_cursos}')
# Out:
# As ocupações mais procuradas pelos trabalhadores são: ['Auxiliar de linha de produção', 'Operador de caixa', 'Auxiliar de limpeza', 'Recepcionista atendente', 'Auxiliar administrativo', 'Repositor de mercadorias', 'Vendedor interno', 'Assistente administrativo', 'Porteiro', 'Operador de telemarketing ativo e receptivo']

# %% [markdown]
# # Criando o corpus apenas para a principal ocupação

# %%
corpus = trab_com_cursos.loc[trab_com_cursos.pretensao == top_10_ocup_com_cursos[0],'CURSOS_PROFISSIONALIZANTES'].copy()

# %%
corpus = preprocess_corpus(corpus)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 322456/322456 [01:45<00:00, 3053.36it/s]

# %%
def get_top_n_words(corpus, n=10, n_gram=2):
    """
    List the top n words in a vocabulary according to occurrence in a text corpus.
    
    get_top_n_words(["I love Python", "Python is a language programming", "Hello world", "I love the world"]) -> 
    [('python', 2),
     ('world', 2),
     ('love', 2),
     ('hello', 1),
     ('is', 1),
     ('programming', 1),
     ('the', 1),
     ('language', 1)]
    """
    vec = CountVectorizer(ngram_range=(n_gram,n_gram)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
t = get_top_n_words(corpus)

# %%
t
# Out:
# [('informatica basica', 85465),
#  ('operador empilhadeira', 17913),
#  ('informatica basico', 10569),
#  ('auxiliar administrativo', 8300),
#  ('ensino medio', 8097),
#  ('mecanica basica', 6732),
#  ('seguranca trabalho', 6507),
#  ('controlador acesso', 4282),
#  ('atendimento cliente', 4196),
#  ('informatica avancada', 4134)]

# %% [markdown]
# # Agora, para as 10 ocupações com maior procura, vamos rodar e gravar os resultados. Quais são as características dos candidatos à mesma ocupação?

# %%
top_caracteristicas = {}

# %%
for job in top_10_ocup_com_cursos:
    corpus = trab_com_cursos.loc[trab_com_cursos.pretensao == job,'CURSOS_PROFISSIONALIZANTES'].copy()
    corpus = preprocess_corpus(corpus)
    top_caracteristicas[job] = get_top_n_words(corpus)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 322456/322456 [01:49<00:00, 2956.00it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 198904/198904 [01:05<00:00, 3046.08it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 189689/189689 [00:57<00:00, 3290.73it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 169051/169051 [00:55<00:00, 3063.06it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 156776/156776 [00:50<00:00, 3100.17it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 128422/128422 [00:39<00:00, 3230.81it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 127537/127537 [00:41<00:00, 3062.63it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 104219/104219 [00:37<00:00, 2810.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 97007/97007 [00:29<00:00, 3235.02it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 96358/96358 [00:36<00:00, 2623.30it/s]

# %%
top_caracteristicas
# Out:
# {'Auxiliar de linha de produção': [('informatica basica', 85465),
#   ('operador empilhadeira', 17913),
#   ('informatica basico', 10569),
#   ('auxiliar administrativo', 8300),
#   ('ensino medio', 8097),
#   ('mecanica basica', 6732),
#   ('seguranca trabalho', 6507),
#   ('controlador acesso', 4282),
#   ('atendimento cliente', 4196),
#   ('informatica avancada', 4134)],
#  'Operador de caixa': [('informatica basica', 67146),
#   ('auxiliar administrativo', 9424),
#   ('informatica basico', 8777),
#   ('operador caixa', 7821),
#   ('atendimento cliente', 5965),
#   ('ensino medio', 4666),
#   ('tecnico enfermagem', 4230),
#   ('atendente farmacia', 4021),
#   ('tecnico administracao', 3868),
#   ('assistente administrativo', 3818)],
#  'Auxiliar de limpeza': [('informatica basica', 43458),
#   ('ensino medio', 7085),
#   ('informatica basico', 6152),
#   ('ensino fundamental', 5023),
#   ('controlador acesso', 4124),
#   ('serie ensino', 3892),
#   ('auxiliar administrativo', 3541),
#   ('cuidador idosos', 3395),
#   ('parou serie', 2889),
#   ('cursou serie', 2627)],
#  'Recepcionista atendente': [('informatica basica', 54651),
#   ('auxiliar administrativo', 8134),
#   ('informatica basico', 7121),
#   ('atendimento cliente', 4764),
#   ('ensino medio', 4633),
#   ('tecnico administracao', 3981),
#   ('tecnico enfermagem', 3944),
#   ('operador caixa', 3493),
#   ('assistente administrativo', 3458),
#   ('seguranca trabalho', 3338)],
#  'Auxiliar administrativo': [('informatica basica', 40179),
#   ('auxiliar administrativo', 10309),
#   ('tecnico administracao', 6878),
#   ('informatica basico', 4769),
#   ('seguranca trabalho', 4146),
#   ('assistente administrativo', 3915),
#   ('ensino medio', 3876),
#   ('informatica avancada', 3653),
#   ('pacote office', 3601),
#   ('recursos humanos', 3523)],
#  'Repositor de mercadorias': [('informatica basica', 36489),
#   ('informatica basico', 5081),
#   ('ensino medio', 4828),
#   ('operador empilhadeira', 3858),
#   ('auxiliar administrativo', 3528),
#   ('atendimento cliente', 1963),
#   ('controlador acesso', 1914),
#   ('seguranca trabalho', 1883),
#   ('informatica avancada', 1793),
#   ('operador caixa', 1599)],
#  'Vendedor interno': [('informatica basica', 42312),
#   ('auxiliar administrativo', 5999),
#   ('informatica basico', 3942),
#   ('atendimento cliente', 3729),
#   ('operador caixa', 3114),
#   ('seguranca trabalho', 3001),
#   ('informatica avancada', 2824),
#   ('tecnico enfermagem', 2630),
#   ('atendente farmacia', 2561),
#   ('ensino medio', 2492)],
#  'Assistente administrativo': [('informatica basica', 23855),
#   ('auxiliar administrativo', 5445),
#   ('tecnico administracao', 5041),
#   ('assistente administrativo', 4846),
#   ('departamento pessoal', 3263),
#   ('seguranca trabalho', 3236),
#   ('recursos humanos', 3155),
#   ('informatica basico', 2830),
#   ('pacote office', 2736),
#   ('atendimento cliente', 2642)],
#  'Porteiro': [('informatica basica', 17676),
#   ('controlador acesso', 6739),
#   ('operador empilhadeira', 4707),
#   ('informatica basico', 2758),
#   ('ensino medio', 2436),
#   ('formacao vigilante', 2074),
#   ('seguranca trabalho', 1840),
#   ('bombeiro civil', 1577),
#   ('porteiro vigilante', 1537),
#   ('basica vigilante', 1473)],
#  'Operador de telemarketing ativo e receptivo': [('informatica basica', 28705),
#   ('auxiliar administrativo', 4054),
#   ('informatica basico', 3143),
#   ('ensino medio', 2994),
#   ('tecnico enfermagem', 2477),
#   ('atendimento cliente', 2374),
#   ('tecnico administracao', 1932),
#   ('informatica avancada', 1924),
#   ('seguranca trabalho', 1868),
#   ('assistente administrativo', 1578)]}

# %% [markdown]
# # Quais são as demais características dos candidatos à mesma função?

# %%
top_outras_caracteristicas = {}

# %% [markdown]
# Vamos obter as 10 ocupações com maior procura, com ou sem cursos.

# %%
top_10_ocup = list(trabalhadores.pretensao.value_counts().index[:10])

# %%
for job in tqdm(top_10_ocup):
    temp_trab = trabalhadores[trabalhadores.pretensao == job]
    top_outras_caracteristicas[job] = {'ESCOLARIDADE': (temp_trab.ESCOLARIDADE.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict(),
                                       'POS_GRADUACOES': (temp_trab.POS_GRADUACOES.isna().value_counts()/temp_trab.shape[0]).to_dict(),
                                       'IDIOMAS': (temp_trab.IDIOMAS.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict(),
                                       'HABILITACAO': (temp_trab.HABILITACAO.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict(),
                                       'VEICULOS': (temp_trab.VEICULOS.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict(),
                                       'DISP_VIAJAR': (temp_trab.DISP_VIAJAR.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict(),
                                       'DISP_DORMIR_EMP': (temp_trab.DISP_DORMIR_EMP.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict(),
                                       'DISP_AUSENTAR_DOMIC': (temp_trab.DISP_AUSENTAR_DOMIC.value_counts(dropna=False)[:5]/temp_trab.shape[0]).to_dict()
                                       }
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:01<00:00,  6.19s/it]

# %%
top_outras_caracteristicas
# Out:
# {'Operador de caixa': {'ESCOLARIDADE': {'Médio Completo': 0.7606047401625523,
#    'Médio Incompleto': 0.11340014777485175,
#    'Fundamental Completo': 0.04265009567474376,
#    'Superior Incompleto': 0.03773184548055245,
#    'Fundamental Incompleto': 0.019475967641096565},
#   'POS_GRADUACOES': {True: 0.9996892939014456, False: 0.0003107060985544588},
#   'IDIOMAS': {nan: 0.9724570410927761,
#    'Inglês Básico': 0.011310459807134873,
#    'Espanhol Básico': 0.002913816948638766,
#    'Inglês Intermediário': 0.0022734592577155523,
#    'Francês Avançado': 0.0018187674061724418},
#   'HABILITACAO': {'Nenhum': 0.8825909857340432,
#    'AB': 0.06261864615501203,
#    'B': 0.04388155277267302,
#    'A': 0.005346418354394407,
#    'AD': 0.0023681867267870338},
#   'VEICULOS': {'N': 0.9771517344599587, 'S': 0.022848265540041303},
#   'DISP_VIAJAR': {'N': 0.8023568194304984, 'S': 0.19764318056950153},
#   'DISP_DORMIR_EMP': {'N': 0.82816058200557, 'S': 0.17183941799443003},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.8300892332758654, 'S': 0.16991076672413466}},
#  'Auxiliar administrativo': {'ESCOLARIDADE': {'Médio Completo': 0.5902610454046958,
#    'Médio Incompleto': 0.18544293734176442,
#    'Superior Incompleto': 0.11988600922200071,
#    'Superior Completo': 0.05838561987581691,
#    'Fundamental Incompleto': 0.027433617494893654},
#   'POS_GRADUACOES': {True: 0.9982754614058047, False: 0.0017245385941952764},
#   'IDIOMAS': {nan: 0.9188814552985735,
#    'Inglês Básico': 0.034437771879828605,
#    'Inglês Intermediário': 0.012899385607645046,
#    'Espanhol Básico': 0.005940077380005952,
#    'Inglês Básico|Espanhol Básico': 0.005495692730437902},
#   'HABILITACAO': {'Nenhum': 0.84184391091107,
#    'AB': 0.07878246759865136,
#    'B': 0.06679223590709507,
#    'A': 0.004113615701047362,
#    'AD': 0.0038119233701479514},
#   'VEICULOS': {'N': 0.964265766481982, 'S': 0.035734233518017966},
#   'DISP_VIAJAR': {'N': 0.7568237505249039, 'S': 0.2431762494750961},
#   'DISP_DORMIR_EMP': {'N': 0.7839515987655076, 'S': 0.2160484012344924},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.7850238296172176, 'S': 0.21497617038278233}},
#  'Auxiliar de escritório': {'ESCOLARIDADE': {'Médio Completo': 0.6674666169048435,
#    'Superior Incompleto': 0.10202620307163533,
#    'Superior Completo': 0.09708763143847833,
#    'Médio Incompleto': 0.0838515651105971,
#    'Fundamental Completo': 0.026845346329269933},
#   'POS_GRADUACOES': {True: 0.998606958265164, False: 0.0013930417348360247},
#   'IDIOMAS': {nan: 0.9629824112207125,
#    'Inglês Básico': 0.016824993164982142,
#    'Inglês Intermediário': 0.00577613255160981,
#    'Espanhol Básico': 0.0032677894901293665,
#    'Inglês Básico|Espanhol Básico': 0.0028034422451840247},
#   'HABILITACAO': {'Nenhum': 0.8098736715112116,
#    'AB': 0.1041613324596083,
#    'B': 0.071231735313391,
#    'AD': 0.004769323571915237,
#    'A': 0.004478564082089649},
#   'VEICULOS': {'N': 0.9697870512214068, 'S': 0.03021294877859316},
#   'DISP_VIAJAR': {'N': 0.8549630909035677, 'S': 0.14503690909643233},
#   'DISP_DORMIR_EMP': {'N': 0.8805369069265854, 'S': 0.1194630930734146},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.8810359717225547, 'S': 0.1189640282774453}},
#  'Vendedor de comércio varejista': {'ESCOLARIDADE': {'Médio Completo': 0.7484167338780376,
#    'Médio Incompleto': 0.07760984675807413,
#    'Fundamental Completo': 0.049752779044078974,
#    'Superior Incompleto': 0.046659887084896726,
#    'Superior Completo': 0.04382648946242592},
#   'POS_GRADUACOES': {True: 0.9995721850124487, False: 0.0004278149875512852},
#   'IDIOMAS': {nan: 0.9948171266262229,
#    'Inglês Básico': 0.0020268611705298594,
#    'Inglês Intermediário': 0.0007714696496826455,
#    'Espanhol Básico': 0.0004558684293579269,
#    'Inglês Básico|Espanhol Básico': 0.00037170810393800187},
#   'HABILITACAO': {'Nenhum': 0.8558403759161202,
#    'AB': 0.08333274888662903,
#    'B': 0.04147000035066802,
#    'AD': 0.00763053617140653,
#    'A': 0.0030648385173756005},
#   'VEICULOS': {'N': 0.985068555598415, 'S': 0.014931444401585019},
#   'DISP_VIAJAR': {'N': 0.9172142932286005, 'S': 0.08278570677139951},
#   'DISP_DORMIR_EMP': {'N': 0.9280078549637059, 'S': 0.07199214503629414},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.9295227408212645, 'S': 0.07047725917873549}},
#  'Assistente administrativo': {'ESCOLARIDADE': {'Médio Completo': 0.6150927589234648,
#    'Superior Completo': 0.1779295789397369,
#    'Superior Incompleto': 0.11803703912549642,
#    'Médio Incompleto': 0.054132867189199206,
#    'Fundamental Completo': 0.018632339554853834},
#   'POS_GRADUACOES': {True: 0.996616695800675, False: 0.0033833041993249504},
#   'IDIOMAS': {nan: 0.9615672753929063,
#    'Inglês Básico': 0.016368747935781663,
#    'Inglês Intermediário': 0.0060496701278405654,
#    'Espanhol Básico': 0.0028999750279928146,
#    'Inglês Básico|Espanhol Básico': 0.0027791427351597808},
#   'HABILITACAO': {'Nenhum': 0.7973884113775687,
#    'B': 0.0937497482660566,
#    'AB': 0.09089005066900813,
#    'AD': 0.006412167006339667,
#    'A': 0.004011632122056727},
#   'VEICULOS': {'N': 0.9723052384826686, 'S': 0.027694761517331377},
#   'DISP_VIAJAR': {'N': 0.867736972264961, 'S': 0.13226302773503895},
#   'DISP_DORMIR_EMP': {'N': 0.8890115112897639, 'S': 0.1109884887102361},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.8879159651680777, 'S': 0.11208403483192228}},
#  'Auxiliar de limpeza': {'ESCOLARIDADE': {'Médio Completo': 0.3915837626127175,
#    'Fundamental Incompleto': 0.201054559807305,
#    'Fundamental Completo': 0.1684664352437531,
#    'Médio Incompleto': 0.15427744436235566,
#    'Não Identificado': 0.07099555708488094},
#   'POS_GRADUACOES': {True: 0.9997874687528464, False: 0.00021253124715359936},
#   'IDIOMAS': {nan: 0.9864283617889059,
#    'Alemão Avançado': 0.002803388355311763,
#    'Inglês Básico': 0.00246941068121325,
#    'Francês Avançado': 0.0014269955166027386,
#    'Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado': 0.0013257901608153104},
#   'HABILITACAO': {'Nenhum': 0.8809723810584056,
#    'AB': 0.0518475037698995,
#    'B': 0.03651489236810412,
#    'AD': 0.0093108927324434,
#    'D': 0.008278598103411633},
#   'VEICULOS': {'N': 0.9765507190640529, 'S': 0.02344928093594713},
#   'DISP_VIAJAR': {'N': 0.7323118339422522, 'S': 0.26768816605774776},
#   'DISP_DORMIR_EMP': {'N': 0.7501138560252608, 'S': 0.24988614397473916},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.7605582487425234, 'S': 0.23944175125747655}},
#  'Faxineiro': {'ESCOLARIDADE': {'Médio Completo': 0.4460432398882797,
#    'Não Identificado': 0.1874211234095376,
#    'Fundamental Completo': 0.18425571532016138,
#    'Médio Incompleto': 0.12109237612496121,
#    'Fundamental Incompleto': 0.04062273714699493},
#   'POS_GRADUACOES': {True: 0.999968966587359, False: 3.1033412640943414e-05},
#   'IDIOMAS': {nan: 0.9979311058239371,
#    'Inglês Básico': 0.0005896348401779249,
#    'Alemão Avançado': 0.0002275783593669184,
#    'Inglês Intermediário': 0.00015516706320471707,
#    'Espanhol Básico': 0.0001448225923244026},
#   'HABILITACAO': {'Nenhum': 0.9399193131271335,
#    'AB': 0.03129202441295128,
#    'B': 0.01796834591910624,
#    'AD': 0.003444708803144719,
#    'A': 0.002803351608565222},
#   'VEICULOS': {'N': 0.9914244336402193, 'S': 0.008575566359780698},
#   'DISP_VIAJAR': {'N': 0.9103237819385538, 'S': 0.08967621806144616},
#   'DISP_DORMIR_EMP': {'N': 0.9192924381917865, 'S': 0.08070756180821351},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.9214544326057722, 'S': 0.07854556739422779}},
#  'nan': {'ESCOLARIDADE': {'Nenhum': 0.793100497406001,
#    'Médio Completo': 0.0743006899502594,
#    'Superior Completo': 0.03297855270899075,
#    'Superior Incompleto': 0.030935444188907313,
#    'Médio Incompleto': 0.024239182756591968},
#   'POS_GRADUACOES': {True: 0.993688827084559, False: 0.006311172915440979},
#   'IDIOMAS': {nan: 0.9717280847194737,
#    'Inglês Básico': 0.005209391881050436,
#    'Inglês Intermediário': 0.005209391881050436,
#    'Inglês Avançado': 0.0032732523934321015,
#    'Inglês Básico|Espanhol Básico': 0.00235331871423223},
#   'HABILITACAO': {'Nenhum': 0.9803925763491469,
#    'B': 0.009712788147831202,
#    'AB': 0.007584104401775686,
#    'A': 0.0007059956142696689,
#    'AD': 0.0005455420655720169},
#   'VEICULOS': {'N': 0.9898272450125689, 'S': 0.01017275498743114},
#   'DISP_VIAJAR': {'S': 0.9449965235064449, 'N': 0.055003476493555116},
#   'DISP_DORMIR_EMP': {'S': 0.9416483927902872, 'N': 0.05835160720971279},
#   'DISP_AUSENTAR_DOMIC': {'S': 0.9412526073701664,
#    'N': 0.05873669572658715,
#    nan: 1.0696903246510136e-05}},
#  'Estoquista': {'ESCOLARIDADE': {'Médio Completo': 0.656412139011258,
#    'Médio Incompleto': 0.17638277043563388,
#    'Fundamental Completo': 0.06576113558492414,
#    'Fundamental Incompleto': 0.0486784140969163,
#    'Superior Incompleto': 0.025624082232011746},
#   'POS_GRADUACOES': {True: 0.9997674987763093, False: 0.000232501223690651},
#   'IDIOMAS': {nan: 0.963228095937347,
#    'Inglês Básico': 0.015186000978952521,
#    'Inglês Intermediário': 0.0035364659813999022,
#    'Espanhol Básico': 0.0031938325991189426,
#    'Inglês Básico|Espanhol Básico': 0.0020802741067058247},
#   'HABILITACAO': {'Nenhum': 0.808565834557024,
#    'AB': 0.09678169358786098,
#    'B': 0.0604992657856094,
#    'AD': 0.011294664708761625,
#    'A': 0.009740577581987273},
#   'VEICULOS': {'N': 0.9653206069505629, 'S': 0.0346793930494371},
#   'DISP_VIAJAR': {'N': 0.7476627508565834, 'S': 0.25233724914341654},
#   'DISP_DORMIR_EMP': {'N': 0.7698482623592756, 'S': 0.2301517376407244},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.7782794909446892, 'S': 0.22172050905531082}},
#  'Empregado  doméstico  nos serviços gerais': {'ESCOLARIDADE': {'Fundamental Incompleto': 0.31785370857106227,
#    'Médio Completo': 0.2982370664786204,
#    'Fundamental Completo': 0.18416565164433618,
#    'Médio Incompleto': 0.13672671325084942,
#    'Não Identificado': 0.048541573177767805},
#   'POS_GRADUACOES': {True: 0.9998974293223925, False: 0.00010257067760753894},
#   'IDIOMAS': {nan: 0.9913840630809667,
#    'Francês Avançado': 0.0018334508622347586,
#    'Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado': 0.001641130841720623,
#    'Inglês Básico': 0.0011923841271876403,
#    'Espanhol Avançado': 0.0007564587473555997},
#   'HABILITACAO': {'Nenhum': 0.9339060196166421,
#    'AB': 0.028027437656260017,
#    'B': 0.02778383229694211,
#    'A': 0.004346432463619463,
#    'AD': 0.0022052695685620873},
#   'VEICULOS': {'N': 0.9792037951150715, 'S': 0.02079620488492852},
#   'DISP_VIAJAR': {'N': 0.7502532213603436, 'S': 0.24974677863965639},
#   'DISP_DORMIR_EMP': {'N': 0.7767805628565934, 'S': 0.22321943714340664},
#   'DISP_AUSENTAR_DOMIC': {'N': 0.7862298865311879, 'S': 0.2137701134688121}}}

# %%
for key, value in top_outras_caracteristicas.items():
    print('Ocupação:', key)
    for k, v in top_outras_caracteristicas[key].items():
        print('\n')
        print('Característica:', k)
        print('Distribuição percentual:\n')
        print(v)
# Out:
# Ocupação: Operador de caixa
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# {'Médio Completo': 0.7606047401625523, 'Médio Incompleto': 0.11340014777485175, 'Fundamental Completo': 0.04265009567474376, 'Superior Incompleto': 0.03773184548055245, 'Fundamental Incompleto': 0.019475967641096565}
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# {True: 0.9996892939014456, False: 0.0003107060985544588}
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# {nan: 0.9724570410927761, 'Inglês Básico': 0.011310459807134873, 'Espanhol Básico': 0.002913816948638766, 'Inglês Intermediário': 0.0022734592577155523, 'Francês Avançado': 0.0018187674061724418}
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# {'Nenhum': 0.8825909857340432, 'AB': 0.06261864615501203, 'B': 0.04388155277267302, 'A': 0.005346418354394407, 'AD': 0.0023681867267870338}
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# {'N': 0.9771517344599587, 'S': 0.022848265540041303}
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# {'N': 0.8023568194304984, 'S': 0.19764318056950153}
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# {'N': 0.82816058200557, 'S': 0.17183941799443003}
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# {'N': 0.8300892332758654, 'S': 0.16991076672413466}
# Ocupação: Auxiliar administrativo
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# {'Médio Completo': 0.5902610454046958, 'Médio Incompleto': 0.18544293734176442, 'Superior Incompleto': 0.11988600922200071, 'Superior Completo': 0.05838561987581691, 'Fundamental Incompleto': 0.027433617494893654}
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# {True: 0.9982754614058047, False: 0.0017245385941952764}
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# {nan: 0.9188814552985735, 'Inglês Básico': 0.034437771879828605, 'Inglês Intermediário': 0.012899385607645046, 'Espanhol Básico': 0.005940077380005952, 'Inglês Básico|Espanhol Básico': 0.005495692730437902}
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# {'Nenhum': 0.84184391091107, 'AB': 0.07878246759865136, 'B': 0.06679223590709507, 'A': 0.004113615701047362, 'AD': 0.0038119233701479514}
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# {'N': 0.964265766481982, 'S': 0.035734233518017966}
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# {'N': 0.7568237505249039, 'S': 0.2431762494750961}
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# {'N': 0.7839515987655076, 'S': 0.2160484012344924}
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# {'N': 0.7850238296172176, 'S': 0.21497617038278233}
# Ocupação: Auxiliar de escritório
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# {'Médio Completo': 0.6674666169048435, 'Superior Incompleto': 0.10202620307163533, 'Superior Completo': 0.09708763143847833, 'Médio Incompleto': 0.0838515651105971, 'Fundamental Completo': 0.026845346329269933}
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# {True: 0.998606958265164, False: 0.0013930417348360247}
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# {nan: 0.9629824112207125, 'Inglês Básico': 0.016824993164982142, 'Inglês Intermediário': 0.00577613255160981, 'Espanhol Básico': 0.0032677894901293665, 'Inglês Básico|Espanhol Básico': 0.0028034422451840247}
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# {'Nenhum': 0.8098736715112116, 'AB': 0.1041613324596083, 'B': 0.071231735313391, 'AD': 0.004769323571915237, 'A': 0.004478564082089649}
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# {'N': 0.9697870512214068, 'S': 0.03021294877859316}
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# {'N': 0.8549630909035677, 'S': 0.14503690909643233}
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# {'N': 0.8805369069265854, 'S': 0.1194630930734146}
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# {'N': 0.8810359717225547, 'S': 0.1189640282774453}
# Ocupação: Vendedor de comércio varejista
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# {'Médio Completo': 0.7484167338780376, 'Médio Incompleto': 0.07760984675807413, 'Fundamental Completo': 0.049752779044078974, 'Superior Incompleto': 0.046659887084896726, 'Superior Completo': 0.04382648946242592}
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# {True: 0.9995721850124487, False: 0.0004278149875512852}
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# {nan: 0.9948171266262229, 'Inglês Básico': 0.0020268611705298594, 'Inglês Intermediário': 0.0007714696496826455, 'Espanhol Básico': 0.0004558684293579269, 'Inglês Básico|Espanhol Básico': 0.00037170810393800187}
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# {'Nenhum': 0.8558403759161202, 'AB': 0.08333274888662903, 'B': 0.04147000035066802, 'AD': 0.00763053617140653, 'A': 0.0030648385173756005}
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# {'N': 0.985068555598415, 'S': 0.014931444401585019}
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# {'N': 0.9172142932286005, 'S': 0.08278570677139951}
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# {'N': 0.9280078549637059, 'S': 0.07199214503629414}
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# {'N': 0.9295227408212645, 'S': 0.07047725917873549}
# Ocupação: Assistente administrativo
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# {'Médio Completo': 0.6150927589234648, 'Superior Completo': 0.1779295789397369, 'Superior Incompleto': 0.11803703912549642, 'Médio Incompleto': 0.054132867189199206, 'Fundamental Completo': 0.018632339554853834}
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# {True: 0.996616695800675, False: 0.0033833041993249504}
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# {nan: 0.9615672753929063, 'Inglês Básico': 0.016368747935781663, 'Inglês Intermediário': 0.0060496701278405654, 'Espanhol Básico': 0.0028999750279928146, 'Inglês Básico|Espanhol Básico': 0.0027791427351597808}
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# {'Nenhum': 0.7973884113775687, 'B': 0.0937497482660566, 'AB': 0.09089005066900813, 'AD': 0.006412167006339667, 'A': 0.004011632122056727}
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# {'N': 0.9723052384826686, 'S': 0.027694761517331377}
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# {'N': 0.867736972264961, 'S': 0.13226302773503895}
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# {'N': 0.8890115112897639, 'S': 0.1109884887102361}
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# {'N': 0.8879159651680777, 'S': 0.11208403483192228}
# Ocupação: Auxiliar de limpeza
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# {'Médio Completo': 0.3915837626127175, 'Fundamental Incompleto': 0.201054559807305, 'Fundamental Completo': 0.1684664352437531, 'Médio Incompleto': 0.15427744436235566, 'Não Identificado': 0.07099555708488094}
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# {True: 0.9997874687528464, False: 0.00021253124715359936}
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# {nan: 0.9864283617889059, 'Alemão Avançado': 0.002803388355311763, 'Inglês Básico': 0.00246941068121325, 'Francês Avançado': 0.0014269955166027386, 'Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado': 0.0013257901608153104}
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# {'Nenhum': 0.8809723810584056, 'AB': 0.0518475037698995, 'B': 0.03651489236810412, 'AD': 0.0093108927324434, 'D': 0.008278598103411633}
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# {'N': 0.9765507190640529, 'S': 0.02344928093594713}
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# {'N': 0.7323118339422522, 'S': 0.26768816605774776}
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# {'N': 0.7501138560252608, 'S': 0.24988614397473916}
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# {'N': 0.7605582487425234, 'S': 0.23944175125747655}
# Ocupação: Faxineiro
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# {'Médio Completo': 0.4460432398882797, 'Não Identificado': 0.1874211234095376, 'Fundamental Completo': 0.18425571532016138, 'Médio Incompleto': 0.12109237612496121, 'Fundamental Incompleto': 0.04062273714699493}
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# {True: 0.999968966587359, False: 3.1033412640943414e-05}
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# {nan: 0.9979311058239371, 'Inglês Básico': 0.0005896348401779249, 'Alemão Avançado': 0.0002275783593669184, 'Inglês Intermediário': 0.00015516706320471707, 'Espanhol Básico': 0.0001448225923244026}
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# {'Nenhum': 0.9399193131271335, 'AB': 0.03129202441295128, 'B': 0.01796834591910624, 'AD': 0.003444708803144719, 'A': 0.002803351608565222}
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# {'N': 0.9914244336402193, 'S': 0.008575566359780698}
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# {'N': 0.9103237819385538, 'S': 0.08967621806144616}
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# {'N': 0.9192924381917865, 'S': 0.08070756180821351}
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# {'N': 0.9214544326057722, 'S': 0.07854556739422779}
# Ocupação: nan
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# {'Nenhum': 0.793100497406001, 'Médio Completo': 0.0743006899502594, 'Superior Completo': 0.03297855270899075, 'Superior Incompleto': 0.030935444188907313, 'Médio Incompleto': 0.024239182756591968}
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# {True: 0.993688827084559, False: 0.006311172915440979}
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# {nan: 0.9717280847194737, 'Inglês Básico': 0.005209391881050436, 'Inglês Intermediário': 0.005209391881050436, 'Inglês Avançado': 0.0032732523934321015, 'Inglês Básico|Espanhol Básico': 0.00235331871423223}
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# {'Nenhum': 0.9803925763491469, 'B': 0.009712788147831202, 'AB': 0.007584104401775686, 'A': 0.0007059956142696689, 'AD': 0.0005455420655720169}
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# {'N': 0.9898272450125689, 'S': 0.01017275498743114}
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# {'S': 0.9449965235064449, 'N': 0.055003476493555116}
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# {'S': 0.9416483927902872, 'N': 0.05835160720971279}
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# {'S': 0.9412526073701664, 'N': 0.05873669572658715, nan: 1.0696903246510136e-05}
# Ocupação: Estoquista
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# {'Médio Completo': 0.656412139011258, 'Médio Incompleto': 0.17638277043563388, 'Fundamental Completo': 0.06576113558492414, 'Fundamental Incompleto': 0.0486784140969163, 'Superior Incompleto': 0.025624082232011746}
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# {True: 0.9997674987763093, False: 0.000232501223690651}
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# {nan: 0.963228095937347, 'Inglês Básico': 0.015186000978952521, 'Inglês Intermediário': 0.0035364659813999022, 'Espanhol Básico': 0.0031938325991189426, 'Inglês Básico|Espanhol Básico': 0.0020802741067058247}
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# {'Nenhum': 0.808565834557024, 'AB': 0.09678169358786098, 'B': 0.0604992657856094, 'AD': 0.011294664708761625, 'A': 0.009740577581987273}
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# {'N': 0.9653206069505629, 'S': 0.0346793930494371}
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# {'N': 0.7476627508565834, 'S': 0.25233724914341654}
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# {'N': 0.7698482623592756, 'S': 0.2301517376407244}
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# {'N': 0.7782794909446892, 'S': 0.22172050905531082}
# Ocupação: Empregado  doméstico  nos serviços gerais
#
#
# Característica: ESCOLARIDADE
# Distribuição percentual:
#
# {'Fundamental Incompleto': 0.31785370857106227, 'Médio Completo': 0.2982370664786204, 'Fundamental Completo': 0.18416565164433618, 'Médio Incompleto': 0.13672671325084942, 'Não Identificado': 0.048541573177767805}
#
#
# Característica: POS_GRADUACOES
# Distribuição percentual:
#
# {True: 0.9998974293223925, False: 0.00010257067760753894}
#
#
# Característica: IDIOMAS
# Distribuição percentual:
#
# {nan: 0.9913840630809667, 'Francês Avançado': 0.0018334508622347586, 'Inglês Avançado|Espanhol Avançado|Francês Avançado|Italiano Avançado|Alemão Avançado': 0.001641130841720623, 'Inglês Básico': 0.0011923841271876403, 'Espanhol Avançado': 0.0007564587473555997}
#
#
# Característica: HABILITACAO
# Distribuição percentual:
#
# {'Nenhum': 0.9339060196166421, 'AB': 0.028027437656260017, 'B': 0.02778383229694211, 'A': 0.004346432463619463, 'AD': 0.0022052695685620873}
#
#
# Característica: VEICULOS
# Distribuição percentual:
#
# {'N': 0.9792037951150715, 'S': 0.02079620488492852}
#
#
# Característica: DISP_VIAJAR
# Distribuição percentual:
#
# {'N': 0.7502532213603436, 'S': 0.24974677863965639}
#
#
# Característica: DISP_DORMIR_EMP
# Distribuição percentual:
#
# {'N': 0.7767805628565934, 'S': 0.22321943714340664}
#
#
# Característica: DISP_AUSENTAR_DOMIC
# Distribuição percentual:
#
# {'N': 0.7862298865311879, 'S': 0.2137701134688121}

# %% [markdown]
# # Lendo e salvando todos os arquivos de vagas em um único dataframe

# %%
path = r'SINE/Vagas' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in tqdm(all_files):
    df = pd.read_csv(filename, sep=";", encoding='iso-8859-1', usecols = list(range(12)))
    li.append(df)

vagas = pd.concat(li, axis=0, ignore_index=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 27/27 [00:02<00:00, 10.32it/s]

# %% [markdown]
# # Eliminando todos os registros que possuem o campo OBSERVACOES_OCUPACAO nulo.

# %%
vagas_com_observacoes = vagas[vagas.OBSERVACOES_OCUPACAO.notnull()]

# %%
vagas_com_observacoes.shape
# Out:
# (1759, 12)

# %% [markdown]
# # Criando o corpus apenas para vagas da principal ocupação

# %%
todas_as_vagas = list(vagas_com_observacoes.TITULO_OCUPACAO.value_counts().index)

# %%
top_exigencias = {}

# %%
for job in todas_as_vagas:
    corpus_vagas = vagas_com_observacoes.loc[vagas_com_observacoes.TITULO_OCUPACAO == job,'OBSERVACOES_OCUPACAO'].copy()
    corpus_vagas = preprocess_corpus(corpus_vagas)
    try:
        top_exigencias[job] = get_top_n_words(corpus_vagas)
    except:
        top_exigencias[job] = 'Não existe vaga para essa ocupação.'
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 111/111 [00:00<00:00, 1293.69it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 49/49 [00:00<00:00, 893.22it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 1077.87it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 1144.76it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 38/38 [00:00<00:00, 1154.51it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 1032.27it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 1297.38it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 22/22 [00:00<00:00, 919.10it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 1114.02it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 1113.88it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 1727.55it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 1004.37it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 1061.79it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 1127.77it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 948.71it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 1311.35it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 1559.76it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 1002.70it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 1169.89it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 931.13it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 1453.37it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 1002.81it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 1629.34it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 1504.10it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 787.88it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 1378.67it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 1378.84it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 1225.92it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 1005.56it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 1253.42it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 911.55it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 1002.76it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 1289.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 1289.32it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 891.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1336.83it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1145.95it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1337.15it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 779.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 539.86it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 1169.73it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 877.39it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 779.88it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 1002.67it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 1169.96it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 1755.36it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1202.73it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1504.32it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 859.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1002.78it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 859.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1504.50it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1203.65it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 859.61it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1503.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 751.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1503.96it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1503.51it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1203.13it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 859.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1202.78it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1504.77it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1003.10it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1002.85it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 835.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 835.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1253.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1003.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 557.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1671.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 716.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 385.65it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1253.45it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1002.75it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 716.19it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 716.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 626.76it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 716.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1253.83it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 2005.88it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 802.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 668.52it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1336.72it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 802.20it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.52it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 802.20it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 802.12it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 802.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 802.09it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1336.62it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1336.30it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.52it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1323.23it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 801.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1976.35it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.76it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 2005.64it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1010.61it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1322.50it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1337.04it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1013.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 745.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1003.50it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 746.63it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1532.26it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1003.02it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 993.20it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1003.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.86it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 752.03it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 993.99it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1503.16it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 429.73it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.54it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 501.27it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 429.69it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.30it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1478.95it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1503.87it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.53it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 752.03it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 501.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.38it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1003.02it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 751.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 501.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1504.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1505.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 300.83it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 501.33it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 601.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.54it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.54it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.14it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 429.67it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 752.03it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.86it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 429.77it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1503.69it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1504.05it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 1002.54it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.52it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 941.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.06it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2007.80it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 845.54it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.35it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.06it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2005.88it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 914.49it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.63it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2005.88it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.30it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.30it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.79it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2006.84it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.82it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.58it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.50it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 400.77it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.06it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.08it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2006.36it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1001.74it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.36it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2005.40it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.95it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2005.88it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.84it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 500.99it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2005.88it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.79it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2005.88it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.20it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 2004.45it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 400.97it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.52it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 334.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.44it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 401.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.20it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.89it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.52it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 501.32it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 668.63it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1002.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.81it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.21it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.14it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.93it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.37it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.77it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.65it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.74it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.23it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.65it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.11it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.51it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.81it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.11it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.99it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.15it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.51it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.03it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.45it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.77it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 503.16it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.14it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 563.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.15it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.38it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.23it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.65it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.34it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.65it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.65it/s]
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.51it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.05it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.23it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.07it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.77it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.86it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.37it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.93it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.03it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.07it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.93it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 998.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 502.07it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.11it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.11it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.05it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.71it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.27it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.11it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1016.06it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1006.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.14it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.75it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1000.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.05it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.86it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.21it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.05it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 500.75it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.77it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.77it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]

# %%
top_exigencias
# Out:
# {'Auxiliar de linha de produção': [('vaga exclusiva', 15),
#   ('linha producao', 15),
#   ('pessoa deficiencia', 12),
#   ('auxiliar producao', 10),
#   ('linhas producao', 8),
#   ('disponibilidade trabalhar', 8),
#   ('exclusiva pcd', 7),
#   ('segunda sexta', 7),
#   ('area servico', 6),
#   ('segunda sabado', 6)],
#  'Vendedor pracista': [('experiencia vendas', 16),
#   ('ensino medio', 11),
#   ('medio completo', 11),
#   ('ter experiencia', 10),
#   ('necessario ter', 6),
#   ('vendas externas', 6),
#   ('cnh ab', 6),
#   ('segunda sexta', 5),
#   ('realizar vendas', 5),
#   ('horario comercial', 4)],
#  'Auxiliar administrativo': [('medio completo', 7),
#   ('ensino medio', 6),
#   ('auxiliar administrativo', 5),
#   ('pacote office', 5),
#   ('rotinas administrativas', 4),
#   ('enviar curriculo', 4),
#   ('segunda sexta', 4),
#   ('vaga exclusiva', 3),
#   ('exclusiva pcd', 3),
#   ('horario trabalho', 3)],
#  'Vendedor interno': [('ensino medio', 9),
#   ('medio completo', 9),
#   ('materiais construcao', 7),
#   ('experiencia vendas', 7),
#   ('segunda sexta', 5),
#   ('horario comercial', 5),
#   ('vaga trabalhar', 4),
#   ('ter experiencia', 4),
#   ('completo experiencia', 4),
#   ('cnh ab', 3)],
#  'Auxiliar de limpeza': [('vaga exclusiva', 6),
#   ('exclusiva pcd', 5),
#   ('ensino fundamental', 5),
#   ('fundamental completo', 5),
#   ('limpeza conservacao', 4),
#   ('vaga trabalhar', 4),
#   ('fazer limpeza', 3),
#   ('conservacao geral', 3),
#   ('limpeza higienizacao', 3),
#   ('limpeza escritorio', 3)],
#  'Empregado  doméstico  nos serviços gerais': [('lavar passar', 8),
#   ('ter experiencia', 7),
#   ('segunda sexta', 6),
#   ('fazer todo', 4),
#   ('passar roupas', 4),
#   ('experiencia comprovada', 4),
#   ('casa lavar', 3),
#   ('preparar refeicoes', 3),
#   ('experiencia referencias', 3),
#   ('ter referencias', 3)],
#  'Pedreiro': [('executar trabalhos', 4),
#   ('outros materiais', 4),
#   ('processos instrumentos', 4),
#   ('instrumentos pertinentes', 4),
#   ('pertinentes oficio', 4),
#   ('servicos pedreiro', 3),
#   ('materiais guiando', 3),
#   ('guiando se', 3),
#   ('trabalhos alvenaria', 3),
#   ('alvenaria concreto', 3)],
#  'Consultor de vendas': [('ensino medio', 5),
#   ('medio completo', 4),
#   ('vendas externas', 4),
#   ('cnh disponibilidade', 3),
#   ('experiencia vendas', 3),
#   ('realizar vendas', 3),
#   ('ambos sexos', 3),
#   ('encaminhar candidatos', 2),
#   ('candidatos ensino', 2),
#   ('completo experiencias', 2)],
#  'Servente de obras': [('ensino fundamental', 4),
#   ('fundamental completo', 3),
#   ('completo ter', 3),
#   ('ter experiencia', 3),
#   ('experiencia 06', 3),
#   ('06 meses', 3),
#   ('meses obra', 3),
#   ('obra porem', 3),
#   ('porem nao', 3),
#   ('nao sao', 3)],
#  'Soldador': [('ter experiencia', 5),
#   ('solda mig', 3),
#   ('candidato deve', 2),
#   ('servicos solda', 2),
#   ('mig tig', 2),
#   ('maquinas agricolas', 2),
#   ('agricolas industria', 2),
#   ('industria madeireira', 2),
#   ('pecas serem', 2),
#   ('eletrodo revestido', 2)],
#  'Motorista de caminhão': [('experiencia comprovada', 6),
#   ('comprovada carteira', 4),
#   ('motorista caminhao', 3),
#   ('ter cnh', 3),
#   ('carteira trabalho', 3),
#   ('necessario ter', 3),
#   ('imprimir carta', 2),
#   ('ira realizar', 2),
#   ('dirigir caminhao', 2),
#   ('fundamental completo', 2)],
#  'Empacotador, a mão': [('exclusiva pcd', 12),
#   ('vaga exclusiva', 11),
#   ('pcd programa', 7),
#   ('programa apoio', 6),
#   ('pessoa deficiencia', 6),
#   ('deficiencia ppd', 6),
#   ('embalar mercadorias', 6),
#   ('apoio pessoa', 5),
#   ('ppd ira', 5),
#   ('mercadorias compradas', 5)],
#  'Operador de caixa': [('fechamento caixa', 5),
#   ('ensino medio', 4),
#   ('recebimento valores', 3),
#   ('atendimento cliente', 3),
#   ('abertura fechamento', 3),
#   ('disponibilidade horarios', 3),
#   ('valores fechamento', 2),
#   ('caixa emissao', 2),
#   ('emissao notas', 2),
#   ('notas fiscais', 2)],
#  'Técnico de enfermagem': [('tecnico enfermagem', 6),
#   ('disponibilidade horario', 4),
#   ('curso tecnico', 4),
#   ('horario trabalho', 3),
#   ('outras atribuicoes', 2),
#   ('atribuicoes funcao', 2),
#   ('curativos outras', 2),
#   ('seguranca trabalho', 2),
#   ('segunda sexta', 2),
#   ('vaga exclusiva', 2)],
#  'Repositor de mercadorias': [('vaga exclusiva', 6),
#   ('exclusiva pcd', 4),
#   ('reposicao mercadorias', 3),
#   ('enviar curriculo', 3),
#   ('pessoa deficiencia', 2),
#   ('veiculo proprio', 2),
#   ('fazer reposicao', 2),
#   ('ensino medio', 2),
#   ('pessoas deficiencia', 2),
#   ('mercadorias gondolas', 2)],
#  'Auxiliar de cozinha': [('pre preparo', 3),
#   ('disponibilidade trabalhar', 3),
#   ('preparo alimentos', 2),
#   ('auxilia preparo', 2),
#   ('generos alimenticios', 2),
#   ('limpeza dependencias', 2),
#   ('trabalhar finais', 2),
#   ('finais semana', 2),
#   ('cozinheira preparar', 2),
#   ('ter experiencia', 2)],
#  'Técnico em segurança do trabalho': [('seguranca trabalho', 3),
#   ('ter experiencia', 2),
#   ('experiencia comprovada', 2),
#   ('trabalhador fara', 2),
#   ('atividades inerentes', 2),
#   ('inerentes funcao', 2),
#   ('construcao civil', 2),
#   ('curso tecnico', 2),
#   ('vagas moradores', 1),
#   ('moradores itapemirim', 1)],
#  'Assistente administrativo': [('ensino medio', 5),
#   ('planilhas excel', 3),
#   ('medio completo', 3),
#   ('enviar curriculo', 3),
#   ('vaga exclusiva', 2),
#   ('exclusiva pcd', 2),
#   ('contas pagar', 2),
#   ('ind trabalhador', 2),
#   ('trabalhador fazer', 2),
#   ('notas fiscais', 2)],
#  'Torneiro mecânico': [('experiencia comprovada', 4),
#   ('vaga trabalhar', 3),
#   ('segunda sexta', 3),
#   ('fazenda rio', 3),
#   ('rio grande', 3),
#   ('horario comercial', 2),
#   ('ter experiencia', 2),
#   ('cnh ab', 2),
#   ('horario trabalho', 2),
#   ('sexta feira', 2)],
#  'Caseiro': [('vaga casal', 3),
#   ('fazer todos', 1),
#   ('todos servicos', 1),
#   ('servicos gerais', 1),
#   ('gerais fazenda', 1),
#   ('fazenda toda', 1),
#   ('toda limpeza', 1),
#   ('vaga permanente', 1),
#   ('permanente caseiro', 1),
#   ('caseiro necessario', 1)],
#  'Mecânico de manutenção de máquina industrial': [('experiencia comprovada',
#    3),
#   ('ensino medio', 2),
#   ('medio completo', 2),
#   ('manutencao maquinas', 2),
#   ('maquinas industriais', 2),
#   ('experiencia comprovacao', 1),
#   ('comprovacao carteira', 1),
#   ('carteira ensino', 1),
#   ('ensino fundamental', 1),
#   ('fundamental disponibilidade', 1)],
#  'Açougueiro': [('preparar carnes', 2),
#   ('carnes comercializacao', 2),
#   ('trabalhar conformidade', 2),
#   ('conformidade normas', 2),
#   ('normas procedimentos', 2),
#   ('procedimentos tecnicos', 2),
#   ('tecnicos qualidade', 2),
#   ('qualidade seguranca', 2),
#   ('preservacao ambiental', 2),
#   ('expediente seg', 2)],
#  'Motorista entregador': [('ter cnh', 4),
#   ('ensino medio', 3),
#   ('entrega clientes', 3),
#   ('cnh ab', 3),
#   ('deve ter', 2),
#   ('ter experiencia', 2),
#   ('curso mopp', 2),
#   ('cnh categoria', 2),
#   ('carga descarga', 2),
#   ('dirige carrega', 1)],
#  'Marceneiro': [('fabricacao moveis', 5),
#   ('moveis sob', 3),
#   ('sob medida', 3),
#   ('ter experiencia', 2),
#   ('segunda sexta', 2),
#   ('moveis planejados', 2),
#   ('atencao vaga', 1),
#   ('vaga exclusiva', 1),
#   ('exclusiva moradores', 1),
#   ('moradores igarape', 1)],
#  'Trabalhador rural': [('servicos gerais', 4),
#   ('ter referencias', 3),
#   ('casal trabalhar', 2),
#   ('trabalhar propriedade', 2),
#   ('propriedade rural', 2),
#   ('referencias experiencia', 2),
#   ('pode ter', 2),
#   ('ter filhos', 2),
#   ('ter experiencia', 2),
#   ('vaga casal', 2)],
#  'Farmacêutico': [('superior completo', 4),
#   ('curso superior', 3),
#   ('completo farmacia', 3),
#   ('disponibilidade horario', 2),
#   ('ctps minimo', 2),
#   ('atendimento cliente', 2),
#   ('farmaceutico deve', 1),
#   ('deve supervisionar', 1),
#   ('supervisionar orientar', 1),
#   ('orientar processo', 1)],
#  'Técnico em manutenção de equipamentos de informática': [('manutencao computadores',
#    3),
#   ('tecnico informatica', 2),
#   ('necessario ter', 2),
#   ('candidatos experiencia', 1),
#   ('experiencia programacao', 1),
#   ('programacao alteracao', 1),
#   ('alteracao loja', 1),
#   ('loja virtual', 1),
#   ('virtual codigofazer', 1),
#   ('codigofazer integracao', 1)],
#  'Oficial de serviços gerais na manutenção de edificações': [('disponibilidade horario',
#    3),
#   ('ter disponibilidade', 3),
#   ('ira realizar', 2),
#   ('realizar servicos', 2),
#   ('servicos limpeza', 2),
#   ('servicos gerais', 2),
#   ('trabalhar restaurante', 1),
#   ('restaurante atendendo', 1),
#   ('atendendo fazer', 1),
#   ('fazer limpeza', 1)],
#  'Auxiliar de logistica': [('vaga exclusiva', 3),
#   ('exclusiva pcd', 3),
#   ('carga descarga', 2),
#   ('ensino medio', 2),
#   ('medio completo', 2),
#   ('separar armazenar', 1),
#   ('armazenar organizar', 1),
#   ('organizar mercadorias', 1),
#   ('mercadorias demais', 1),
#   ('demais atividades', 1)],
#  'Zelador': [('necessario ter', 2),
#   ('experiencia funcao', 2),
#   ('pessoa experiencia', 2),
#   ('trabalhador fara', 2),
#   ('vaga trabalhar', 1),
#   ('trabalhar campos', 1),
#   ('campos julio', 1),
#   ('julio necessario', 1),
#   ('ter experiencia', 1),
#   ('efetuar limpeza', 1)],
#  'Cozinheiro geral': [('trabalhador experiencia', 3),
#   ('boas praticas', 2),
#   ('cozinha industrial', 2),
#   ('vaga casal', 2),
#   ('ter experiencia', 2),
#   ('residir cidade', 1),
#   ('cidade taua', 1),
#   ('taua conhecimento', 1),
#   ('conhecimento boas', 1),
#   ('praticas higiene', 1)],
#  'Ajudante de carga e descarga de mercadoria': [('carga descarga', 6),
#   ('vaga exclusiva', 4),
#   ('exclusiva pcd', 4),
#   ('pessoa deficiencia', 2),
#   ('enviar curriculo', 2),
#   ('deposito carga', 2),
#   ('candidatos vaga', 1),
#   ('pcd ensino', 1),
#   ('ensino fundamental', 1),
#   ('fundamental completo', 1)],
#  'Operador de empilhadeira': [('vaga trabalhar', 3),
#   ('operar empilhadeira', 2),
#   ('operador empilhadeira', 2),
#   ('acompanhar plano', 1),
#   ('plano manutencao', 1),
#   ('manutencao acompanhar', 1),
#   ('acompanhar graficos', 1),
#   ('graficos sistema', 1),
#   ('sistema gestao', 1),
#   ('gestao atualizado', 1)],
#  'Alimentador de linha de produção': [('ira realizar', 1),
#   ('realizar diversos', 1),
#   ('diversos servicos', 1),
#   ('servicos internos', 1),
#   ('ira trabalhar', 1),
#   ('trabalhar servicos', 1),
#   ('servicos diversos', 1),
#   ('diversos auxiliar', 1),
#   ('cortar limpar', 1),
#   ('limpar frango', 1)],
#  'Motorista de caminhão-guincho pesado com munk': [('experiencia comprovada',
#    2),
#   ('gsst 100', 2),
#   ('operador munk', 2),
#   ('responsavel efetuar', 1),
#   ('efetuar servicos', 1),
#   ('servicos motorista', 1),
#   ('motorista operacao', 1),
#   ('operacao caminhao', 1),
#   ('caminhao munck', 1),
#   ('munck fazer', 1)],
#  'Operador de retro-escavadeira': [('retro escavadeira', 3),
#   ('experiencia comprovada', 2),
#   ('segunda sexta', 2),
#   ('operador bob', 1),
#   ('bob cat', 1),
#   ('operar equipamentos', 1),
#   ('equipamentos escavacao', 1),
#   ('escavacao carregamento', 1),
#   ('carregamento confeccionado', 1),
#   ('confeccionado valas', 1)],
#  'Borracheiro': [('montagem desmontagem', 3),
#   ('desmontagem pneus', 2),
#   ('motorista borracheiro', 1),
#   ('sine municipal', 1),
#   ('municipal experiencia', 1),
#   ('experiencia consertos', 1),
#   ('consertos pneus', 1),
#   ('pneus carro', 1),
#   ('carro caminhao', 1),
#   ('caminhao etc', 1)],
#  'Costureira em geral': [('ter experiencia', 2),
#   ('diferencial ter', 1),
#   ('experiencia ramo', 1),
#   ('ramo colchoes', 1),
#   ('colchoes estofados', 1),
#   ('pessoa ira', 1),
#   ('ira confeccionar', 1),
#   ('confeccionar pecas', 1),
#   ('pecas inteiras', 1),
#   ('inteiras ajustes', 1)],
#  'Serralheiro': [('experiencia solda', 2),
#   ('experiencia comprovada', 2),
#   ('solda inox', 1),
#   ('confeccionam reparam', 1),
#   ('reparam instalam', 1),
#   ('instalam pecas', 1),
#   ('pecas elementos', 1),
#   ('elementos diversos', 1),
#   ('diversos chapas', 1),
#   ('chapas metal', 1)],
#  'Vigilante': [('entrada saida', 3),
#   ('saida pessoas', 3),
#   ('curso vigilante', 2),
#   ('vigilancia seguranca', 2),
#   ('curso formacao', 2),
#   ('formacao vigilante', 2),
#   ('escala 12x36', 2),
#   ('vaga exclusiva', 2),
#   ('controlar entrada', 2),
#   ('ensino medio', 2)],
#  'Mecânico de automóvel': [('enviar curriculo', 2),
#   ('veiculos leves', 2),
#   ('injecao eletronica', 2),
#   ('trabalhador realizar', 2),
#   ('manutencao veiculos', 2),
#   ('mecanico automotivo', 1),
#   ('curriculo juliana', 1),
#   ('juliana cabralseteq', 1),
#   ('cabralseteq pe', 1),
#   ('pe gov', 1)],
#  'Motorista carreteiro': [('disponibilidade viagens', 2),
#   ('obrigatorio ensino', 2),
#   ('experiencia ctps', 2),
#   ('ctps cnh', 2),
#   ('cnh trabalhar', 2),
#   ('trabalhar motorista', 2),
#   ('motorista coleta', 2),
#   ('coleta entrega', 2),
#   ('pcdtransporte carga', 1),
#   ('carga graos', 1)],
#  'Analista de recursos humanos': [('superior completo', 3),
#   ('promovem acoes', 2),
#   ('departamento pessoal', 2),
#   ('assistente rh', 1),
#   ('assistente gerencia', 1),
#   ('gerencia presidencia', 1),
#   ('presidencia conhecimentos', 1),
#   ('conhecimentos ingles', 1),
#   ('ingles espanhol', 1),
#   ('espanhol ferramentas', 1)],
#  'Eletricista': [('instalacoes eletricas', 2),
#   ('trabalhador experiencia', 2),
#   ('equipamentos eletricos', 2),
#   ('atuar area', 1),
#   ('area manutencao', 1),
#   ('manutencao construcao', 1),
#   ('construcao prestar', 1),
#   ('prestar servicos', 1),
#   ('servicos diversos', 1),
#   ('diversos energisa', 1)],
#  'Representante comercial autônomo': [('veiculo proprio', 5),
#   ('experiencia vendas', 3),
#   ('ter veiculo', 3),
#   ('carteira habilitacao', 2),
#   ('horario comercial', 2),
#   ('ensino medio', 2),
#   ('realizar vendas', 1),
#   ('vendas cosmeticos', 1),
#   ('cosmeticos afins', 1),
#   ('afins necessario', 1)],
#  'Motofretista': [('moto propria', 2),
#   ('realizar entrega', 1),
#   ('entrega moto', 1),
#   ('moto empresa', 1),
#   ('empresa durante', 1),
#   ('durante dia', 1),
#   ('dia conheca', 1),
#   ('conheca ruascom', 1),
#   ('ruascom experiencia', 1),
#   ('experiencia referencia', 1)],
#  'Atendente de balcão': [('ter experiencia', 2),
#   ('vendas pecas', 2),
#   ('ira realizar', 1),
#   ('realizar atendimento', 1),
#   ('atendimento on', 1),
#   ('on line', 1),
#   ('line telefone', 1),
#   ('telefone necessario', 1),
#   ('necessario possuir', 1),
#   ('possuir boa', 1)],
#  'Operador de caldeira': [('controlar funcionamento', 2),
#   ('funcionamento caldeiras', 2),
#   ('ensino medio', 2),
#   ('medio completo', 2),
#   ('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('vaga permanente', 1),
#   ('permanente operador', 1),
#   ('operador caldeiras', 1),
#   ('caldeiras trabalhador', 1)],
#  'Mecânico de manutenção de máquinas agrícolas': [('necessario ter', 2),
#   ('experiencia comprovada', 2),
#   ('realizar manutencao', 1),
#   ('manutencao tratores', 1),
#   ('tratores necessario', 1),
#   ('ter curso', 1),
#   ('curso mecanica', 1),
#   ('trabalhar fazenda', 1),
#   ('formacao tecnica', 1),
#   ('tecnica completa', 1)],
#  'Jardineiro': [('local trabalho', 2),
#   ('exclusiva pcd', 1),
#   ('pcd executar', 1),
#   ('executar atividades', 1),
#   ('atividades poda', 1),
#   ('poda replantio', 1),
#   ('replantio adubacao', 1),
#   ('adubacao periodica', 1),
#   ('periodica irrigacao', 1),
#   ('irrigacao varredura', 1)],
#  'Enfermeiro': [('superior completo', 3),
#   ('vaga exclusiva', 2),
#   ('enviar curriculo', 1),
#   ('curriculo mail', 1),
#   ('mail ilanaamaciellgmail', 1),
#   ('ilanaamaciellgmail assunto', 1),
#   ('assunto enfermeiro', 1),
#   ('enfermeiro cpf', 1),
#   ('cpf pis', 1),
#   ('pis aguardar', 1)],
#  'Servente de limpeza': [('servicos gerais', 3),
#   ('gerais limpeza', 2),
#   ('ajudante limpeza', 1),
#   ('limpeza servicos', 1),
#   ('trabalhador vaga', 1),
#   ('vaga masculinarealizar', 1),
#   ('masculinarealizar servicos', 1),
#   ('limpeza industrial', 1),
#   ('industrial moinho', 1),
#   ('moinho servico', 1)],
#  'Padeiro': [('experiencia comprovada', 3),
#   ('comprovada funcao', 2),
#   ('vaga permanente', 1),
#   ('permanente padeiro', 1),
#   ('padeiro nova', 1),
#   ('nova canaa', 1),
#   ('canaa norte', 1),
#   ('norte deve', 1),
#   ('deve ter', 1),
#   ('ter experiencia', 1)],
#  'Operador de telemarketing ativo e receptivo': [('18 anos', 3),
#   ('anos ensino', 3),
#   ('ensino medio', 3),
#   ('medio completo', 3),
#   ('vaga exclusiva', 2),
#   ('exclusiva pcd', 2),
#   ('somente maiores', 2),
#   ('maiores 18', 2),
#   ('atendimento cliente', 2),
#   ('realizara atendimento', 2)],
#  'Auxiliar de mecânico de autos': [('necessario ter', 2),
#   ('ensino medio', 2),
#   ('medio completo', 2),
#   ('experiencia mecanica', 2),
#   ('auxiliar manutencao', 1),
#   ('manutencao mecanica', 1),
#   ('mecanica caminhoes', 1),
#   ('caminhoes caminhonetes', 1),
#   ('nao necessario', 1),
#   ('ter experiencia', 1)],
#  'Vendedor de serviços': [('empresa contrata', 2),
#   ('contrata vendedor', 2),
#   ('vendedor externo', 2),
#   ('externo experiencia', 2),
#   ('experiencia trabalhar', 2),
#   ('contrato temporario', 2),
#   ('temporario possibilidade', 2),
#   ('possibilidade renovacao', 2),
#   ('renovacao contratacao', 2),
#   ('contratacao permanente', 2)],
#  'Cuidador de idosos': [('cuidar idosa', 1),
#   ('idosa 8o', 1),
#   ('8o anoscom', 1),
#   ('anoscom alzheimer', 1),
#   ('alzheimer trocar', 1),
#   ('trocar frauda', 1),
#   ('frauda fazer', 1),
#   ('fazer higiene', 1),
#   ('higiene medicamento', 1),
#   ('medicamento entrar', 1)],
#  'Montador de móveis de madeira': [('montador moveis', 3),
#   ('moveis sob', 2),
#   ('sob medida', 2),
#   ('montagem moveis', 2),
#   ('moveis planejados', 2),
#   ('preparam local', 1),
#   ('local trabalho', 1),
#   ('trabalho montam', 1),
#   ('montam serie', 1),
#   ('serie unidade', 1)],
#  'Recepcionista secretária': [('vaga trabalhar', 3),
#   ('ira auxiliar', 2),
#   ('imprescindivel experiencia', 1),
#   ('experiencia administrativo', 1),
#   ('administrativo atendimento', 1),
#   ('atendimento telefone', 1),
#   ('telefone auxiliar', 1),
#   ('auxiliar escritorio', 1),
#   ('escritorio deixa', 1),
#   ('deixa lo', 1)],
#  'Repositor - em supermercados': [('vaga exclusiva', 2),
#   ('exclusiva pcd', 2),
#   ('vaga trabalhar', 1),
#   ('trabalhar supermercado', 1),
#   ('supermercado avenida', 1),
#   ('avenida valdon', 1),
#   ('valdon varjao', 1),
#   ('varjao setor', 1),
#   ('setor industrialvai', 1),
#   ('industrialvai registrar', 1)],
#  'Cozinheiro de restaurante': [('horario comercial', 2),
#   ('preparar pratos', 1),
#   ('pratos diversos', 1),
#   ('diversos carnes', 1),
#   ('carnes peixe', 1),
#   ('peixe frangos', 1),
#   ('frangos massas', 1),
#   ('massas saladas', 1),
#   ('saladas comida', 1),
#   ('comida selv', 1)],
#  'Ajudante de eletricista': [('horario comercial', 3),
#   ('trabalho horario', 1),
#   ('comercial nao', 1),
#   ('nao exige', 1),
#   ('exige experiencia', 1),
#   ('experiencia auxiliara', 1),
#   ('auxiliara parte', 1),
#   ('parte eletrica', 1),
#   ('eletrica obras', 1),
#   ('obras geral', 1)],
#  'Eletricista de instalações de veículos automotores': [('trabalhador ira', 3),
#   ('exclusiva pcd', 2),
#   ('sistema eletrico', 2),
#   ('ira realizar', 2),
#   ('manutencao eletrica', 2),
#   ('expediente segunda', 2),
#   ('segunda sexta', 2),
#   ('pcd eletricista', 1),
#   ('eletricista manutencao', 1),
#   ('manutencao veiculos', 1)],
#  'Pizzaiolo': [('preparo pizzas', 2),
#   ('folga semana', 2),
#   ('semana domingo', 2),
#   ('domingo mes', 2),
#   ('horario trabalho', 2),
#   ('ramo atividade', 1),
#   ('atividade hoteispreparacao', 1),
#   ('hoteispreparacao pizzas', 1),
#   ('pizzas salgados', 1),
#   ('pizzaiolo ajudante', 1)],
#  'Montador': [('observando normas', 4),
#   ('trabalhador ira', 2),
#   ('etapas iniciais', 2),
#   ('iniciais processo', 2),
#   ('processo producao', 2),
#   ('producao observando', 2),
#   ('normas seguranca', 2),
#   ('seguranca qualidade', 2),
#   ('qualidade produto', 2),
#   ('produto final', 2)],
#  'Auxiliar de marceneiro': [('auxiliar fabricacao', 2),
#   ('fabricacao moveis', 2),
#   ('moveis sob', 2),
#   ('sob medida', 2),
#   ('auxiliar montador', 2),
#   ('trabalhador ira', 1),
#   ('ira auxiliar', 1),
#   ('medida cortes', 1),
#   ('cortes chapas', 1),
#   ('chapas carga', 1)],
#  'Montador soldador': [('experiencia solda', 2),
#   ('solda montagem', 1),
#   ('montagem pecas', 1),
#   ('pecas silos', 1),
#   ('silos ensino', 1),
#   ('ensino fundamental', 1),
#   ('fundamental completo', 1),
#   ('montagem desmontagem', 1),
#   ('desmontagem equipamentos', 1),
#   ('equipamentos solda', 1)],
#  'Lavador de veículos': [('exclusiva pcd', 1),
#   ('pcd lavagem', 1),
#   ('lavagem veiculos', 1),
#   ('veiculos pesados', 1),
#   ('pesados caminhao', 1),
#   ('caminhao aplicacao', 1),
#   ('aplicacao produtos', 1),
#   ('produtos higienizacao', 1),
#   ('higienizacao geral', 1),
#   ('necessario ter', 1)],
#  'Inspetor de qualidade': [('ensino medio', 2),
#   ('medio completo', 2),
#   ('vaga assistente', 1),
#   ('assistente qualidade', 1),
#   ('qualidade implementar', 1),
#   ('implementar executar', 1),
#   ('executar procedimentos', 1),
#   ('procedimentos sistema', 1),
#   ('sistema qualidade', 1),
#   ('qualidade organizar', 1)],
#  'Carpinteiro': [('trabalhar obras', 1),
#   ('obras construtora', 1),
#   ('construtora ha', 1),
#   ('ha 20', 1),
#   ('20 km', 1),
#   ('km cidade', 1),
#   ('cidade sorriso', 1),
#   ('sorriso mt', 1),
#   ('mt nao', 1),
#   ('nao alojamento', 1)],
#  'Confeiteiro': [('ter experiencia', 2),
#   ('experiencia comprovada', 2),
#   ('trabalhar padaria', 1),
#   ('padaria supermercado', 1),
#   ('supermercado necessario', 1),
#   ('necessario ter', 1),
#   ('candidatos deve', 1),
#   ('deve ter', 1),
#   ('experiencia funcaoira', 1),
#   ('funcaoira auxiliar', 1)],
#  'Auxiliar de estoque': [('limpo organizado', 4),
#   ('produtos materiais', 4),
#   ('vaga exclusiva', 2),
#   ('exclusiva pcd', 2),
#   ('pcd executar', 2),
#   ('executar atividades', 2),
#   ('atividades relacionadas', 2),
#   ('relacionadas setor', 2),
#   ('setor deposito', 2),
#   ('deposito conforme', 2)],
#  'Ajudante de açougueiro (comércio)': [('horario trabalho', 3),
#   ('atendimento balcao', 2),
#   ('folga escala', 2),
#   ('trabalhar supermercado', 2),
#   ('domingo domingo', 2),
#   ('vaga auxiliar', 2),
#   ('auxiliar acougue', 2),
#   ('deve ser', 2),
#   ('conhecimento gerais', 1),
#   ('gerais acougue', 1)],
#  'Auxiliar financeiro': [('ira trabalhar', 1),
#   ('trabalhar material', 1),
#   ('material construcao', 1),
#   ('construcao auxiliar', 1),
#   ('auxiliar financeiro', 1),
#   ('financeiro foco', 1),
#   ('foco faturamento', 1),
#   ('faturamento lancamento', 1),
#   ('lancamento notas', 1),
#   ('vaga trabalhar', 1)],
#  'Mecânico de máquinas pesadas (manutenção)': [('maquinas pesadas', 2),
#   ('necessario ter', 2),
#   ('experiencia funcao', 2),
#   ('montar desmontar', 2),
#   ('ramo atividadeobras', 1),
#   ('atividadeobras terraplenagemmanutencao', 1),
#   ('terraplenagemmanutencao maquinas', 1),
#   ('pesadas ex', 1),
#   ('ex escavadeira', 1),
#   ('escavadeira retroescavadeira', 1)],
#  'Promotor de vendas': [('necessario ter', 2),
#   ('vendas externas', 2),
#   ('atencao vaga', 1),
#   ('vaga exclusiva', 1),
#   ('exclusiva moradores', 1),
#   ('moradores igarape', 1),
#   ('igarape sao', 1),
#   ('sao joaquim', 1),
#   ('joaquim bicas', 1),
#   ('bicas necessario', 1)],
#  'Encanador': [('cnh ab', 2),
#   ('deve ter', 2),
#   ('expediente segunda', 2),
#   ('encanador rede', 1),
#   ('rede aguas', 1),
#   ('aguas pluvial', 1),
#   ('pluvial obras', 1),
#   ('obras infraestrutura', 1),
#   ('infraestrutura experiencia', 1),
#   ('experiencia cnh', 1)],
#  'Auxiliar de escritório': [('trabalho ser', 1),
#   ('ser executado', 1),
#   ('executado preparacao', 1),
#   ('preparacao documentos', 1),
#   ('documentos digitalizacao', 1),
#   ('digitalizacao geracao', 1),
#   ('geracao imagens', 1),
#   ('11 auxiliar', 1),
#   ('auxiliar atividades', 1),
#   ('atividades escritorio', 1)],
#  'Recepcionista atendente': [('ensino medio', 2),
#   ('medio completo', 2),
#   ('atendimento cliente', 1),
#   ('cliente pessoalmente', 1),
#   ('pessoalmente telefone', 1),
#   ('telefone organizacao', 1),
#   ('organizacao processos', 1),
#   ('processos arquivos', 1),
#   ('arquivos rotinas', 1),
#   ('rotinas administrativas', 1)],
#  'Estoquista': [('controle estoque', 2),
#   ('trabalhar entrada', 1),
#   ('entrada saida', 1),
#   ('saida mercadorias', 1),
#   ('mercadorias organizacao', 1),
#   ('organizacao geral', 1),
#   ('geral empresa', 1),
#   ('empresa equipamentos', 1),
#   ('equipamentos agricultura', 1),
#   ('agricultura pecuaria', 1)],
#  'Mecânico de manutenção de caminhão a diesel': [('mecanico caminhao', 1),
#   ('caminhao diesel', 1),
#   ('diesel d20', 1),
#   ('efetuar manutencao', 1),
#   ('manutencao preventiva', 1),
#   ('preventiva corretiva', 1),
#   ('corretiva equipamentos', 1),
#   ('equipamentos automoveis', 1),
#   ('automoveis caminhoes', 1),
#   ('caminhoes empresa', 1)],
#  'Técnico em eletromecânica': [('atividades eletrica', 2),
#   ('eletrica mecanica', 2),
#   ('mecanica industrial', 2),
#   ('ter curso', 2),
#   ('curso tecnico', 2),
#   ('executar atividades', 1),
#   ('industrial conforme', 1),
#   ('conforme solicitacao', 1),
#   ('solicitacao ordem', 1),
#   ('ordem servico', 1)],
#  'Gerente comercial': [('conhecimento vendas', 2),
#   ('vendas demais', 2),
#   ('ter cnh', 1),
#   ('cnh disponibilidade', 1),
#   ('disponibilidade viajar', 1),
#   ('viajar curso', 1),
#   ('curso tecnico', 1),
#   ('tecnico tecnologo', 1),
#   ('tecnologo gestao', 1),
#   ('gestao comercial', 1)],
#  'Mestre de obras': [('vaga permanente', 1),
#   ('permanente mestre', 1),
#   ('mestre obras', 1),
#   ('obras necessario', 1),
#   ('necessario experiencia', 1),
#   ('experiencia funca', 1),
#   ('profissional funcao', 1),
#   ('necessario cnh', 1),
#   ('cnh trabalhar', 1),
#   ('trabalhar obra', 1)],
#  'Operador de processo de produção': [('ter disponibilidade', 2),
#   ('embalar selar', 1),
#   ('selar cortar', 1),
#   ('cortar inspecionar', 1),
#   ('inspecionar frango', 1),
#   ('tarefas diversas', 1),
#   ('diversas setores', 1),
#   ('setores embalagem', 1),
#   ('embalagem evisceracao', 1),
#   ('vaga exclusiva', 1)],
#  'Auxiliar de almoxarifado': [('exclusiva pcd', 2),
#   ('vaga exclusiva', 1),
#   ('pcd pessoa', 1),
#   ('pessoa deficiencia', 1),
#   ('deficiencia trabalhar', 1),
#   ('trabalhar empresa', 1),
#   ('empresa avenida', 1),
#   ('avenida miguel', 1),
#   ('miguel sutil', 1),
#   ('sutil bairro', 1)],
#  'Auxiliar de contabilidade': [('ter experiencia', 3),
#   ('experiencia comprovada', 2),
#   ('ciencias contabeis', 2),
#   ('comprovada area', 1),
#   ('area estar', 1),
#   ('estar cursando', 1),
#   ('cursando ter', 1),
#   ('ter concluido', 1),
#   ('concluido ciencias', 1),
#   ('contabeis enviar', 1)],
#  'Frentista': [('exclusiva pcd', 1),
#   ('pcd realizar', 1),
#   ('realizar abastecimento', 1),
#   ('abastecimento lubrificacao', 1),
#   ('lubrificacao calibragem', 1),
#   ('calibragem veiculos', 1),
#   ('veiculos pesados', 1),
#   ('vendem mercadorias', 1),
#   ('mercadorias estabelecimentos', 1),
#   ('estabelecimentos comercio', 1)],
#  'Conferente de carga e descarga': [('disponibilidade horario', 1),
#   ('horario noturno', 1),
#   ('noturno vaga', 1),
#   ('vaga trabalhar', 1),
#   ('trabalhar companhia', 1),
#   ('companhia alimentos', 1),
#   ('alimentos varzea', 1),
#   ('varzea grande', 1),
#   ('grande ira', 1),
#   ('ira carregar', 1)],
#  'Vaqueiro': [('necessario ter', 2),
#   ('ter experiencia', 2),
#   ('experiencia funcao', 2),
#   ('trabalhar cuidando', 1),
#   ('cuidando animais', 1),
#   ('animais tirando', 1),
#   ('tirando leite', 1),
#   ('leite fazendo', 1),
#   ('fazendo queijo', 1),
#   ('queijo fazendo', 1)],
#  'Mecânico de manutenção de máquinas, em geral': [('maquinas pesadas', 3),
#   ('manutencao mecanica', 2),
#   ('mecanica maquinas', 2),
#   ('pesadas frotas', 2),
#   ('frotas equipamentos', 2),
#   ('equipamentos mineracao', 2),
#   ('mineracao cat', 2),
#   ('cat scania', 2),
#   ('scania volvo', 2),
#   ('volvo liebherr', 2)],
#  'Corretor de imóveis': [('ensino medio', 2),
#   ('ter experiencia', 1),
#   ('experiencia curso', 1),
#   ('curso area', 1),
#   ('area ensino', 1),
#   ('medio morar', 1),
#   ('morar eusebio', 1),
#   ('eusebio fortaleza', 1),
#   ('fortaleza interessados', 1),
#   ('interessados enviar', 1)],
#  'Atendente de farmácia - balconista': [('experiencia area', 2),
#   ('balconista deve', 1),
#   ('deve supervisionar', 1),
#   ('supervisionar orientar', 1),
#   ('orientar processo', 1),
#   ('processo compra', 1),
#   ('compra medicamentos', 1),
#   ('medicamentos demais', 1),
#   ('demais produtos', 1),
#   ('produtos farmacia', 1)],
#  'Vigia': [('areas externas', 2),
#   ('vigiar diversas', 1),
#   ('diversas areas', 1),
#   ('areas unidade', 1),
#   ('unidade portaria', 1),
#   ('portaria areas', 1),
#   ('areas limitrofes', 1),
#   ('limitrofes empresa', 1),
#   ('empresa percorrendo', 1),
#   ('percorrendo verificando', 1)],
#  'Operador de escavadeira': [('mini escavadeira', 2),
#   ('trabalhador ira', 1),
#   ('ira operar', 1),
#   ('operar mini', 1),
#   ('escavadeira cnh', 1),
#   ('cnh pois', 1),
#   ('pois transporta', 1),
#   ('transporta escavadeira', 1),
#   ('escavadeira caminhao', 1),
#   ('caminhao horario', 1)],
#  'Auxiliar de expedição': [('produtos materiais', 2),
#   ('vaga exclusiva', 1),
#   ('exclusiva pcd', 1),
#   ('pcd experiencia', 1),
#   ('experiencia carga', 1),
#   ('carga descarga', 1),
#   ('descarga encaminhar', 1),
#   ('encaminhar candidatos', 1),
#   ('candidatos deficiencia', 1),
#   ('deficiencia leve', 1)],
#  'Salgadeiro': [('segunda sabado', 2),
#   ('trabalhar segunda', 1),
#   ('sabado necessario', 1),
#   ('necessario experiencia', 1),
#   ('experiencia nao', 1),
#   ('nao fumante', 1),
#   ('necessario ter', 1),
#   ('ter experiencia', 1),
#   ('experiencia producao', 1),
#   ('producao salgados', 1)],
#  'Balconista': [('atuar area', 1),
#   ('area auto', 1),
#   ('auto pecas', 1),
#   ('pessoa ter', 1),
#   ('ter experiencia', 1),
#   ('experiencia balcao', 1),
#   ('balcao padaria', 1),
#   ('padaria saber', 1),
#   ('saber troco', 1),
#   ('troco auxiliar', 1)],
#  'Chapista de lanchonete': [('recebera treinamento', 1),
#   ('treinamento manipulacao', 1),
#   ('manipulacao boas', 1),
#   ('boas praticas', 1),
#   ('praticas alimentos', 1),
#   ('alimentos experiencia', 1),
#   ('experiencia auxiliar', 1),
#   ('auxiliar chapeiro', 1),
#   ('chapeiro montagem', 1),
#   ('montagem lanches', 1)],
#  'Manicure': [('cuidam beleza', 2),
#   ('beleza maos', 2),
#   ('maos pes', 2),
#   ('tratam estetica', 1),
#   ('estetica saude', 1),
#   ('saude aplicam', 1),
#   ('aplicam produtos', 1),
#   ('produtos quimicos', 1),
#   ('quimicos ondular', 1),
#   ('ondular alisar', 1)],
#  'Eletricista de manutenção industrial': [('experiencia curso', 2),
#   ('nr 10', 2),
#   ('executar montagem', 1),
#   ('montagem manutencao', 1),
#   ('manutencao instalacoes', 1),
#   ('instalacoes eletricas', 1),
#   ('eletricas maquinas', 1),
#   ('maquinas equipamentos', 1),
#   ('equipamentos industriais', 1),
#   ('industriais outras', 1)],
#  'Atendente de telemarketing': [('atendem usuarios', 1),
#   ('usuarios oferecem', 1),
#   ('oferecem servicos', 1),
#   ('servicos produtos', 1),
#   ('produtos prestam', 1),
#   ('prestam servicos', 1),
#   ('servicos tecnicos', 1),
#   ('tecnicos especializados', 1),
#   ('especializados realizam', 1),
#   ('realizam pesquisas', 1)],
#  'Operador de máquinas fixas, em geral': [('vaga exclusiva', 4),
#   ('exclusiva ppd', 3),
#   ('ppd ira', 3),
#   ('ira verificar', 3),
#   ('verificar condicoes', 3),
#   ('condicoes operacao', 3),
#   ('operacao maquina', 3),
#   ('maquina dispositivos', 3),
#   ('dispositivos ferramentas', 3),
#   ('ferramentas operar', 3)],
#  'Abatedor de aves': [('desossa cortes', 2),
#   ('cortes congeladospesagem', 2),
#   ('ocupacao trabalhar', 1),
#   ('trabalhar abatedouro', 1),
#   ('abatedouro aves', 1),
#   ('aves separador', 1),
#   ('separador partes', 1),
#   ('partes frango', 1),
#   ('trabalhar abate', 1),
#   ('abate aves', 1)],
#  'Mecânico de veículos': [('exclusiva pcd', 1),
#   ('pcd substituir', 1),
#   ('substituir filtro', 1),
#   ('filtro diesel', 1),
#   ('diesel lubrificante', 1),
#   ('lubrificante assim', 1),
#   ('assim troca', 1),
#   ('troca oleo', 1),
#   ('oleo motor', 1),
#   ('motor cambio', 1)],
#  'Técnico mecânico': [('tecnico mecanica', 2),
#   ('veiculos leves', 2),
#   ('leves pesados', 2),
#   ('curso tecnico', 2),
#   ('ter cnh', 2),
#   ('ensino medio', 1),
#   ('medio tecnico', 1),
#   ('mecanica conhecimento', 1),
#   ('conhecimento operacao', 1),
#   ('operacao equipamentos', 1)],
#  'Operador de teleatendimento híbrido (telemarketing)': [('atencao entrevista',
#    1),
#   ('entrevista levar', 1),
#   ('levar rg', 1),
#   ('atividades ira', 1),
#   ('ira atuar', 1),
#   ('atuar central', 1),
#   ('central atendimento', 1),
#   ('atendimento cliente', 1),
#   ('cliente podendo', 1),
#   ('podendo atuar', 1)],
#  'Instalador de sistemas eletroeletrônicos de segurança': [('instalacao manutencao',
#    2),
#   ('necessario experiencia', 1),
#   ('experiencia trabalhador', 1),
#   ('trabalhador devera', 1),
#   ('devera ter', 1),
#   ('ter disponibilidade', 1),
#   ('disponibilidade fazer', 1),
#   ('fazer plantao', 1),
#   ('plantao viagens', 1),
#   ('viagens interior', 1)],
#  'Porteiro': [('exclusiva pcd', 1),
#   ('pcd controle', 1),
#   ('controle acesso', 1),
#   ('acesso pessoas', 1),
#   ('pessoas veiculos', 1),
#   ('veiculos materiais', 1),
#   ('materiais atendimento', 1),
#   ('atendimento pessoal', 1),
#   ('pessoal telefonico', 1),
#   ('telefonico visitantes', 1)],
#  'Auxiliar mecânico de refrigeração': [('experiencia comprovada', 2),
#   ('auxiliar instalacao', 1),
#   ('instalacao servicos', 1),
#   ('servicos manutencao', 1),
#   ('manutencao preventiva', 1),
#   ('preventiva corretiva', 1),
#   ('corretiva equipamentos', 1),
#   ('equipamentos climatizacao', 1),
#   ('climatizacao refrigeracao', 1),
#   ('refrigeracao self', 1)],
#  'Operador de vendas (lojas)': [('atendimento cliente', 2),
#   ('ajudante lojasrepositorfiscal', 1),
#   ('lojasrepositorfiscal lojaempacotadoroperador', 1),
#   ('lojaempacotadoroperador caixa', 1),
#   ('xy1945 captacao', 1),
#   ('captacao curriculos', 1),
#   ('curriculos cleuza', 1),
#   ('cleuza email', 1),
#   ('email dp', 1),
#   ('dp rioclarospani', 1)],
#  'Almoxarife': [('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('trabalhador realizar', 1),
#   ('realizar separacao', 1),
#   ('separacao carregamento', 1),
#   ('carregamento pecas', 1),
#   ('pecas area', 1),
#   ('area usinagem', 1),
#   ('usinagem cnh', 1),
#   ('cnh expediente', 1)],
#  'Mecânico de refrigeração': [('experiencia comprovada', 3),
#   ('comprovada area', 2),
#   ('possuir experiencia', 1),
#   ('trabalhador ira', 1),
#   ('ira fazer', 1),
#   ('fazer desmontagem', 1),
#   ('desmontagem montagem', 1),
#   ('montagem limpeza', 1),
#   ('limpeza retirada', 1),
#   ('retirada reinstalacao', 1)],
#  'Técnico agrícola': [('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('trabalhador dara', 1),
#   ('dara assistencia', 1),
#   ('assistencia produtores', 1),
#   ('produtores leite', 1),
#   ('leite manutencao', 1),
#   ('manutencao maquinas', 1),
#   ('maquinas ordenha', 1),
#   ('ordenha interessante', 1)],
#  'Servente de pedreiro': [('carpinteiro armador', 2),
#   ('ramo atividadeconstrucao', 1),
#   ('atividadeconstrucao edificiosexecutar', 1),
#   ('edificiosexecutar servicos', 1),
#   ('servicos apoio', 1),
#   ('apoio pedreiro', 1),
#   ('pedreiro carpinteiro', 1),
#   ('armador canteiro', 1),
#   ('canteiro transportando', 1),
#   ('transportando materiais', 1)],
#  'Eletricista de instalações': [('instalacao equipamentos', 2),
#   ('trabalho seg', 2),
#   ('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('eletricista instalacao', 1),
#   ('equipamentos energia', 1),
#   ('energia solar', 1),
#   ('solar trabalho', 1),
#   ('seg sex', 1),
#   ('sex horario', 1)],
#  'Tratorista agrícola': [('vaga trabalhar', 1),
#   ('trabalhar curtume', 1),
#   ('curtume saida', 1),
#   ('saida cuiaba', 1),
#   ('cuiaba ter', 1),
#   ('ter disponibilidade', 1),
#   ('disponibilidade horario', 1),
#   ('horario cnh', 1),
#   ('ira trabalhar', 1),
#   ('trabalhar transbordo', 1)],
#  'Técnico eletrônico': [('atencao vaga', 1),
#   ('vaga exclusiva', 1),
#   ('exclusiva moradores', 1),
#   ('moradores igarape', 1),
#   ('igarape sao', 1),
#   ('sao joaquim', 1),
#   ('joaquim bicas', 1),
#   ('bicas betim', 1),
#   ('betim ira', 1),
#   ('ira realizar', 1)],
#  'Pintor industrial': [('segunda sexta', 2),
#   ('pintor experiencia', 1),
#   ('experiencia pintura', 1),
#   ('pintura po', 1),
#   ('po eletrostatica', 1),
#   ('eletrostatica expediente', 1),
#   ('expediente segunda', 1),
#   ('sexta horario', 1),
#   ('horario comercial', 1),
#   ('comercial antes', 1)],
#  'Babá': [('crianca anos', 2),
#   ('trabalhara primeiros', 1),
#   ('primeiros meses', 1),
#   ('meses navirai', 1),
#   ('navirai mudara', 1),
#   ('mudara trabalhar', 1),
#   ('trabalhar maringa', 1),
#   ('maringa residencia', 1),
#   ('residencia empregadora', 1),
#   ('empregadora cuidando', 1)],
#  'Gerente de vendas': [('gerente vendas', 3),
#   ('todo brasil', 2),
#   ('vendas emporio', 1),
#   ('emporio italiano', 1),
#   ('italiano salario', 1),
#   ('salario 50000', 1),
#   ('50000 necessario', 1),
#   ('necessario ensino', 1),
#   ('ensino medio', 1),
#   ('medio completo', 1)],
#  'Vidraceiro': [('planejar trabalhos', 1),
#   ('trabalhos efetuar', 1),
#   ('efetuar cortes', 1),
#   ('cortes montagem', 1),
#   ('montagem edficacoes', 1),
#   ('edficacoes anos', 1),
#   ('anos comprovacao', 1),
#   ('comprovacao preferencialmente', 1),
#   ('preferencialmente morar', 1),
#   ('morar bairros', 1)],
#  'Auxiliar de agricultura': [('ira trabalhar', 2),
#   ('trabalhar tratos', 2),
#   ('tratos culturais', 2),
#   ('culturais cana', 2),
#   ('cana acucar', 2),
#   ('acucar auxiliam', 1),
#   ('auxiliam colheita', 1),
#   ('colheita mesma', 1),
#   ('plantio cana', 1),
#   ('cana acucaradubamento', 1)],
#  'Instalador de alarme': [('rastreamento veicular', 2),
#   ('instalador rastreamento', 1),
#   ('veicular trabalhar', 1),
#   ('trabalhar instalacao', 1),
#   ('instalacao manutencao', 1),
#   ('manutencao equipamentos', 1),
#   ('equipamentos eletronicos', 1),
#   ('eletronicos rastreamento', 1),
#   ('veicular carro', 1),
#   ('carro moto', 1)],
#  'Contador': [('necessario curso', 1),
#   ('curso superior', 1),
#   ('superior experiencia', 1),
#   ('experiencia contadorcnh', 1),
#   ('contadorcnh desejavel', 1),
#   ('desejavel conhecimento', 1),
#   ('conhecimento sistema', 1),
#   ('sistema totvsrm', 1),
#   ('totvsrm trabalhar', 1),
#   ('trabalhar laticinios', 1)],
#  'Montador de estruturas metálicas': [('expediente segunda', 2),
#   ('segunda sexta', 2),
#   ('trabalhador ira', 2),
#   ('vaga fabricante', 1),
#   ('fabricante estruturas', 1),
#   ('estruturas metalicas', 1),
#   ('metalicas expediente', 1),
#   ('sexta atencao', 1),
#   ('atencao enviar', 1),
#   ('enviar curriculo', 1)],
#  'Técnico de refrigeração (instalação)': [('tecnico eletromecanica', 1),
#   ('eletromecanica industrial', 1),
#   ('industrial concluido', 1),
#   ('concluido nr13', 1),
#   ('nr13 nr10', 1),
#   ('nr10 nr', 1),
#   ('nr 35', 1),
#   ('35 trabalhar', 1),
#   ('trabalhar industria', 1),
#   ('industria ramo', 1)],
#  'Atendente de padaria': [('pessoa ira', 1),
#   ('ira realizar', 1),
#   ('realizar atendimento', 1),
#   ('atendimento padaria', 1),
#   ('padaria mercado', 1),
#   ('mercado auxiliar', 1),
#   ('auxiliar limpeza', 1),
#   ('limpeza organizacao', 1),
#   ('organizacao local', 1),
#   ('local seg', 1)],
#  'Camareira de hotel': [('ramo atividade', 1),
#   ('atividade hoteislimpeza', 1),
#   ('hoteislimpeza geral', 1),
#   ('geral arrumacao', 1),
#   ('arrumacao quartos', 1),
#   ('quartos hotel', 1),
#   ('vaga exclusiva', 1),
#   ('exclusiva pessoas', 1),
#   ('pessoas deficiencia', 1),
#   ('deficiencia realizar', 1)],
#  'Atendente de lojas': [('atendimento cliente', 2),
#   ('14h 22h', 2),
#   ('candidatos operador', 1),
#   ('operador loja', 1),
#   ('loja caixaexclusiva', 1),
#   ('caixaexclusiva pcdreposicao', 1),
#   ('pcdreposicao mercadorias', 1),
#   ('mercadorias atendimento', 1),
#   ('cliente operacoes', 1),
#   ('operacoes caixaexperiencia', 1)],
#  'Atendente balconista': [('realizar atendimento', 1),
#   ('atendimento viajantes', 1),
#   ('viajantes iram', 1),
#   ('iram fazer', 1),
#   ('fazer refeicoes', 1),
#   ('refeicoes balcao', 1),
#   ('atendimento cliente', 1),
#   ('cliente organizacao', 1),
#   ('organizacao limpeza', 1),
#   ('limpeza local', 1)],
#  'Mecânico de motor a diesel': [('trabalhador fara', 1),
#   ('fara todas', 1),
#   ('todas atividades', 1),
#   ('atividades inerentes', 1),
#   ('inerentes funcao', 1),
#   ('trabalhar mecanica', 1),
#   ('mecanica caminhonetes', 1),
#   ('caminhonetes diesel', 1),
#   ('diesel eletricidade', 1),
#   ('eletricidade demais', 1)],
#  'Ajudante de cozinha': [('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('itapemirim marataizes', 1),
#   ('vaga trabalhar', 1),
#   ('trabalhar adrianopolis', 1),
#   ('adrianopolis restaurante', 1),
#   ('restaurante coma', 1),
#   ('coma bem', 1),
#   ('bem auxiliar', 1),
#   ('auxiliar servicos', 1)],
#  'Vendedor - no comércio de mercadorias': [('ter disponibilidade', 2),
#   ('vendas mercadorias', 1),
#   ('informacoes fgtas', 1),
#   ('fgtas sine', 1),
#   ('sine tres', 1),
#   ('tres maio', 1),
#   ('maio 55', 1),
#   ('55 3535', 1),
#   ('3535 1841', 1),
#   ('obs conta', 1)],
#  'Auxiliar operacional de logística': [('exclusiva pcd', 3),
#   ('curriculo carta', 2),
#   ('carta sine', 2),
#   ('vaga exclusiva', 2),
#   ('movimentacao mercadorias', 2),
#   ('vaga auxiliar', 1),
#   ('auxiliar operacional', 1),
#   ('operacional exclusiva', 1),
#   ('pcd carimbar', 1),
#   ('carimbar auditar', 1)],
#  'Operador de pá carregadeira': [('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('imprescindivel habilitacao', 1),
#   ('habilitacao categoria', 1),
#   ('categoria bd', 1),
#   ('bd curso', 1),
#   ('curso operador', 1),
#   ('operador maquinas', 1),
#   ('maquinas candidato', 1),
#   ('candidato ira', 1)],
#  'Pintor de automóveis': [('preparar tinta', 1),
#   ('tinta pintar', 1),
#   ('pintar carretas', 1),
#   ('carretas pintar', 1),
#   ('pintar chassi', 1),
#   ('chassi caminhoes', 1),
#   ('caminhoes pintura', 1),
#   ('pintura parte', 1),
#   ('parte graneleira', 1),
#   ('graneleira carretas', 1)],
#  'Mecânico de automóveis e caminhões': [('manutencao mecanica', 1),
#   ('mecanica caminhoes', 1),
#   ('caminhoes caminhonetes', 1),
#   ('elaboram planos', 1),
#   ('planos manutencao', 1),
#   ('manutencao realizam', 1),
#   ('realizam manutencoes', 1),
#   ('manutencoes motores', 1),
#   ('motores sistemas', 1),
#   ('sistemas partes', 1)],
#  'Cobrador externo': [('necessario ter', 2),
#   ('ter experiencia', 1),
#   ('experiencia funcao', 1),
#   ('funcao ter', 1),
#   ('ter cnh', 1),
#   ('cnh empresa', 1),
#   ('empresa disponibiliza', 1),
#   ('disponibiliza moto', 1),
#   ('moto trabalhar', 1),
#   ('trabalhar trabalho', 1)],
#  'Classificador de grãos': [('vaga trabalhar', 2),
#   ('trabalhar auditor', 2),
#   ('auditor graos', 2),
#   ('graos ira', 2),
#   ('ira fazer', 2),
#   ('fazer analise', 2),
#   ('analise criteriosa', 2),
#   ('criteriosa graos', 2),
#   ('graos soja', 2),
#   ('soja interagir', 2)],
#  'Analista administrativo': [('realizar analise', 2),
#   ('departamento pessoal', 2),
#   ('0800 1800', 2),
#   ('analise processos', 1),
#   ('processos departamento', 1),
#   ('pessoal identificar', 1),
#   ('identificar pontos', 1),
#   ('pontos melhoria', 1),
#   ('melhoria propor', 1),
#   ('propor solucoes', 1)],
#  'Auxiliar de operação': [('receber separar', 1),
#   ('separar preparar', 1),
#   ('preparar documentos', 1),
#   ('documentos conferindo', 1),
#   ('conferindo relacoes', 1),
#   ('relacoes remessas', 1),
#   ('remessas encaminhadas', 1),
#   ('encaminhadas area', 1),
#   ('area caixa', 1),
#   ('caixa forte', 1)],
#  'Armador de ferragens na construção civil': [('armacao ferragens', 1),
#   ('ferragens montagem', 1),
#   ('montagem ferragens', 1),
#   ('ferragens conforme', 1),
#   ('conforme projeto', 1),
#   ('projeto anos', 1),
#   ('anos comprovacao', 1),
#   ('comprovacao preferencialmente', 1),
#   ('preferencialmente morar', 1),
#   ('morar bairros', 1)],
#  'Apontador de obras': [('trabalhador deve', 1),
#   ('deve ter', 1),
#   ('ter conhecimentos', 1),
#   ('conhecimentos informatica', 1),
#   ('informatica word', 1),
#   ('word excel', 1),
#   ('excel ponto', 1),
#   ('ponto trabalhadores', 1),
#   ('trabalhadores enteder', 1),
#   ('enteder obras', 1)],
#  'Ajudante de motorista': [('carregar descarregar', 1),
#   ('descarregar produtos', 1),
#   ('produtos cliente', 1),
#   ('cliente revenda', 1),
#   ('revenda conferir', 1),
#   ('conferir vasilhames', 1),
#   ('vasilhames conformidade', 1),
#   ('conformidade auxiliar', 1),
#   ('auxiliar motorista', 1),
#   ('motorista entregas', 1)],
#  'Mecânico de auto em geral': [('vagas moradores', 1),
#   ('moradores itapemirim', 1),
#   ('experiencia motor', 1),
#   ('motor diferencial', 1),
#   ('diferencial caixa', 1),
#   ('caixa necessario', 1),
#   ('necessario ter', 1),
#   ('ter experiencia', 1),
#   ('experiencia comprovada', 1),
#   ('comprovada carteira', 1)],
#  'Ajudante de farmácia': [('medicamentos materiais', 2),
#   ('ensino medio', 2),
#   ('medio completo', 2),
#   ('precisa estar', 1),
#   ('estar cursando', 1),
#   ('cursando concluido', 1),
#   ('concluido ensino', 1),
#   ('ensino superior', 1),
#   ('superior tecnico', 1),
#   ('tecnico farmacia', 1)],
#  'Fonoaudiólogo geral': [('candidatas formacao', 1),
#   ('formacao area', 1),
#   ('area ira', 1),
#   ('ira atuar', 1),
#   ('atuar junto', 1),
#   ('junto equipe', 1),
#   ('equipe multidisciplinar', 1),
#   ('multidisciplinar atendimento', 1),
#   ('atendimento clinico', 1),
#   ('clinico infantil', 1)],
#  'Empregado doméstico diarista': [('trabalhar 2x', 2),
#   ('2x semana', 2),
#   ('necessario ter', 1),
#   ('ter experiencia', 1),
#   ('experiencia funcao', 1),
#   ('funcao referencia', 1),
#   ('referencia pessoal', 1),
#   ('pessoal trabalhar', 1),
#   ('semana limpeza', 1),
#   ('limpeza organizacao', 1)],
#  'Ajudante de estruturas metálicas': [('ter disponibilidade', 2),
#   ('auxiliara montadores', 1),
#   ('montadores organizacao', 1),
#   ('organizacao pecas', 1),
#   ('pecas torres', 1),
#   ('torres estrutura', 1),
#   ('estrutura metalica', 1),
#   ('metalica necessario', 1),
#   ('necessario ter', 1),
#   ('disponibilidade trabalhar', 1)],
#  'Torneiro cnc': [('vaga trabalhar', 1),
#   ('trabalhar cachoeira', 1),
#   ('cachoeira sul', 1),
#   ('sul programador', 1),
#   ('programador cnc', 1),
#   ('cnc exige', 1),
#   ('exige ensino', 1),
#   ('ensino medio', 1),
#   ('medio completo', 1),
#   ('completo experiencia', 1)],
#  'Vendedor porta a porta': [('perfil vendas', 1),
#   ('vendas trabalhar', 1),
#   ('trabalhar vendas', 1),
#   ('vendas energia', 1),
#   ('energia fotovoltaicatera', 1),
#   ('fotovoltaicatera treinamento', 1),
#   ('vaga moradores', 1),
#   ('moradores viamao', 1),
#   ('nao necessita', 1),
#   ('necessita experiencia', 1)],
#  'Atendente central telemarketing': [('agente atendimento', 1),
#   ('atendimento sac', 1),
#   ('sac empresa', 1),
#   ('empresa exige', 1),
#   ('exige 2o', 1),
#   ('2o completo', 1),
#   ('completo atendimento', 1),
#   ('atendimento clientes', 1),
#   ('clientes criticos', 1),
#   ('criticos ativo', 1)],
#  'Costureiro, a  máquina  na confecção em série': [('trabalhar confeccao', 2),
#   ('trabalhar maquina', 1),
#   ('maquina reta', 1),
#   ('reta fechadeira', 1),
#   ('fechadeira fechar', 1),
#   ('fechar lateral', 1),
#   ('lateral unir', 1),
#   ('unir pala', 1),
#   ('pala pregar', 1),
#   ('pregar carcela', 1)],
#  'Mecânico de veículos automotores a diesel (exceto tratores)': [('trabalhar ter',
#    1),
#   ('ter experiencia', 1),
#   ('experiencia manutencao', 1),
#   ('manutencao preventiva', 1),
#   ('preventiva corretiva', 1),
#   ('corretiva veiculo', 1),
#   ('veiculo diesel', 1),
#   ('diesel medio', 1),
#   ('medio grande', 1),
#   ('grande porte', 1)],
#  'Programador de sistemas de informação': [('vaga exclusiva', 2),
#   ('exclusiva pcdprograma', 2),
#   ('pcdprograma apoio', 2),
#   ('apoio pessoa', 2),
#   ('pessoa deficiencia', 2),
#   ('deficiencia ppd', 2),
#   ('ira trabalhar', 2),
#   ('inerentes funcao', 2),
#   ('funcao expediente', 2),
#   ('expediente 900hs', 2)],
#  'Mecânico de equipamentos industriais': [('mecanico experiencia', 1),
#   ('experiencia comprovada', 1),
#   ('comprovada maquinas', 1),
#   ('maquinas industriais', 1),
#   ('industriais carregadeiras', 1),
#   ('carregadeiras salario', 1),
#   ('salario refeicao', 1),
#   ('refeicao vale', 1),
#   ('vale alimentacao', 1),
#   ('alimentacao plano', 1)],
#  'Telefonista': [('vaga trabalhar', 1),
#   ('trabalhar centro', 1),
#   ('centro politico', 1),
#   ('politico administrativo', 1),
#   ('administrativo indispensavel', 1),
#   ('indispensavel ter', 1),
#   ('ter curso', 1),
#   ('curso experiencia', 1),
#   ('experiencia operar', 1),
#   ('operar equipamentos', 1)],
#  'Marmorista - exclusive empregador  em marmoraria': [('trabalhador ira', 1),
#   ('ira fazer', 1),
#   ('fazer servicos', 1),
#   ('servicos corte', 1),
#   ('corte acabamento', 1),
#   ('acabamento montagem', 1),
#   ('montagem pecas', 1),
#   ('pecas marmore', 1),
#   ('marmore granito', 1),
#   ('granito expediente', 1)],
#  'Terapeuta ocupacional': [('candidatas formacao', 1),
#   ('formacao area', 1),
#   ('area ira', 1),
#   ('ira atuar', 1),
#   ('atuar junto', 1),
#   ('junto equipe', 1),
#   ('equipe multidisciplinar', 1),
#   ('multidisciplinar atendimento', 1),
#   ('atendimento clinico', 1),
#   ('clinico infantil', 1)],
#  'Auxiliar de enfermagem': [('auxiliar enfermagem', 2),
#   ('ter curso', 1),
# ...
#   ('impostos apresentados', 1),
#   ('apresentados contabilidade', 1),
#   ('contabilidade assegurar', 1)],
#  'Desenhista de móveis': [('profissionais cria', 1),
#   ('cria projetos', 1),
#   ('projetos comunicacao', 1),
#   ('comunicacao visual', 1),
#   ('visual novos', 1),
#   ('novos produtos', 1),
#   ('produtos fabrica', 1),
#   ('fabrica sofa', 1),
#   ('sofa colchoes', 1),
#   ('colchoes levando', 1)],
#  'Serrador - em serrarias': [('planejam operacoes', 1),
#   ('operacoes desdobramento', 1),
#   ('desdobramento madeiras', 1),
#   ('madeiras preparam', 1),
#   ('preparam maquinas', 1),
#   ('maquinas realizacao', 1),
#   ('realizacao seguem', 1),
#   ('seguem procedimentos', 1),
#   ('procedimentos seguranca', 1),
#   ('seguranca realizam', 1)],
#  'Auxiliar geral de conservação de vias permanentes (exceto trilhos)': [('masculino rastelar',
#    1),
#   ('rastelar pavimentacao', 1),
#   ('pavimentacao tapar', 1),
#   ('tapar buraco', 1),
#   ('buraco massa', 1),
#   ('massa asfalto', 1)],
#  'Técnico em instrumentação': [('vaga pcd', 1),
#   ('pcd tec', 1),
#   ('tec enfermagem', 1),
#   ('enfermagem instrumentador', 1),
#   ('instrumentador meses', 1),
#   ('meses experiencia', 1),
#   ('experiencia ctps', 1),
#   ('ctps medio', 1),
#   ('medio completo', 1),
#   ('completo aceita', 1)],
#  'Laboratorista químico': [('crq ativo', 1)],
#  'Encanador industrial': [('trabalhar tubulacaoencanamento', 1),
#   ('tubulacaoencanamento frigorifico', 1),
#   ('frigorifico expediente', 1),
#   ('expediente segunda', 1),
#   ('segunda sabado', 1),
#   ('sabado 13h40', 1),
#   ('13h40 22h00', 1)],
#  'Panfleteiro': [('seg sex', 1),
#   ('sex 0830', 1),
#   ('0830 12', 1),
#   ('12 1330', 1),
#   ('1330 17h', 1),
#   ('17h pago', 1),
#   ('pago diaria', 1)],
#  'Operador de quadro de distribuição de energia elétrica': [('operador casa',
#    1),
#   ('casa forca', 1)],
#  'Ajudante de padeiro': [('ja trabalhado', 1),
#   ('trabalhado panificadora', 1),
#   ('panificadora disponibilidade', 1),
#   ('disponibilidade horarios', 1)],
#  'Avaliador de imóveis': [('trabalhador conhecimento', 1),
#   ('conhecimento informatica', 1),
#   ('informatica ira', 1),
#   ('ira trabalhar', 1),
#   ('trabalhar vistorias', 1),
#   ('vistorias imoveis', 1),
#   ('imoveis fazer', 1),
#   ('fazer relatorios', 1),
#   ('relatorios atendimento', 1),
#   ('atendimento cliente', 1)],
#  'Lavador de peças': [('trabalhador cnh', 1),
#   ('cnh ab', 1),
#   ('ab requisito', 1),
#   ('requisito obrigatorio', 1),
#   ('obrigatorio nocao', 1),
#   ('nocao pecas', 1),
#   ('pecas mecanica', 1)],
#  'Chapeador': [('chapeador funileiro', 1), ('funileiro experiencia', 1)],
#  'Preparador de tintas': [('obrigatorio experiencia', 1),
#   ('experiencia ctps', 1),
#   ('ctps preparar', 1),
#   ('preparar veiculo', 1),
#   ('veiculo pintura', 1),
#   ('pintura dar', 1),
#   ('dar massa', 1),
#   ('massa lixar', 1)],
#  'Escriturário': [('atendimento cliente', 1),
#   ('cliente suporte', 1),
#   ('suporte gerente', 1),
#   ('gerente vendas', 1),
#   ('vendas produtos', 1),
#   ('produtos bancarios', 1)],
#  'Atendente de buffet': [('pessoa ira', 1),
#   ('ira atender', 1),
#   ('atender clientes', 1),
#   ('clientes servir', 1),
#   ('servir alimentos', 1),
#   ('alimentos bebidas', 1),
#   ('bebidas restaurante', 1),
#   ('restaurante ira', 1),
#   ('ira ainda', 1),
#   ('ainda auxiliar', 1)],
#  'Trabalhador da pecuária (bovinos leite)': [('vaga homens', 1),
#   ('homens idade', 1),
#   ('idade 25', 1),
#   ('25 45', 1),
#   ('45 anos', 1),
#   ('anos ter', 1),
#   ('ter experiencia', 1),
#   ('experiencia trabalhar', 1),
#   ('trabalhar gado', 1),
#   ('gado conhecimento', 1)],
#  'Supervisor de cozinha': [('vaga destinada', 1),
#   ('destinada supervisora', 1),
#   ('supervisora padaria', 1)],
#  'Meia-colher': [('trabalhador atuara', 1),
#   ('atuara meio', 1),
#   ('meio oficial', 1),
#   ('oficial experiencia', 1),
#   ('experiencia comprovada', 1),
#   ('comprovada carteira', 1),
#   ('carteira minimo', 1),
#   ('minimo 06', 1),
#   ('06 meses', 1),
#   ('meses comprovacao', 1)],
#  'Queimador - em olaria': [('telhas tijolos', 3),
#   ('extraem materia', 1),
#   ('materia prima', 1),
#   ('prima jazidas', 1),
#   ('jazidas preparam', 1),
#   ('preparam argila', 1),
#   ('argila fabricacao', 1),
#   ('fabricacao telhas', 1),
#   ('tijolos processam', 1),
#   ('processam fabricacao', 1)],
#  'Técnico em manutenção de balanças': [('mecanico manutencao', 1),
#   ('manutencao balancas', 1),
#   ('balancas equipamentos', 1),
#   ('equipamentos padaria', 1),
#   ('padaria refrigeracao', 1),
#   ('refrigeracao comercial', 1),
#   ('comercial equipamentos', 1),
#   ('equipamentos leves', 1),
#   ('leves experiencia', 1),
#   ('experiencia meses', 1)],
#  'Operador de máquinas e equipamentos rodoferroviários': [('trabalhar empresa',
#    1),
#   ('empresa manutencao', 1),
#   ('manutencao rodovias', 1),
#   ('rodovias ter', 1),
#   ('ter habilitacao', 1)],
#  'Balconista de lanchonete': [('experiencia atendimento', 1),
#   ('atendimento lancheria', 1),
#   ('lancheria deve', 1),
#   ('deve ter', 1),
#   ('ter disponibilidade', 1),
#   ('disponibilidade trabalhar', 1),
#   ('trabalhar finais', 1),
#   ('finais semana', 1),
#   ('semana feriados', 1)],
#  'Instalador de antenas de televisão': [('instalacao antena', 1),
#   ('antena tv', 1),
#   ('tv acessorios', 1)],
#  'Carregador (armazém)': [('vaga exclusiva', 1),
#   ('exclusiva pessoa', 1),
#   ('pessoa deficiencia', 1),
#   ('deficiencia trabalhador', 1),
#   ('trabalhador fara', 1),
#   ('fara carga', 1),
#   ('carga descarga', 1),
#   ('descarga separacao', 1),
#   ('separacao mercadoriasconferencia', 1),
#   ('mercadoriasconferencia organizacao', 1)],
#  'Técnico em óptica e optometria': [('vaga temporaria', 1),
#   ('temporaria dias', 1),
#   ('dias mes', 1),
#   ('mes todos', 1),
#   ('todos meses', 1),
#   ('meses necessario', 1),
#   ('necessario ter', 1),
#   ('ter ensino', 1),
#   ('ensino medio', 1),
#   ('medio completo', 1)],
#  'Carregador e descarregador de caminhões': [('trabalhar empresa', 1),
#   ('empresa cargas', 1),
#   ('cargas farinha', 1),
#   ('farinha area', 1),
#   ('area industrial', 1),
#   ('industrial morumbi', 1)],
#  'Auxiliares administrativos e de escritórios': [('ira ajudar', 1),
#   ('ajudar tarefas', 1),
#   ('tarefas simples', 1),
#   ('simples area', 1),
#   ('area administrativa', 1),
#   ('administrativa arquivo', 1),
#   ('arquivo informacoes', 1),
#   ('informacoes fornecedores', 1),
#   ('fornecedores etc', 1)],
#  'Entregador de gás (ajudante de caminhão)': [('vaga trabalhador', 1),
#   ('trabalhador entregar', 1),
#   ('entregar agua', 1),
#   ('agua gas', 1),
#   ('gas moto', 1),
#   ('moto cnh', 1),
#   ('cnh ab', 1),
#   ('ab tambem', 1),
#   ('tambem fara', 1),
#   ('fara servicos', 1)],
#  'Vidraceiro colocador de vidros': [('instalador vidro', 1),
#   ('vidro temperado', 1),
#   ('temperado serralheiro', 1),
#   ('serralheiro aluminio', 1)],
#  'Esteticista': [('pessoa realizar', 1),
#   ('realizar atendimento', 1),
#   ('atendimento clientes', 1),
#   ('clientes realizacao', 1),
#   ('realizacao procedimentos', 1),
#   ('procedimentos esteticos', 1),
#   ('esteticos possuir', 1),
#   ('possuir curso', 1),
#   ('curso tecnico', 1),
#   ('tecnico area', 1)],
#  'Misturador de massas alimentícias': [('experiencia servicos', 1),
#   ('servicos organizacao', 1),
#   ('organizacao espaco', 1),
#   ('espaco cozinha', 1),
#   ('cozinha fazer', 1),
#   ('fazer varios', 1),
#   ('varios tipos', 1),
#   ('tipos receitas', 1)],
#  'Operador de ponte rolante': [('vagas moradores', 1),
#   ('moradores itapemirim', 1)],
#  'Bombeiro civil': [('vao trabalhar', 1),
#   ('trabalhar efetuando', 1),
#   ('efetuando salvamento', 1),
#   ('salvamento terrestres', 1),
#   ('terrestres aquaticos', 1),
#   ('aquaticos altura', 1),
#   ('altura protegendo', 1),
#   ('protegendo pessoas', 1),
#   ('pessoas patrimonios', 1),
#   ('patrimonios incendios', 1)],
#  'Encarregado de expedição': [('carregar caminhoesentregar', 1),
#   ('caminhoesentregar receber', 1),
#   ('receber mercadorias', 1),
#   ('mercadorias cuidar', 1),
#   ('cuidar estoques', 1),
#   ('estoques materiais', 1),
#   ('materiais vao', 1),
#   ('vao obras', 1),
#   ('obras precisa', 1),
#   ('precisa ter', 1)],
#  'Garçom': [('vaga permanente', 1),
#   ('permanente garcom', 1),
#   ('garcom atendimento', 1),
#   ('atendimento clientes', 1),
#   ('clientes apresentacao', 1),
#   ('apresentacao cardapio', 1),
#   ('cardapio sugerir', 1),
#   ('sugerir melhor', 1),
#   ('melhor opcao', 1),
#   ('opcao ocasiao', 1)],
#  'Técnico de desenvolvimento de sistemas (ti)': [('vaga correta', 1),
#   ('correta desenvolvedor', 1),
#   ('desenvolvedor java', 1),
#   ('java programar', 1),
#   ('programar desenvolver', 1),
#   ('desenvolver programas', 1),
#   ('programas java', 1),
#   ('java web', 1),
#   ('web html', 1),
#   ('html css', 1)],
#  'Impressor flexográfico': [('necessario ter', 1),
#   ('ter experiencia', 1),
#   ('experiencia flexografia', 1),
#   ('flexografia residir', 1),
#   ('residir joao', 1),
#   ('joao pessoapb', 1)],
#  'Representante técnico de vendas': [('trabalhar regiao', 1),
#   ('regiao cariri', 1),
#   ('cariri representacao', 1),
#   ('representacao administradora', 1),
#   ('administradora cartao', 1),
#   ('cartao credito', 1),
#   ('credito legista', 1),
#   ('legista substituindo', 1),
#   ('substituindo crediario', 1),
#   ('crediario garantindo', 1)],
#  'Impressor de ofsete (plano e rotativo)': [('curso tecnico', 1),
#   ('tecnico completo', 1),
#   ('completo mecanica', 1),
#   ('mecanica eletrica', 1),
#   ('eletrica artes', 1),
#   ('artes graficas', 1),
#   ('graficas experiencia', 1),
#   ('experiencia area', 1),
#   ('area offset', 1),
#   ('offset disponib', 1)],
#  'Retireiro': [('trabalhar retireiro', 1),
#   ('retireiro chacara', 1),
#   ('chacara localizada', 1),
#   ('localizada perto', 1),
#   ('perto avenorte', 1),
#   ('avenorte empresa', 1),
#   ('empresa oferece', 1),
#   ('oferece casa', 1),
#   ('casa agua', 1),
#   ('agua luz', 1)],
#  'Auxiliar de manutenção predial': [('trabalhador ira', 1),
#   ('ira executar', 1),
#   ('executar servicos', 1),
#   ('servicos manutencao', 1),
#   ('manutencao eletrica', 1),
#   ('eletrica mecanica', 1),
#   ('mecanica hidraulica', 1),
#   ('hidraulica carpintaria', 1),
#   ('carpintaria alvenaria', 1),
#   ('alvenaria substituindo', 1)],
#  'Mecânico de manutenção e instalação elétrica': [('ramo atividade', 1),
#   ('atividade metalurgica', 1),
#   ('metalurgica atividade', 1),
#   ('atividade principal', 1),
#   ('principal fazer', 1),
#   ('fazer manutencao', 1),
#   ('manutencao geradores', 1),
#   ('geradores eletricos', 1)],
#  'Operador de máquina agrícola': [('trabalhar preparo', 1),
#   ('preparo terras', 1),
#   ('terras auxiliar', 1),
#   ('auxiliar colheita', 1),
#   ('colheita reboque', 1),
#   ('reboque transbordo', 1)],
#  'Técnico de manutenção de computador': [('dinamico apt', 1),
#   ('apt aprender', 1),
#   ('aprender conhecimentos', 1),
#   ('conhecimentos basicos', 1),
#   ('basicos buscar', 1),
#   ('buscar entregar', 1),
#   ('entregar maquinas', 1),
#   ('maquinas auxiliar', 1),
#   ('auxiliar manutencao', 1)],
#  'Instrutor de informática': [('professor informatica', 1),
#   ('informatica tecnologia', 1),
#   ('tecnologia conhecimento', 1),
#   ('conhecimento funcao', 1),
#   ('funcao experiencia', 1),
#   ('experiencia programacao', 1),
#   ('programacao adobe', 1),
#   ('adobe horario', 1),
#   ('horario trabalho', 1),
#   ('trabalho flexivel', 1)],
#  'Mecânico de bomba injetora (exceto de veículos automotores)': [('ter disponibilidade',
#    1),
#   ('disponibilidade viajar', 1),
#   ('viajar cnh', 1),
#   ('cnh vaga', 1),
#   ('vaga trabalhar', 1),
#   ('trabalhar empresa', 1),
#   ('empresa especializada', 1),
#   ('especializada manutencao', 1),
#   ('manutencao injecao', 1),
#   ('injecao eletronica', 1)],
#  'Podador de árvores na conservação de vias permanentes': [('ajudante podador',
#    1)],
#  'Técnico de inspeção da indústria metalúrgica': [('vaga tecnico', 1),
#   ('tecnico inspecao', 1),
#   ('inspecao planejamento', 1),
#   ('planejamento mecanico', 1),
#   ('mecanico iv', 1),
#   ('iv v2060218', 1),
#   ('v2060218 candidato', 1),
#   ('candidato deve', 1),
#   ('deve ser', 1),
#   ('ser encaminhado', 1)],
#  'Encarregado da recepção': [('hotel matrincha', 1)],
#  'Mecânico de manutenção de ar condicionado': [('ter cnh', 1),
#   ('cnh ter', 1),
#   ('ter curso', 1),
#   ('curso tecnico', 1),
#   ('tecnico ar', 1),
#   ('ar condicionado', 1),
#   ('condicionado morar', 1),
#   ('morar trabalhar', 1),
#   ('trabalhar nobres', 1),
#   ('nobres vaga', 1)],
#  'Mecânico de manutenção hidráulica': [('ter experiencia', 2),
#   ('necessario ter', 1),
#   ('experiencia funcao', 1),
#   ('funcao trabalha', 1),
#   ('trabalha mina', 1),
#   ('mina subterranea', 1),
#   ('subterranea mineracao', 1),
#   ('mineracao pau', 1),
#   ('pau pique', 1),
#   ('pique ter', 1)],
#  'Funileiro industrial': [('obrigatorio ensino', 1),
#   ('ensino fundamental', 1),
#   ('fundamental completo', 1),
#   ('completo experiencia', 1),
#   ('experiencia minimo', 1),
#   ('minimo meses', 1),
#   ('meses produzir', 1),
#   ('produzir calhas', 1),
#   ('calhas coifas', 1),
#   ('coifas algerosas', 1)],
#  'Auxiliar de faturamento': [('notas fiscais', 3),
#   ('vaga exclusiva', 1),
#   ('exclusiva pcd', 1),
#   ('pcd pessoa', 1),
#   ('pessoa deficiencia', 1),
#   ('deficiencia auxiliar', 1),
#   ('auxiliar faturamento', 1),
#   ('faturamento pedidos', 1),
#   ('pedidos notas', 1),
#   ('fiscais expedicao', 1)],
#  'Mecânico de manutenção de máquinas de construção e terraplenagem': [('auxiliar manutencao',
#    1)],
#  'Advogado': [('vagaadvogado contratos', 1),
#   ('contratos candidato', 1),
#   ('candidato deve', 1),
#   ('deve ser', 1),
#   ('ser encaminhado', 1),
#   ('encaminhado sistema', 1),
#   ('sistema mte', 1),
#   ('mte emprega', 1),
#   ('emprega brasil', 1),
#   ('brasil orientado', 1)],
#  'Instrutor de auto-escola': [('vaga instrutor', 1),
#   ('instrutor trabalhador', 1),
#   ('trabalhador devera', 1),
#   ('devera ter', 1),
#   ('ter cursos', 1),
#   ('cursos experiencia', 1),
#   ('experiencia ctps', 1)],
#  'Chefe de lavanderia': [('lider lavanderia', 1),
#   ('lavanderia realizara', 1),
#   ('realizara parte', 1),
#   ('parte chefia', 1),
#   ('chefia lavanderia', 1),
#   ('lavanderia experiencia', 1),
#   ('experiencia gestao', 1),
#   ('gestao equipes', 1),
#   ('equipes necessario', 1),
#   ('necessario possuir', 1)],
#  'Preparador de calçados': [('vaga exclusiva', 1),
#   ('exclusiva pessoa', 1),
#   ('pessoa deficiencia', 1),
#   ('deficiencia trabalhar', 1),
#   ('trabalhar senador', 1),
#   ('senador pompeu', 1),
#   ('pompeu candidatos', 1),
#   ('candidatos precisam', 1),
#   ('precisam ser', 1),
#   ('ser homologados', 1)],
#  'Faturista': [('organizam documentos', 1),
#   ('documentos efetuam', 1),
#   ('efetuam classificacao', 1),
#   ('classificacao contabil', 1),
#   ('contabil geram', 1),
#   ('geram lancamentos', 1),
#   ('lancamentos contabeis', 1),
#   ('contabeis auxiliam', 1),
#   ('auxiliam apuracao', 1),
#   ('apuracao impostos', 1)],
#  'Atendente de clínica  médica': [('estagio atender', 1),
#   ('atender telefone', 1),
#   ('telefone pacientes', 1),
#   ('pacientes pos', 1),
#   ('pos consulta', 1),
#   ('consulta entregar', 1),
#   ('entregar receitas', 1),
#   ('receitas atestados', 1),
#   ('atestados preparos', 1),
#   ('preparos exames', 1)],
#  'Professor de educação física no ensino superior': [('vaga estagio', 1),
#   ('estagio cursando', 1),
#   ('cursando educacao', 1),
#   ('educacao fisica', 1),
#   ('fisica trabalhara', 1),
#   ('trabalhara instrutor', 1),
#   ('instrutor academia', 1),
#   ('academia auxiliando', 1),
#   ('auxiliando alunos', 1),
#   ('alunos treinos', 1)],
#  'Trabalhador da avicultura de corte': [('abate corte', 1), ('corte aves', 1)],
#  'Operador especializado de extrusora': [('fazer corantes', 1),
#   ('corantes preparar', 1),
#   ('preparar recheio', 1),
#   ('recheio nuggets', 1),
#   ('nuggets preencher', 1),
#   ('preencher fichas', 1),
#   ('fichas procedimentos', 1),
#   ('procedimentos montar', 1),
#   ('montar matrizes', 1),
#   ('matrizes regular', 1)],
#  'Mecânico de suspensão': [('trabalhar mecanico', 1),
#   ('mecanico suspensao', 1),
#   ('suspensao pesada', 1),
#   ('pesada tornearia', 1),
#   ('tornearia experiencia', 1),
#   ('experiencia disponibilidade', 1),
#   ('disponibilidade viajar', 1)],
#  'Condutor de ambulância': [('vaga exclusiva', 1),
#   ('exclusiva sobradinho', 1),
#   ('sobradinho ba', 1),
#   ('ba trabalhador', 1),
#   ('trabalhador deve', 1),
#   ('deve comparecer', 1),
#   ('comparecer posto', 1),
#   ('posto retirar', 1),
#   ('retirar carta', 1),
#   ('carta encaminhamento', 1)]}

# %% [markdown]
# # Preparando os resultados para salvar em BD

# %%
maisProcuradas = pd.DataFrame(top_10_ocup, columns=['pretensao'])

# %%
maisProcuradasComCursos = pd.DataFrame(top_10_ocup_com_cursos, columns=['pretensao'])

# %%
def flat_caracteristicas(data):
    flat = [[(k, v) for v in vs] for k, vs in data.items()]
    flat2 = []
    for i in flat:
        for j in i:
            try:
                flat2.append([j[0], j[1][0], j[1][1]])
            except:
                flat2.append([j[0], '-', '0'])
    return flat2

# %%
 flatten_top_caracteristicas = flat_caracteristicas(top_caracteristicas)

# %%
topCaracteristicasConcorrentes = pd.DataFrame.from_records(flatten_top_caracteristicas, columns=['pretensao', 'caracteristica', 'ocorrencias'])

# %%
topCaracteristicasConcorrentes
# Out:
#                                       pretensao             caracteristica  \
# 0                 Auxiliar de linha de produção         informatica basica
# 1                 Auxiliar de linha de produção      operador empilhadeira
# 2                 Auxiliar de linha de produção         informatica basico
# 3                 Auxiliar de linha de produção    auxiliar administrativo
# 4                 Auxiliar de linha de produção               ensino medio
# ..                                          ...                        ...
# 95  Operador de telemarketing ativo e receptivo        atendimento cliente
# 96  Operador de telemarketing ativo e receptivo      tecnico administracao
# 97  Operador de telemarketing ativo e receptivo       informatica avancada
# 98  Operador de telemarketing ativo e receptivo         seguranca trabalho
# 99  Operador de telemarketing ativo e receptivo  assistente administrativo
#
#     ocorrencias
# 0         85465
# 1         17913
# 2         10569
# 3          8300
# 4          8097
# ..          ...
# 95         2374
# 96         1932
# 97         1924
# 98         1868
# 99         1578
#
# [100 rows x 3 columns]

# %%
flatten_top_outras_caracteristicas = []
for ks, vs in top_outras_caracteristicas.items():
    for kk, vv in vs.items():
        for k, v in vv.items():
            flatten_top_outras_caracteristicas.append(list((ks, kk, k, round(v,3))))

# %%
topOutrasCaracteristicasConcorrentes = pd.DataFrame.from_records(flatten_top_outras_caracteristicas, columns=['pretensao', 'caracteristica', 'valor','proporcao'])

# %%
topOutrasCaracteristicasConcorrentes
# Out:
#                                      pretensao       caracteristica  \
# 0                            Operador de caixa         ESCOLARIDADE
# 1                            Operador de caixa         ESCOLARIDADE
# 2                            Operador de caixa         ESCOLARIDADE
# 3                            Operador de caixa         ESCOLARIDADE
# 4                            Operador de caixa         ESCOLARIDADE
# ..                                         ...                  ...
# 246  Empregado  doméstico  nos serviços gerais          DISP_VIAJAR
# 247  Empregado  doméstico  nos serviços gerais      DISP_DORMIR_EMP
# 248  Empregado  doméstico  nos serviços gerais      DISP_DORMIR_EMP
# 249  Empregado  doméstico  nos serviços gerais  DISP_AUSENTAR_DOMIC
# 250  Empregado  doméstico  nos serviços gerais  DISP_AUSENTAR_DOMIC
#
#                       valor  proporcao
# 0            Médio Completo      0.761
# 1          Médio Incompleto      0.113
# 2      Fundamental Completo      0.043
# 3       Superior Incompleto      0.038
# 4    Fundamental Incompleto      0.019
# ..                      ...        ...
# 246                       S      0.250
# 247                       N      0.777
# 248                       S      0.223
# 249                       N      0.786
# 250                       S      0.214
#
# [251 rows x 4 columns]

# %%
flatten_top_exigencias = flat_caracteristicas(top_exigencias)

# %%
topExigenciasVagas = pd.DataFrame.from_records(flatten_top_exigencias, columns=['pretensao', 'caracteristica', 'ocorrencias'])

# %%
topExigenciasVagas['ocorrencias'] = topExigenciasVagas['ocorrencias'].astype(int)

# %% [markdown]
# # Salvando os resultados no banco SQLite

# %%
conn = sqlite3.connect('coronathon_db.sqlite')

# %%
cur = conn.cursor()

# %%
maisProcuradas.to_sql(name='pre_maisprocuradas', con=conn, if_exists='replace')

# %%
maisProcuradasComCursos.to_sql(name='pre_maisProcuradasComCursos', con=conn, if_exists='replace')

# %%
topCaracteristicasConcorrentes.to_sql(name='pre_topCaracteristicasConcorrentes', con=conn, if_exists='replace')

# %%
topOutrasCaracteristicasConcorrentes.to_sql(name='pre_topOutrasCaracteristicasConcorrentes', con=conn, if_exists='replace')

# %%
topExigenciasVagas.to_sql(name='pre_topExigenciasVagas', con=conn, if_exists='replace')

# %%
cur.execute("DROP TABLE pre_topExigenciasVagas;")
print(cur.fetchall())

# %%
def to_csv():
    db = sqlite3.connect('coronathon_db.sqlite')
    cursor = db.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()
    for table_name in tables:
        table_name = table_name[0]
        table = pd.read_sql_query("SELECT * from %s" % table_name, db)
        table.to_csv(table_name + '.csv', index_label='index')
    cursor.close()
    db.close()

# %%
to_csv()

# %%
cur.execute("SELECT * FROM pre_topExigenciasVagas;")
print(cur.fetchall())
# Out:
# [(0, 'Auxiliar de linha de produção', 'vaga exclusiva', 15), (1, 'Auxiliar de linha de produção', 'linha producao', 15), (2, 'Auxiliar de linha de produção', 'pessoa deficiencia', 12), (3, 'Auxiliar de linha de produção', 'auxiliar producao', 10), (4, 'Auxiliar de linha de produção', 'linhas producao', 8), (5, 'Auxiliar de linha de produção', 'disponibilidade trabalhar', 8), (6, 'Auxiliar de linha de produção', 'exclusiva pcd', 7), (7, 'Auxiliar de linha de produção', 'segunda sexta', 7), (8, 'Auxiliar de linha de produção', 'area servico', 6), (9, 'Auxiliar de linha de produção', 'segunda sabado', 6), (10, 'Vendedor pracista', 'experiencia vendas', 16), (11, 'Vendedor pracista', 'ensino medio', 11), (12, 'Vendedor pracista', 'medio completo', 11), (13, 'Vendedor pracista', 'ter experiencia', 10), (14, 'Vendedor pracista', 'necessario ter', 6), (15, 'Vendedor pracista', 'vendas externas', 6), (16, 'Vendedor pracista', 'cnh ab', 6), (17, 'Vendedor pracista', 'segunda sexta', 5), (18, 'Vendedor pracista', 'realizar vendas', 5), (19, 'Vendedor pracista', 'horario comercial', 4), (20, 'Auxiliar administrativo', 'medio completo', 7), (21, 'Auxiliar administrativo', 'ensino medio', 6), (22, 'Auxiliar administrativo', 'auxiliar administrativo', 5), (23, 'Auxiliar administrativo', 'pacote office', 5), (24, 'Auxiliar administrativo', 'rotinas administrativas', 4), (25, 'Auxiliar administrativo', 'enviar curriculo', 4), (26, 'Auxiliar administrativo', 'segunda sexta', 4), (27, 'Auxiliar administrativo', 'vaga exclusiva', 3), (28, 'Auxiliar administrativo', 'exclusiva pcd', 3), (29, 'Auxiliar administrativo', 'horario trabalho', 3), (30, 'Vendedor interno', 'ensino medio', 9), (31, 'Vendedor interno', 'medio completo', 9), (32, 'Vendedor interno', 'materiais construcao', 7), (33, 'Vendedor interno', 'experiencia vendas', 7), (34, 'Vendedor interno', 'segunda sexta', 5), (35, 'Vendedor interno', 'horario comercial', 5), (36, 'Vendedor interno', 'vaga trabalhar', 4), (37, 'Vendedor interno', 'ter experiencia', 4), (38, 'Vendedor interno', 'completo experiencia', 4), (39, 'Vendedor interno', 'cnh ab', 3), (40, 'Auxiliar de limpeza', 'vaga exclusiva', 6), (41, 'Auxiliar de limpeza', 'exclusiva pcd', 5), (42, 'Auxiliar de limpeza', 'ensino fundamental', 5), (43, 'Auxiliar de limpeza', 'fundamental completo', 5), (44, 'Auxiliar de limpeza', 'limpeza conservacao', 4), (45, 'Auxiliar de limpeza', 'vaga trabalhar', 4), (46, 'Auxiliar de limpeza', 'fazer limpeza', 3), (47, 'Auxiliar de limpeza', 'conservacao geral', 3), (48, 'Auxiliar de limpeza', 'limpeza higienizacao', 3), (49, 'Auxiliar de limpeza', 'limpeza escritorio', 3), (50, 'Empregado  doméstico  nos serviços gerais', 'lavar passar', 8), (51, 'Empregado  doméstico  nos serviços gerais', 'ter experiencia', 7), (52, 'Empregado  doméstico  nos serviços gerais', 'segunda sexta', 6), (53, 'Empregado  doméstico  nos serviços gerais', 'fazer todo', 4), (54, 'Empregado  doméstico  nos serviços gerais', 'passar roupas', 4), (55, 'Empregado  doméstico  nos serviços gerais', 'experiencia comprovada', 4), (56, 'Empregado  doméstico  nos serviços gerais', 'casa lavar', 3), (57, 'Empregado  doméstico  nos serviços gerais', 'preparar refeicoes', 3), (58, 'Empregado  doméstico  nos serviços gerais', 'experiencia referencias', 3), (59, 'Empregado  doméstico  nos serviços gerais', 'ter referencias', 3), (60, 'Pedreiro', 'executar trabalhos', 4), (61, 'Pedreiro', 'outros materiais', 4), (62, 'Pedreiro', 'processos instrumentos', 4), (63, 'Pedreiro', 'instrumentos pertinentes', 4), (64, 'Pedreiro', 'pertinentes oficio', 4), (65, 'Pedreiro', 'servicos pedreiro', 3), (66, 'Pedreiro', 'materiais guiando', 3), (67, 'Pedreiro', 'guiando se', 3), (68, 'Pedreiro', 'trabalhos alvenaria', 3), (69, 'Pedreiro', 'alvenaria concreto', 3), (70, 'Consultor de vendas', 'ensino medio', 5), (71, 'Consultor de vendas', 'medio completo', 4), (72, 'Consultor de vendas', 'vendas externas', 4), (73, 'Consultor de vendas', 'cnh dis ...
